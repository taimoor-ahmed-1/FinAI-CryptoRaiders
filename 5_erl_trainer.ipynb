# %%
import os
# For Colab/Google Drive integration:
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/FinRL/final')  # Change to your project folder in Drive
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd
import os
import json
import matplotlib.pyplot as plt
from collections import deque
import random
from typing import Tuple, List, Dict, Any
import warnings
warnings.filterwarnings('ignore')

# ==================== IMPROVED HYPERPARAMETERS ====================
PPO_VERSION = "5_7_3"
CLIP_RATIO = 0.2
LAMBDA_GAE = 0.95
ENTROPY_COEF = 0.05
VALUE_COEF = 0.5
MAX_GRAD_NORM = 0.5
TARGET_KL = 0.02
NUM_EPOCHS = 6
BATCH_SIZE = 64
HORIZON_LEN = 4096
GAMMA = 0.99
GAE_LAMBDA = 0.95
ADV_NORM = True
VALUE_NORM = True
RETURN_NORM = True

# Training parameters
LEARNING_RATE = 3e-4
TOTAL_STEPS = 2000000
SAVE_GAP = 50000
EVAL_TIMES = 8
REPEAT_TIMES = 4
REWARD_SCALE = 1e-1

# Environment parameters
NUM_SIMS = 64
STEP_GAP = 2
MAX_POSITION = 1
SLIPPAGE = 7e-7
NUM_IGNORE_STEP = 60

NET_DIMS = [256, 256, 128, 128, 64]
ACTOR_LR = 3e-4
CRITIC_LR = 3e-4

# Environment parameters
STEP_GAP = 2
MAX_POSITION = 1
SLIPPAGE = 7e-7
NUM_IGNORE_STEP = 60
NORMALIZE_LLM_SIGNALS = True

def check_cuda():
    """Check CUDA availability and print status"""
    try:
        if torch.cuda.is_available():
            print(f"CUDA version: {torch.version.cuda}")
            print(f"GPU count: {torch.cuda.device_count()}")
            if torch.cuda.device_count() > 0:
                print(f"Current GPU: {torch.cuda.current_device()}")
                print(f"GPU name: {torch.cuda.get_device_name(0)}")
            return True
        else:
            print("CUDA is not available")
            return False
    except Exception as e:
        print(f"Error checking CUDA: {e}")
        return False

# ====================PPO NETWORK ARCHITECTURE ====================

class SimplePPOActor(nn.Module):
    def __init__(self, state_dim: int, action_dim: int, net_dims: List[int]):
        super().__init__()
        self.state_dim = state_dim
        self.action_dim = action_dim

        #MLP layers
        layers = []
        input_dim = state_dim

        for i, dim in enumerate(net_dims):
            layers.extend([
                nn.Linear(input_dim, dim),
                nn.ReLU(),
                nn.Dropout(0.1)
            ])

            if i < len(net_dims) - 1:
                layers.append(nn.LayerNorm(dim))
            input_dim = dim

        # Output layer
        layers.append(nn.Linear(input_dim, action_dim))

        self.net = nn.Sequential(*layers)
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            nn.init.orthogonal_(module.weight, gain=0.01)
            nn.init.constant_(module.bias, 0.0)

    def forward(self, state: torch.Tensor) -> torch.Tensor:
        return self.net(state)

    def get_action_probs(self, state: torch.Tensor) -> torch.Tensor:
        """Get action probabilities using softmax"""
        logits = self.forward(state)
        return F.softmax(logits, dim=-1)

    def get_action_log_probs(self, state: torch.Tensor, action: torch.Tensor) -> torch.Tensor:
        """Get log probabilities for specific actions"""
        action_probs = self.get_action_probs(state)
        log_probs = torch.log(action_probs + 1e-8)
        action = action.unsqueeze(-1)
        gathered = log_probs.gather(-1, action).squeeze(-1)

        return gathered

class SimplePPOCritic(nn.Module):
    """Critic network for PPO"""

    def __init__(self, state_dim: int, net_dims: List[int]):
        super().__init__()
        self.state_dim = state_dim

        # Build MLP layers
        layers = []
        input_dim = state_dim

        for i, dim in enumerate(net_dims):
            layers.extend([
                nn.Linear(input_dim, dim),
                nn.ReLU(),
                nn.Dropout(0.1)
            ])

            if i < len(net_dims) - 1:
                layers.append(nn.LayerNorm(dim))
            input_dim = dim

        # Output layer for single value
        layers.append(nn.Linear(input_dim, 1))

        self.net = nn.Sequential(*layers)
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            nn.init.orthogonal_(module.weight, gain=1.0)
            nn.init.constant_(module.bias, 0.0)

    def forward(self, state: torch.Tensor) -> torch.Tensor:
        return self.net(state).squeeze(-1)

# ==================== PPO AGENT ====================

class ImprovedPPOTrader:
    """PPO agent"""

    def __init__(self, state_dim: int, action_dim: int, net_dims: List[int],
                 device: str = 'cuda' if torch.cuda.is_available() else 'cpu'):
        self.device = device
        self.state_dim = state_dim
        self.action_dim = action_dim

        # Networks
        self.actor = SimplePPOActor(state_dim, action_dim, net_dims).to(device)
        self.critic = SimplePPOCritic(state_dim, net_dims).to(device)

        self.optimizer = optim.Adam([
            {'params': self.actor.parameters(), 'lr': ACTOR_LR},
            {'params': self.critic.parameters(), 'lr': CRITIC_LR}
        ])
        self.scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(self.optimizer, T_max=TOTAL_STEPS, eta_min=LEARNING_RATE*0.1)

        # PPO buffers
        self.states = []
        self.actions = []
        self.rewards = []
        self.values = []
        self.log_probs = []
        self.dones = []

        # Training stats
        self.total_steps = 0
        self.episode_rewards = []
        self.episode_lengths = []

    def select_action(self, state: torch.Tensor, training: bool = True) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        """Select action using current policy"""
        with torch.no_grad():
            action_probs = self.actor.get_action_probs(state)

            if training:
                temperature = 1.2  # Slightly higher temperature for more exploration
                logits = self.actor(state)
                scaled_logits = logits / temperature
                scaled_probs = F.softmax(scaled_logits, dim=-1)
                dist = torch.distributions.Categorical(scaled_probs)
                action = dist.sample()
                log_prob = dist.log_prob(action)
            else:
                # Greedy action selection
                action = torch.argmax(action_probs, dim=-1)
                log_prob = torch.zeros_like(action, dtype=torch.float)

            value = self.critic(state)

        return action, log_prob, value

    def store_transition(self, state: torch.Tensor, action: torch.Tensor,
                        reward: float, value: torch.Tensor, log_prob: torch.Tensor, done: bool):
        """Store transition in PPO buffer"""
        self.states.append(state.cpu().numpy())
        self.actions.append(action.cpu().numpy())
        self.rewards.append(reward)
        self.values.append(value.cpu().numpy())
        self.log_probs.append(log_prob.cpu().numpy())
        self.dones.append(done)

    def compute_gae(self, rewards: List[float], values: List[float],
                   dones: List[bool], gamma: float = GAMMA, lambda_: float = GAE_LAMBDA) -> Tuple[np.ndarray, np.ndarray]:
        """Compute Generalized Advantage Estimation"""
        advantages = np.zeros_like(rewards)
        last_gae_lam = 0

        for t in reversed(range(len(rewards))):
            if t == len(rewards) - 1:
                next_value = 0
            else:
                next_value = values[t + 1]

            delta = rewards[t] + gamma * next_value * (1 - dones[t]) - values[t]
            advantages[t] = last_gae_lam = delta + gamma * lambda_ * (1 - dones[t]) * last_gae_lam

        returns = advantages + values
        return advantages, returns

    def update_policy(self) -> Dict[str, float]:
        """Policy update"""
        if len(self.states) < BATCH_SIZE:
            return {}

        # Convert to tensors
        states = torch.FloatTensor(np.array(self.states)).to(self.device)
        actions = torch.LongTensor(np.array(self.actions)).to(self.device)
        old_log_probs = torch.FloatTensor(np.array(self.log_probs)).to(self.device)
        old_values = torch.FloatTensor(np.array(self.values)).to(self.device)

        # Compute GAE
        advantages, returns = self.compute_gae(self.rewards, self.values, self.dones)
        advantages = torch.FloatTensor(advantages).to(self.device)
        returns = torch.FloatTensor(returns).to(self.device)

        # Normalize advantages
        if ADV_NORM:
            advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        # Normalize returns
        if RETURN_NORM:
            returns = (returns - returns.mean()) / (returns.std() + 1e-8)

        actor_losses = []
        critic_losses = []
        kl_divs = []
        entropy_values = []

        for epoch in range(NUM_EPOCHS):
            # Shuffle data
            indices = torch.randperm(len(states))

            for start_idx in range(0, len(states), BATCH_SIZE):
                end_idx = min(start_idx + BATCH_SIZE, len(states))
                batch_indices = indices[start_idx:end_idx]

                batch_states = states[batch_indices]
                batch_actions = actions[batch_indices]
                batch_old_log_probs = old_log_probs[batch_indices]
                batch_advantages = advantages[batch_indices]
                batch_returns = returns[batch_indices]

                # Get current policy outputs
                current_log_probs = self.actor.get_action_log_probs(batch_states, batch_actions)
                current_values = self.critic(batch_states)

                # PPO clipped objective
                ratio = torch.exp(current_log_probs - batch_old_log_probs)
                surr1 = ratio * batch_advantages
                surr2 = torch.clamp(ratio, 1 - CLIP_RATIO, 1 + CLIP_RATIO) * batch_advantages
                actor_loss = -torch.min(surr1, surr2).mean()

                value_loss = F.mse_loss(current_values, batch_returns)

                # Entropy bonus
                action_probs = self.actor.get_action_probs(batch_states)
                entropy = -(action_probs * torch.log(action_probs + 1e-8)).sum(dim=-1).mean()

                # Total loss
                total_loss = actor_loss + VALUE_COEF * value_loss - ENTROPY_COEF * entropy

                self.optimizer.zero_grad()
                total_loss.backward()
                torch.nn.utils.clip_grad_norm_(
                    list(self.actor.parameters()) + list(self.critic.parameters()),
                    MAX_GRAD_NORM
                )
                self.optimizer.step()

                # Compute KL divergence for monitoring
                with torch.no_grad():
                    kl_div = (batch_old_log_probs - current_log_probs).mean()

                actor_losses.append(actor_loss.item())
                critic_losses.append(value_loss.item())
                kl_divs.append(kl_div.item())
                entropy_values.append(entropy.item())

            avg_kl = np.mean(kl_divs[-len(kl_divs)//NUM_EPOCHS:])
            if avg_kl > TARGET_KL:
                print(f"Early stopping at epoch {epoch} due to high KL divergence: {avg_kl:.6f}")
                break

        # Clear buffer
        self.states.clear()
        self.actions.clear()
        self.rewards.clear()
        self.values.clear()
        self.log_probs.clear()
        self.dones.clear()

        return {
            'actor_loss': np.mean(actor_losses),
            'critic_loss': np.mean(critic_losses),
            'kl_div': np.mean(kl_divs),
            'entropy': np.mean(entropy_values),
            'epochs_completed': epoch + 1
        }

    def save_agent(self, save_dir: str):
        """Save agent models"""
        os.makedirs(save_dir, exist_ok=True)
        torch.save(self.actor.state_dict(), os.path.join(save_dir, 'actor.pth'))
        torch.save(self.critic.state_dict(), os.path.join(save_dir, 'critic.pth'))

        # Save training stats
        stats = {
            'total_steps': self.total_steps,
            'episode_rewards': self.episode_rewards,
            'episode_lengths': self.episode_lengths
        }
        with open(os.path.join(save_dir, 'training_stats.json'), 'w') as f:
            json.dump(stats, f)

    def save_or_load_agent(self, cwd: str, if_save: bool):
        """Save or load agent models - compatibility method for evaluation"""
        if if_save:
            self.save_agent(cwd)
        else:
            return self.load_agent(cwd)

    def load_agent(self, load_dir: str):
        """Load agent models"""
        actor_path = os.path.join(load_dir, 'actor.pth')
        critic_path = os.path.join(load_dir, 'critic.pth')

        if os.path.exists(actor_path) and os.path.exists(critic_path):
            self.actor.load_state_dict(torch.load(actor_path, map_location=self.device))
            self.critic.load_state_dict(torch.load(critic_path, map_location=self.device))
            print(f"Loaded PPO agent from {load_dir}")
            return True
        else:
            print(f"Model files not found in {load_dir}")
            return False

# ==================== IMPROVED TRAINING FUNCTION ====================

def train_improved_ppo_agent(timeframe: str = '1sec') -> ImprovedPPOTrader:
    """Train an improved PPO agent for the specified timeframe"""
    # Check CUDA status first
    cuda_available = check_cuda()

    try:
        if cuda_available and torch.cuda.is_available():
            device = torch.device("cuda:0")
            gpu_id = 0
            print(f"CUDA available, using GPU: {device}")
        else:
            device = torch.device("cpu")
            gpu_id = -1
            print(f"CUDA not available, using CPU: {device}")

        # Create environment
        env = TradeSimulator(
            num_sims=NUM_SIMS,
            slippage=SLIPPAGE,
            max_position=MAX_POSITION,
            step_gap=STEP_GAP,
            gpu_id=gpu_id,
            timeframe=timeframe
        )

    except Exception as e:
        print(f"Error creating environment: {e}")
        print("Trying with CPU fallback...")

        device = torch.device("cpu")
        gpu_id = -1

        env = TradeSimulator(
            num_sims=NUM_SIMS,
            slippage=SLIPPAGE,
            max_position=MAX_POSITION,
            step_gap=STEP_GAP,
            gpu_id=gpu_id,
            timeframe=timeframe
        )

    print(f"Environment ready: {env.full_seq_len} steps available")
    print(f"Environment info: state_dim={env.state_dim}, action_dim={env.action_dim}")

    # Create agent
    state_dim = env.state_dim
    action_dim = env.action_dim

    agent = ImprovedPPOTrader(state_dim, action_dim, NET_DIMS, device=str(device))
    print(f"Improved PPO agent created successfully on {device}")

    initial_state = env.reset()
    print(f"Environment initialized, state shape: {initial_state.shape}")

    # Training loop
    episode_reward = 0
    episode_length = 0
    update_count = 0

    print(f"Starting training for {TOTAL_STEPS} steps...")

    for step in range(TOTAL_STEPS):
        # Get current state (first simulation)
        state = env.get_state(env.step_is)
        state_single = state[0:1]  # Take first simulation for single agent training

        # Select action
        action, log_prob, value = agent.select_action(state_single, training=True)

        # Convert action from [0,1,2] to [-1,0,1] for environment (SHORT, HOLD, LONG)
        action_env = (action - 1).expand(env.num_sims)  # Convert to environment action space

        # Execute action
        next_state, reward, terminal, info = env.step(action_env)

        #Store transition with proper reward scaling and shaping
        base_reward = reward[0].item() * REWARD_SCALE

        #Reward shaping to encourage trading
        current_position = env.position[0].item()
        prev_position = getattr(env, '_prev_position', 0)
        position_change = abs(current_position - prev_position)
        trading_bonus = 0.001 * position_change  # Small bonus for taking positions

        #Profit incentive
        profit_incentive = 0.01 * base_reward if base_reward > 0 else 0

        reward_single = base_reward + trading_bonus + profit_incentive
        done_single = terminal[0].item()
        agent.store_transition(state_single, action, reward_single, value, log_prob, done_single)

        # Store previous position for next step
        env._prev_position = env.position[0].item()

        #Enhanced debugging for asset tracking
        if step % 1000 == 0:  # Debug every 1000 steps
            current_price = env.price_ary[env.step_is[0] + env.step_i, 2].item()
            print(f"🔍 Debug: Step {step} - Asset=${env.asset[0].item():.2f}, "
                  f"Cash=${env.cash[0].item():.2f}, "
                  f"Position={env.position[0].item()}, "
                  f"Price=${current_price:.2f}, "
                  f"Reward={reward_single:.6f}")

        # Update episode stats
        episode_reward += reward_single
        episode_length += 1

        # Update policy when buffer is full
        if len(agent.states) >= HORIZON_LEN:
            update_stats = agent.update_policy()
            update_count += 1

            # Learning rate scheduling for longer training
            agent.scheduler.step()

            # Better logging frequency
            if update_count % 50 == 0:
                print(f"Step {step}: Actor Loss: {update_stats.get('actor_loss', 0):.6f}, "
                      f"Critic Loss: {update_stats.get('critic_loss', 0):.6f}, "
                      f"KL Div: {update_stats.get('kl_div', 0):.6f}, "
                      f"Entropy: {update_stats.get('entropy', 0):.6f}")

        # Reset episode if done
        if done_single:
            agent.episode_rewards.append(episode_reward)
            agent.episode_lengths.append(episode_length)

            # Enhanced episode logging with asset tracking
            final_asset = env.asset[0].item()
            final_cash = env.cash[0].item()
            if len(agent.episode_rewards) % 20 == 0:
                avg_reward = np.mean(agent.episode_rewards[-20:])
                avg_length = np.mean(agent.episode_lengths[-20:])
                print(f"Episode {len(agent.episode_rewards)}: Avg Reward: {avg_reward:.6f}, Avg Length: {avg_length:.1f}, "
                      f"Final Asset=${final_asset:.2f}, Final Cash=${final_cash:.2f}")

            episode_reward = 0
            episode_length = 0
            env.reset()

        # Save agent periodically
        if step % SAVE_GAP == 0 and step > 0:
            save_dir = f"./trained_agents/{PPO_VERSION}/{timeframe}/PPO"
            agent.save_agent(save_dir)
            print(f"Saved agent at step {step}")

        # Update total steps
        agent.total_steps = step

    # Final save
    save_dir = f"./trained_agents/{PPO_VERSION}/{timeframe}/PPO"
    agent.save_agent(save_dir)
    print(f"Training completed! Agent saved to {save_dir}")

    return agent

# ==================== TRADING ENVIRONMENT ====================

class TradeSimulator:
    def __init__(self, num_sims=32, slippage=5e-5, max_position=1, step_gap=1,
                 delay_step=1, num_ignore_step=60, device=torch.device("cpu"), gpu_id=-1, timeframe='1sec'):
        self.device = torch.device(f"cuda:{gpu_id}") if gpu_id >= 0 else device
        self.num_sims = num_sims
        self.slippage = slippage
        self.delay_step = delay_step
        self.max_holding = 60 * 60 // step_gap
        self.max_position = max_position
        self.step_gap = step_gap
        self.sim_ids = torch.arange(self.num_sims, device=self.device)
        self.timeframe = timeframe

        self.load_data()

        self.env_name = "TradeSimulator-v0"
        self.state_dim = 2 + 8 + 2
        self.action_dim = 3
        self.if_discrete = True
        self.max_step = (self.seq_len - num_ignore_step) // step_gap
        self.target_return = +np.inf

        self.best_price = torch.zeros((num_sims,), dtype=torch.float32, device=device)
        self.stop_loss_thresh = 1e-3

    def load_data(self):
        # Load training predictions with multiple fallback options
        possible_paths = [
            f"output/{self.timeframe}/train_predictions.npy",
            f"output/{self.timeframe}/predictions.npy",
            f"../output/{self.timeframe}/train_predictions.npy",
            f"../output/{self.timeframe}/predictions.npy"
        ]

        factor_path = None
        for path in possible_paths:
            if os.path.exists(path):
                factor_path = path
                print(f"Found predictions at: {path}")
                break

        if factor_path is None:
            # Quit training if no predictions found
            print("Error: No prediction files found in any of the expected locations:")
            for path in possible_paths:
                print(f"   - {path}")
            print("Please ensure the prediction files exist before running training.")
            raise FileNotFoundError("Required prediction files not found. Cannot proceed with training.")

        self.factor_ary = np.load(factor_path)
        self.factor_ary = torch.tensor(self.factor_ary, dtype=torch.float32)

        if self.factor_ary.shape[0] == 0:
            raise ValueError(f"Alpha101 factors are empty for {self.timeframe}.")

        # Try multiple paths for price data
        possible_csv_paths = [
            f"data/{self.timeframe}/BTC_{self.timeframe}_with_sentiment_risk_train_{self.timeframe}_train_70.csv",
            f"../data/{self.timeframe}/BTC_{self.timeframe}_with_sentiment_risk_train_{self.timeframe}_train_70.csv",
            f"data/{self.timeframe}/BTC_{self.timeframe}_with_sentiment_risk_train.csv",
            f"../data/{self.timeframe}/BTC_{self.timeframe}_with_sentiment_risk_train.csv"
        ]

        csv_path = None
        for path in possible_csv_paths:
            if os.path.exists(path):
                csv_path = path
                print(f"Found price data at: {path}")
                break

        if csv_path is None:
            # Quit training if no price data found
            print("Error: No price data files found in any of the expected locations:")
            for path in possible_csv_paths:
                print(f"   - {path}")
            print("Please ensure the price data files exist before running training.")
            raise FileNotFoundError("Required price data files not found. Cannot proceed with training.")
        try:
            data_df = pd.read_csv(csv_path, engine='python')
        except Exception:
            data_df = pd.read_csv(csv_path)

        required_columns = ["bids_distance_3", "asks_distance_3", "midpoint", "sentiment_score", "risk_score"]
        missing_columns = [col for col in required_columns if col not in data_df.columns]
        if missing_columns:
            raise ValueError(f"Missing required columns: {missing_columns}.")

        self.price_ary = data_df[["bids_distance_3", "asks_distance_3", "midpoint"]].values
        self.price_ary[:, 0] = self.price_ary[:, 2] * (1 + self.price_ary[:, 0])
        self.price_ary[:, 1] = self.price_ary[:, 2] * (1 + self.price_ary[:, 0])
        self.llm_signals = data_df[["sentiment_score", "risk_score"]].values

        min_len = min(self.factor_ary.shape[0], self.price_ary.shape[0], self.llm_signals.shape[0])
        self.factor_ary = self.factor_ary[:min_len]
        self.price_ary = torch.tensor(self.price_ary[:min_len], dtype=torch.float32)
        self.llm_signals = torch.tensor(self.llm_signals[:min_len], dtype=torch.float32)

        if NORMALIZE_LLM_SIGNALS:
            llm_min = self.llm_signals.amin(dim=0, keepdim=True)
            llm_max = self.llm_signals.amax(dim=0, keepdim=True)
            llm_range = (llm_max - llm_min)
            self.llm_signals = (self.llm_signals - llm_min) / (llm_range + 1e-6)
            self.llm_signals = torch.clamp(self.llm_signals, 0.0, 1.0)

        if self.timeframe == '1sec':
            self.seq_len = 1800
        elif self.timeframe == '1min':
            self.seq_len = 64
        elif self.timeframe == '5min':
            self.seq_len = 16
        else:
            self.seq_len = 1800

        self.full_seq_len = self.price_ary.shape[0]

    def reset(self, slippage=None):
        self.slippage = slippage if isinstance(slippage, float) else self.slippage

        min_start = self.seq_len
        max_start = self.full_seq_len - self.seq_len * 2
        if min_start >= max_start:
            if self.full_seq_len > self.seq_len:
                max_start = self.full_seq_len - self.seq_len
                min_start = 0
                i0s = np.random.randint(min_start, max_start, size=self.num_sims)
            else:
                if self.full_seq_len > 0:
                    i0s = np.arange(min(self.num_sims, self.full_seq_len))
                    if len(i0s) < self.num_sims:
                        i0s = np.pad(i0s, (0, self.num_sims - len(i0s)), mode='constant', constant_values=0)
                else:
                    i0s = np.zeros(self.num_sims, dtype=np.int64)
        else:
            i0s = np.random.randint(min_start, max_start, size=self.num_sims)

        self.step_i = 0
        self.step_is = torch.tensor(i0s, dtype=torch.long, device=self.device)

        # Initialize with starting cash instead of zero
        starting_cash = 1000000.0  # $1M starting capital
        self.cash = torch.full((self.num_sims,), starting_cash, dtype=torch.float32, device=self.device)
        self.asset = torch.full((self.num_sims,), starting_cash, dtype=torch.float32, device=self.device)

        # Debug logging for asset initialization
        print(f"Debug: Environment reset - Cash: {self.cash[0].item():.2f}, Asset: {self.asset[0].item():.2f}")
        self.holding = torch.zeros((self.num_sims,), dtype=torch.long, device=self.device)
        self.position = torch.zeros((self.num_sims,), dtype=torch.long, device=self.device)
        self.empty_count = torch.zeros((self.num_sims,), dtype=torch.long, device=self.device)
        self.best_price = torch.zeros((self.num_sims,), dtype=torch.float32, device=self.device)

        step_is = self.step_is + self.step_i
        state = self.get_state(step_is)
        return state

    def step(self, action):
        try:
            if not hasattr(self, 'step_i'):
                self.step_i = 0
            self.step_i += self.step_gap
            step_is = self.step_is + self.step_i

            if action.dim() == 1:
                action = action.to(self.device)
            else:
                action = action.squeeze().to(self.device)
            action_int = action - 1

            old_cash = self.cash
            old_asset = self.asset
            old_position = self.position

            step_is_cpu = step_is.cpu()
            max_idx = self.price_ary.shape[0] - 1
            step_is_cpu = torch.clamp(step_is_cpu, 0, max_idx)
            mid_price = self.price_ary[step_is_cpu, 2].to(self.device)

            truncated = self.step_i >= (self.max_step * self.step_gap)
            if truncated:
                action_int = -old_position
            else:
                new_position = (old_position + action_int).clip(-self.max_position, self.max_position)
                action_int = new_position - old_position

            self.holding = self.holding + 1
            mask_max_holding = self.holding.gt(self.max_holding)
            if mask_max_holding.sum() > 0:
                action_int[mask_max_holding] = -old_position[mask_max_holding]
            self.holding[old_position == 0] = 0

            direction_mask1 = old_position.gt(0)
            if direction_mask1.sum() > 0:
                _best_price = torch.max(
                    torch.stack([self.best_price[direction_mask1], mid_price[direction_mask1]]),
                    dim=0,
                )[0]
                self.best_price[direction_mask1] = _best_price

            direction_mask2 = old_position.lt(0)
            if direction_mask2.sum() > 0:
                _best_price = torch.min(
                    torch.stack([self.best_price[direction_mask2], mid_price[direction_mask2]]),
                    dim=0,
                )[0]
                self.best_price[direction_mask2] = _best_price

            stop_loss_mask1 = torch.logical_and(direction_mask1, (self.best_price - mid_price).gt(self.stop_loss_thresh))
            stop_loss_mask2 = torch.logical_and(direction_mask2, (mid_price - self.best_price).gt(self.stop_loss_thresh))
            stop_loss_mask = torch.logical_or(stop_loss_mask1, stop_loss_mask2)
            if stop_loss_mask.sum() > 0:
                action_int[stop_loss_mask] = -old_position[stop_loss_mask]

            new_position = old_position + action_int
            direction = action_int.gt(0)
            cost = action_int * mid_price
            new_cash = old_cash - cost * torch.where(direction, 1 + self.slippage, 1 - self.slippage)
            new_asset = new_cash + new_position * mid_price
            reward = new_asset - old_asset

            # Debug logging for asset changes
            if self.step_i % 100 == 0:  # Debug every 100 steps
                print(f"Debug: Step {self.step_i} - Old Asset: {old_asset[0].item():.2f}, "
                      f"New Asset: {new_asset[0].item():.2f}, Reward: {reward[0].item():.6f}")

            self.cash = new_cash
            self.asset = new_asset
            self.position = new_position

            state = self.get_state(step_is)
            if truncated:
                terminal = torch.ones_like(self.position, dtype=torch.bool)
                state = self.reset()
            else:
                terminal = torch.zeros_like(self.position, dtype=torch.bool)

            return state, reward, terminal, {}

        except Exception as e:
            print(f"Error in environment step: {e}")
            state = torch.zeros((self.num_sims, self.state_dim), dtype=torch.float32).to(self.device)
            reward = torch.zeros((self.num_sims,), dtype=torch.float32).to(self.device)
            terminal = torch.zeros((self.num_sims,), dtype=torch.bool).to(self.device)
            return state, reward, terminal, {}

    def get_state(self, step_is):
        step_is_cpu = step_is.cpu()
        max_idx = min(self.factor_ary.shape[0], self.price_ary.shape[0], self.llm_signals.shape[0]) - 1
        step_is_cpu = torch.clamp(step_is_cpu, 0, max_idx)
        factor_ary = self.factor_ary[step_is_cpu, :].to(self.device)
        llm_signals = self.llm_signals[step_is_cpu, :].to(self.device)
        return torch.concat(
            (
                (self.position.float() / self.max_position)[:, None],
                (self.holding.float() / self.max_holding)[:, None],
                factor_ary,
                llm_signals,
            ),
            dim=1,
        )

# %%
agent = train_improved_ppo_agent('1sec')
# Out:
# Streaming output truncated to the last 5000 lines.
# 🔍 Debug: Step 100 - Old Asset: 999987.00, New Asset: 999986.94, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 999979.94, New Asset: 999979.94, Reward: 0.000000
# 🔍 Debug: Step 300 - Old Asset: 999977.94, New Asset: 999977.94, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 999945.50, New Asset: 999945.50, Reward: 0.000000
# 🔍 Debug: Step 1782000 - Asset=$999955.00, Cash=$1058426.00, Position=-1, Price=$58471.02, Reward=0.001000
# 🔍 Debug: Step 500 - Old Asset: 999953.69, New Asset: 999953.62, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 999926.94, New Asset: 999926.88, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 999951.00, New Asset: 999951.00, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 999905.19, New Asset: 999905.19, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 999908.44, New Asset: 999908.38, Reward: -0.062500
# 🔍 Debug: Step 1000 - Old Asset: 999878.56, New Asset: 999878.50, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 999860.50, New Asset: 999860.44, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 999891.19, New Asset: 999891.19, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 999924.12, New Asset: 999908.81, Reward: -15.312500
# 🔍 Debug: Step 1400 - Old Asset: 999905.31, New Asset: 999905.31, Reward: 0.000000
# 🔍 Debug: Step 1500 - Old Asset: 999895.25, New Asset: 999895.25, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 999893.50, New Asset: 999893.44, Reward: -0.062500
# 🔍 Debug: Step 1700 - Old Asset: 999890.69, New Asset: 999890.69, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000010.31, New Asset: 1000010.31, Reward: 0.000000
# 🔍 Debug: Step 200 - Old Asset: 1000003.69, New Asset: 1000003.62, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 1000027.19, New Asset: 1000027.19, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 1000035.62, New Asset: 1000035.56, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 1000050.12, New Asset: 1000050.00, Reward: -0.125000
# 🔍 Debug: Step 600 - Old Asset: 1000027.81, New Asset: 1000027.81, Reward: 0.000000
# 🔍 Debug: Step 700 - Old Asset: 1000027.00, New Asset: 1000026.94, Reward: -0.062500
# 🔍 Debug: Step 1783000 - Asset=$1000038.38, Cash=$1057958.62, Position=-1, Price=$57920.25, Reward=-0.005250
# 🔍 Debug: Step 800 - Old Asset: 1000029.62, New Asset: 1000035.12, Reward: 5.500000
# 🔍 Debug: Step 900 - Old Asset: 1000068.12, New Asset: 1000068.12, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 1000047.75, New Asset: 1000047.69, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 1000059.50, New Asset: 1000059.44, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 1000098.06, New Asset: 1000098.00, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 1000088.75, New Asset: 1000088.69, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 1000065.00, New Asset: 1000064.94, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 1000060.88, New Asset: 1000060.88, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 1000048.50, New Asset: 1000048.44, Reward: -0.062500
# 🔍 Debug: Step 1700 - Old Asset: 1000031.75, New Asset: 1000031.75, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000004.69, New Asset: 1000004.62, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 1000005.88, New Asset: 1000005.81, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 1000007.50, New Asset: 1000007.50, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 1000006.19, New Asset: 1000006.12, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 1000013.38, New Asset: 1000013.38, Reward: 0.000000
# 🔍 Debug: Step 600 - Old Asset: 999994.31, New Asset: 999992.81, Reward: -1.500000
# 🔍 Debug: Step 700 - Old Asset: 1000003.75, New Asset: 1000003.75, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 1000017.75, New Asset: 1000017.69, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 999958.56, New Asset: 999958.50, Reward: -0.062500
# 🔍 Debug: Step 1000 - Old Asset: 999967.94, New Asset: 999967.88, Reward: -0.062500
# 🔍 Debug: Step 1784000 - Asset=$999967.81, Cash=$999967.81, Position=0, Price=$59751.00, Reward=-0.005250
# 🔍 Debug: Step 1100 - Old Asset: 999957.62, New Asset: 999957.62, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 999929.06, New Asset: 999929.00, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 999943.62, New Asset: 999943.62, Reward: 0.000000
# 🔍 Debug: Step 1400 - Old Asset: 999969.38, New Asset: 999969.31, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999970.50, New Asset: 999970.50, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 999903.00, New Asset: 999902.94, Reward: -0.062500
# 🔍 Debug: Step 1700 - Old Asset: 999909.12, New Asset: 999909.06, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000020.06, New Asset: 1000020.06, Reward: 0.000000
# 🔍 Debug: Step 200 - Old Asset: 1000016.31, New Asset: 1000016.31, Reward: 0.000000
# 🔍 Debug: Step 300 - Old Asset: 999950.25, New Asset: 999950.25, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 999997.50, New Asset: 999997.50, Reward: 0.000000
# 🔍 Debug: Step 500 - Old Asset: 1000001.94, New Asset: 1000001.88, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 999999.75, New Asset: 999999.69, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 1000029.56, New Asset: 1000029.50, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 1000026.94, New Asset: 1000026.94, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 1000036.81, New Asset: 1000036.75, Reward: -0.062500
# 🔍 Debug: Step 1000 - Old Asset: 1000056.81, New Asset: 1000060.69, Reward: 3.875000
# 🔍 Debug: Step 1100 - Old Asset: 1000006.75, New Asset: 1000006.75, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 999982.19, New Asset: 999982.12, Reward: -0.062500
# 🔍 Debug: Step 1785000 - Asset=$1000014.38, Cash=$1057938.38, Position=-1, Price=$57923.98, Reward=0.001000
# 🔍 Debug: Step 1300 - Old Asset: 1000008.69, New Asset: 1000008.56, Reward: -0.125000
# 🔍 Debug: Step 1400 - Old Asset: 999945.50, New Asset: 999945.44, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999985.88, New Asset: 999985.88, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 1000012.31, New Asset: 1000012.31, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 1000058.88, New Asset: 1000058.88, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999982.25, New Asset: 999982.19, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 999979.62, New Asset: 999987.62, Reward: 8.000000
# 🔍 Debug: Step 300 - Old Asset: 999968.50, New Asset: 999968.50, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 999946.12, New Asset: 999946.06, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 999942.31, New Asset: 999942.19, Reward: -0.125000
# 🔍 Debug: Step 600 - Old Asset: 999957.06, New Asset: 999957.00, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 999942.50, New Asset: 999942.38, Reward: -0.125000
# 🔍 Debug: Step 800 - Old Asset: 999951.00, New Asset: 999950.88, Reward: -0.125000
# 🔍 Debug: Step 900 - Old Asset: 999966.06, New Asset: 999966.06, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 999965.19, New Asset: 999970.69, Reward: 5.500000
# 🔍 Debug: Step 1100 - Old Asset: 999967.06, New Asset: 999967.06, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 999948.88, New Asset: 999948.88, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 999911.38, New Asset: 999911.38, Reward: 0.000000
# 🔍 Debug: Step 1400 - Old Asset: 999887.06, New Asset: 999887.06, Reward: 0.000000
# 🔍 Debug: Step 1500 - Old Asset: 999867.31, New Asset: 999867.25, Reward: -0.062500
# 🔍 Debug: Step 1786000 - Asset=$999869.62, Cash=$1058014.50, Position=-1, Price=$58144.89, Reward=-0.005250
# 🔍 Debug: Step 1600 - Old Asset: 999870.75, New Asset: 999870.69, Reward: -0.062500
# 🔍 Debug: Step 1700 - Old Asset: 999858.94, New Asset: 999858.88, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999991.94, New Asset: 999991.94, Reward: 0.000000
# 🔍 Debug: Step 200 - Old Asset: 999994.06, New Asset: 999994.06, Reward: 0.000000
# 🔍 Debug: Step 300 - Old Asset: 1000008.94, New Asset: 1000008.94, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 999994.31, New Asset: 999994.25, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 999974.62, New Asset: 999974.62, Reward: 0.000000
# 🔍 Debug: Step 600 - Old Asset: 999927.12, New Asset: 999927.06, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 999921.62, New Asset: 999921.56, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 999897.50, New Asset: 999897.44, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 999880.06, New Asset: 999880.00, Reward: -0.062500
# 🔍 Debug: Step 1000 - Old Asset: 999809.31, New Asset: 999809.25, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 999834.62, New Asset: 999834.56, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 999809.56, New Asset: 999809.50, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 999836.81, New Asset: 999836.75, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 999848.12, New Asset: 999848.06, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999847.31, New Asset: 999847.31, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 999826.19, New Asset: 999826.19, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 999828.50, New Asset: 999828.44, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 1787000 - Asset=$1000006.88, Cash=$1000006.88, Position=0, Price=$58416.57, Reward=0.000000
# 🔍 Debug: Step 100 - Old Asset: 1000020.19, New Asset: 1000020.12, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 1000014.00, New Asset: 1000013.94, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 999990.75, New Asset: 999990.25, Reward: -0.500000
# 🔍 Debug: Step 400 - Old Asset: 999990.88, New Asset: 999990.88, Reward: 0.000000
# 🔍 Debug: Step 500 - Old Asset: 999980.06, New Asset: 999980.06, Reward: 0.000000
# 🔍 Debug: Step 600 - Old Asset: 999973.31, New Asset: 999973.25, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 999968.94, New Asset: 999968.88, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 999962.56, New Asset: 999962.56, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 999943.69, New Asset: 999943.69, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 999879.62, New Asset: 999879.56, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 999824.38, New Asset: 999824.31, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 999760.69, New Asset: 999760.69, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 999721.06, New Asset: 999721.06, Reward: 0.000000
# 🔍 Debug: Step 1400 - Old Asset: 999726.12, New Asset: 999726.06, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999768.75, New Asset: 999768.75, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 999745.69, New Asset: 999742.56, Reward: -3.125000
# 🔍 Debug: Step 1700 - Old Asset: 999812.19, New Asset: 999812.19, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999975.56, New Asset: 999975.50, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 999988.62, New Asset: 999988.62, Reward: 0.000000
# 🔍 Debug: Step 300 - Old Asset: 999963.38, New Asset: 999963.31, Reward: -0.062500
# 🔍 Debug: Step 1788000 - Asset=$999980.31, Cash=$999980.31, Position=0, Price=$60649.39, Reward=1.718000
# 🔍 Debug: Step 400 - Old Asset: 999979.19, New Asset: 999979.12, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 999982.56, New Asset: 999982.44, Reward: -0.125000
# 🔍 Debug: Step 600 - Old Asset: 999995.50, New Asset: 999995.50, Reward: 0.000000
# 🔍 Debug: Step 700 - Old Asset: 1000034.19, New Asset: 1000034.19, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 1000034.00, New Asset: 1000034.00, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 1000100.19, New Asset: 1000100.12, Reward: -0.062500
# 🔍 Debug: Step 1000 - Old Asset: 1000108.06, New Asset: 1000108.06, Reward: 0.000000
# 🔍 Debug: Step 1100 - Old Asset: 1000099.94, New Asset: 1000099.94, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 1000068.62, New Asset: 1000056.81, Reward: -11.812500
# 🔍 Debug: Step 1300 - Old Asset: 1000082.06, New Asset: 1000095.19, Reward: 13.125000
# 🔍 Debug: Step 1400 - Old Asset: 1000080.44, New Asset: 1000080.44, Reward: 0.000000
# 🔍 Debug: Step 1500 - Old Asset: 1000057.19, New Asset: 1000054.44, Reward: -2.750000
# 🔍 Debug: Step 1600 - Old Asset: 1000035.00, New Asset: 1000034.94, Reward: -0.062500
# 🔍 Debug: Step 1700 - Old Asset: 1000062.94, New Asset: 1000062.94, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999965.56, New Asset: 999965.50, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 999948.62, New Asset: 999948.50, Reward: -0.125000
# 🔍 Debug: Step 300 - Old Asset: 999907.81, New Asset: 999907.69, Reward: -0.125000
# 🔍 Debug: Step 400 - Old Asset: 999853.19, New Asset: 999841.00, Reward: -12.187500
# 🔍 Debug: Step 500 - Old Asset: 999845.94, New Asset: 999845.94, Reward: 0.000000
# 🔍 Debug: Step 1789000 - Asset=$999815.31, Cash=$1060011.12, Position=-1, Price=$60195.80, Reward=0.001000
# 🔍 Debug: Step 600 - Old Asset: 999815.06, New Asset: 999815.00, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 999794.56, New Asset: 999789.69, Reward: -4.875000
# 🔍 Debug: Step 800 - Old Asset: 999823.19, New Asset: 999823.19, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 999812.38, New Asset: 999812.31, Reward: -0.062500
# 🔍 Debug: Step 1000 - Old Asset: 999760.06, New Asset: 999760.06, Reward: 0.000000
# 🔍 Debug: Step 1100 - Old Asset: 999837.12, New Asset: 999837.06, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 999768.44, New Asset: 999768.44, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 999760.31, New Asset: 999736.31, Reward: -24.000000
# 🔍 Debug: Step 1400 - Old Asset: 999709.19, New Asset: 999695.75, Reward: -13.437500
# 🔍 Debug: Step 1500 - Old Asset: 999726.06, New Asset: 999726.06, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 999773.25, New Asset: 999773.19, Reward: -0.062500
# 🔍 Debug: Step 1700 - Old Asset: 999758.06, New Asset: 999758.00, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999997.88, New Asset: 999997.75, Reward: -0.125000
# 🔍 Debug: Step 200 - Old Asset: 1000006.56, New Asset: 1000006.50, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 1000024.62, New Asset: 1000024.62, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 1000008.12, New Asset: 1000008.12, Reward: 0.000000
# 🔍 Debug: Step 500 - Old Asset: 1000031.50, New Asset: 1000031.44, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 1000058.38, New Asset: 1000041.88, Reward: -16.500000
# 🔍 Debug: Step 700 - Old Asset: 1000024.12, New Asset: 1000024.06, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 1000042.44, New Asset: 1000042.44, Reward: 0.000000
# 🔍 Debug: Step 1790000 - Asset=$1000043.75, Cash=$1000043.75, Position=0, Price=$58491.84, Reward=-0.267750
# 🔍 Debug: Step 900 - Old Asset: 1000039.62, New Asset: 1000029.69, Reward: -9.937500
# 🔍 Debug: Step 1000 - Old Asset: 1000071.56, New Asset: 1000071.50, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 1000024.31, New Asset: 1000024.25, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 1000025.94, New Asset: 1000025.88, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 1000060.94, New Asset: 1000045.62, Reward: -15.312500
# 🔍 Debug: Step 1400 - Old Asset: 1000028.88, New Asset: 1000016.25, Reward: -12.625000
# 🔍 Debug: Step 1500 - Old Asset: 1000050.81, New Asset: 1000050.75, Reward: -0.062500
# 🔍 Debug: Step 1600 - Old Asset: 1000057.50, New Asset: 1000057.50, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 1000058.88, New Asset: 1000058.81, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999959.31, New Asset: 999959.25, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 999919.81, New Asset: 999918.56, Reward: -1.250000
# 🔍 Debug: Step 300 - Old Asset: 999837.94, New Asset: 999837.88, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 999783.69, New Asset: 999783.69, Reward: 0.000000
# 🔍 Debug: Step 500 - Old Asset: 999795.19, New Asset: 999795.19, Reward: 0.000000
# 🔍 Debug: Step 600 - Old Asset: 999862.12, New Asset: 999862.06, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 999831.75, New Asset: 999831.75, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 999812.25, New Asset: 999812.19, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 999802.38, New Asset: 999802.38, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 999753.88, New Asset: 999754.44, Reward: 0.562500
# 🔍 Debug: Step 1791000 - Asset=$999738.00, Cash=$999738.00, Position=0, Price=$60056.43, Reward=-0.005250
# 🔍 Debug: Step 1100 - Old Asset: 999695.12, New Asset: 999695.06, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 999731.00, New Asset: 999730.94, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 999672.69, New Asset: 999672.62, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 999660.88, New Asset: 999660.81, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999631.75, New Asset: 999636.81, Reward: 5.062500
# 🔍 Debug: Step 1600 - Old Asset: 999590.19, New Asset: 999590.19, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 999611.31, New Asset: 999611.31, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000000.12, New Asset: 1000000.12, Reward: 0.000000
# 🔍 Debug: Step 200 - Old Asset: 1000048.81, New Asset: 1000048.75, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 999979.38, New Asset: 999979.38, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 999945.12, New Asset: 999938.06, Reward: -7.062500
# 🔍 Debug: Step 500 - Old Asset: 999877.75, New Asset: 999877.75, Reward: 0.000000
# 🔍 Debug: Step 600 - Old Asset: 999909.00, New Asset: 999869.88, Reward: -39.125000
# 🔍 Debug: Step 700 - Old Asset: 999884.38, New Asset: 999884.31, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 999854.38, New Asset: 999841.62, Reward: -12.750000
# 🔍 Debug: Step 900 - Old Asset: 999857.25, New Asset: 999857.25, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 999847.88, New Asset: 999847.81, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 999846.19, New Asset: 999846.12, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 999879.06, New Asset: 999879.06, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 999908.75, New Asset: 999908.75, Reward: 0.000000
# 🔍 Debug: Step 1792000 - Asset=$999895.25, Cash=$999895.25, Position=0, Price=$56147.68, Reward=0.000000
# 🔍 Debug: Step 1400 - Old Asset: 999890.56, New Asset: 999890.50, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999896.94, New Asset: 999896.94, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 999915.44, New Asset: 999919.00, Reward: 3.562500
# 🔍 Debug: Step 1700 - Old Asset: 999944.44, New Asset: 999944.44, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# Episode 2060: Avg Reward: -7.765384, Avg Length: 870.0, Final Asset=$1000000.00, Final Cash=$1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000029.81, New Asset: 1000030.31, Reward: 0.500000
# 🔍 Debug: Step 200 - Old Asset: 1000039.50, New Asset: 1000039.38, Reward: -0.125000
# 🔍 Debug: Step 300 - Old Asset: 1000002.00, New Asset: 1000002.00, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 1000032.50, New Asset: 1000032.50, Reward: 0.000000
# 🔍 Debug: Step 500 - Old Asset: 1000033.38, New Asset: 1000033.38, Reward: 0.000000
# 🔍 Debug: Step 600 - Old Asset: 1000035.69, New Asset: 1000035.62, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 1000028.31, New Asset: 1000028.25, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 1000043.38, New Asset: 1000043.38, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 1000029.75, New Asset: 1000029.69, Reward: -0.062500
# 🔍 Debug: Step 1000 - Old Asset: 1000059.06, New Asset: 1000059.00, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 1000077.94, New Asset: 1000077.94, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 1000072.69, New Asset: 1000072.62, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 1000082.56, New Asset: 1000082.56, Reward: 0.000000
# 🔍 Debug: Step 1400 - Old Asset: 1000054.56, New Asset: 1000054.50, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 1000056.94, New Asset: 1000056.94, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 1000069.19, New Asset: 1000069.19, Reward: 0.000000
# 🔍 Debug: Step 1793000 - Asset=$1000069.12, Cash=$1057969.12, Position=-1, Price=$57900.00, Reward=-0.005250
# 🔍 Debug: Step 1700 - Old Asset: 1000144.56, New Asset: 1000144.56, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000006.19, New Asset: 999987.31, Reward: -18.875000
# 🔍 Debug: Step 200 - Old Asset: 999966.88, New Asset: 999966.88, Reward: 0.000000
# 🔍 Debug: Step 300 - Old Asset: 999933.69, New Asset: 999933.69, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 999880.69, New Asset: 999880.69, Reward: 0.000000
# 🔍 Debug: Step 500 - Old Asset: 999892.56, New Asset: 999880.88, Reward: -11.687500
# 🔍 Debug: Step 600 - Old Asset: 999878.75, New Asset: 999878.69, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 999894.94, New Asset: 999894.88, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 999903.81, New Asset: 999903.75, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 999902.69, New Asset: 999899.31, Reward: -3.375000
# 🔍 Debug: Step 1000 - Old Asset: 999823.62, New Asset: 999823.62, Reward: 0.000000
# 🔍 Debug: Step 1100 - Old Asset: 999816.38, New Asset: 999816.38, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 999816.38, New Asset: 999816.38, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 999833.00, New Asset: 999832.94, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 999804.88, New Asset: 999804.81, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999744.38, New Asset: 999736.31, Reward: -8.062500
# 🔍 Debug: Step 1600 - Old Asset: 999711.81, New Asset: 999711.81, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 999716.12, New Asset: 999716.06, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999966.75, New Asset: 999966.62, Reward: -0.125000
# 🔍 Debug: Step 1794000 - Asset=$1000037.12, Cash=$1060028.75, Position=-1, Price=$59991.61, Reward=-0.005250
# 🔍 Debug: Step 200 - Old Asset: 1000039.12, New Asset: 1000039.06, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 1000018.12, New Asset: 1000018.06, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 999978.00, New Asset: 999977.88, Reward: -0.125000
# 🔍 Debug: Step 500 - Old Asset: 1000013.56, New Asset: 1000009.94, Reward: -3.625000
# 🔍 Debug: Step 600 - Old Asset: 1000002.19, New Asset: 1000005.38, Reward: 3.187500
# 🔍 Debug: Step 700 - Old Asset: 1000012.81, New Asset: 1000012.81, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 1000075.12, New Asset: 1000075.12, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 1000011.19, New Asset: 1000011.12, Reward: -0.062500
# 🔍 Debug: Step 1000 - Old Asset: 999992.31, New Asset: 999992.25, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 999997.06, New Asset: 1000013.69, Reward: 16.625000
# 🔍 Debug: Step 1200 - Old Asset: 1000006.88, New Asset: 1000006.81, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 999988.62, New Asset: 999986.69, Reward: -1.937500
# 🔍 Debug: Step 1400 - Old Asset: 999978.62, New Asset: 999978.56, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999987.25, New Asset: 999987.19, Reward: -0.062500
# 🔍 Debug: Step 1600 - Old Asset: 999987.12, New Asset: 999987.12, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 999988.94, New Asset: 999988.94, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999990.31, New Asset: 1000001.50, Reward: 11.187500
# 🔍 Debug: Step 200 - Old Asset: 999998.44, New Asset: 999992.69, Reward: -5.750000
# 🔍 Debug: Step 300 - Old Asset: 999976.56, New Asset: 999976.56, Reward: 0.000000
# 🔍 Debug: Step 1795000 - Asset=$999965.62, Cash=$999965.62, Position=0, Price=$57709.12, Reward=0.000000
# 🔍 Debug: Step 400 - Old Asset: 999961.19, New Asset: 999961.19, Reward: 0.000000
# 🔍 Debug: Step 500 - Old Asset: 999949.50, New Asset: 999949.44, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 999979.12, New Asset: 999979.06, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 1000005.81, New Asset: 1000005.81, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 999984.06, New Asset: 999984.06, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 999975.38, New Asset: 999975.38, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 999973.81, New Asset: 999973.81, Reward: 0.000000
# 🔍 Debug: Step 1100 - Old Asset: 999969.31, New Asset: 999969.25, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 999909.69, New Asset: 999909.69, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 999909.06, New Asset: 999909.00, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 999899.69, New Asset: 999899.69, Reward: 0.000000
# 🔍 Debug: Step 1500 - Old Asset: 999939.69, New Asset: 999939.69, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 999973.19, New Asset: 999973.19, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 999985.38, New Asset: 999985.25, Reward: -0.125000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000010.12, New Asset: 1000010.06, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 1000044.69, New Asset: 1000044.62, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 1000065.38, New Asset: 1000065.38, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 1000064.62, New Asset: 1000064.56, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 1000071.50, New Asset: 1000066.25, Reward: -5.250000
# 🔍 Debug: Step 600 - Old Asset: 1000093.38, New Asset: 1000093.38, Reward: 0.000000
# 🔍 Debug: Step 1796000 - Asset=$1000102.44, Cash=$1058249.75, Position=-1, Price=$58147.34, Reward=-0.005250
# 🔍 Debug: Step 700 - Old Asset: 1000111.25, New Asset: 1000111.25, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 1000114.19, New Asset: 1000116.81, Reward: 2.625000
# 🔍 Debug: Step 900 - Old Asset: 1000107.62, New Asset: 1000107.62, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 1000109.44, New Asset: 1000109.38, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 1000156.19, New Asset: 1000156.12, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 1000189.19, New Asset: 1000177.88, Reward: -11.312500
# 🔍 Debug: Step 1300 - Old Asset: 1000147.88, New Asset: 1000147.81, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 1000172.00, New Asset: 1000171.94, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 1000185.12, New Asset: 1000185.06, Reward: -0.062500
# 🔍 Debug: Step 1600 - Old Asset: 1000191.62, New Asset: 1000191.62, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 1000168.19, New Asset: 1000168.12, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999993.00, New Asset: 999992.94, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 999993.25, New Asset: 999993.19, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 1000001.50, New Asset: 1000001.44, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 1000016.62, New Asset: 1000025.81, Reward: 9.187500
# 🔍 Debug: Step 500 - Old Asset: 1000008.50, New Asset: 1000008.44, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 999981.19, New Asset: 999981.12, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 999991.62, New Asset: 999991.56, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 999952.06, New Asset: 999952.06, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 999950.50, New Asset: 999950.50, Reward: 0.000000
# 🔍 Debug: Step 1797000 - Asset=$999950.38, Cash=$1056217.75, Position=-1, Price=$56267.34, Reward=-0.011500
# 🔍 Debug: Step 1000 - Old Asset: 999956.69, New Asset: 999956.62, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 999987.62, New Asset: 999987.56, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 999954.75, New Asset: 999954.62, Reward: -0.125000
# 🔍 Debug: Step 1300 - Old Asset: 999927.19, New Asset: 999927.12, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 999929.62, New Asset: 999929.56, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999933.81, New Asset: 999933.81, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 999913.69, New Asset: 999913.69, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 999912.56, New Asset: 999912.56, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999978.19, New Asset: 999978.12, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 999965.75, New Asset: 999965.69, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 999977.75, New Asset: 999977.69, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 999973.50, New Asset: 999973.44, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 1000032.12, New Asset: 1000048.12, Reward: 16.000000
# 🔍 Debug: Step 600 - Old Asset: 1000072.50, New Asset: 1000065.62, Reward: -6.875000
# 🔍 Debug: Step 700 - Old Asset: 1000016.62, New Asset: 1000017.44, Reward: 0.812500
# 🔍 Debug: Step 800 - Old Asset: 1000010.19, New Asset: 1000010.12, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 1000011.38, New Asset: 1000012.56, Reward: 1.187500
# 🔍 Debug: Step 1000 - Old Asset: 1000018.25, New Asset: 1000018.19, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 1000030.69, New Asset: 1000030.69, Reward: 0.000000
# 🔍 Debug: Step 1798000 - Asset=$1000034.56, Cash=$1000034.56, Position=0, Price=$59169.89, Reward=0.007313
# 🔍 Debug: Step 1200 - Old Asset: 1000033.81, New Asset: 1000033.75, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 1000015.25, New Asset: 1000015.19, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 1000055.19, New Asset: 1000055.19, Reward: 0.000000
# 🔍 Debug: Step 1500 - Old Asset: 1000081.19, New Asset: 1000081.19, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 1000150.88, New Asset: 1000150.88, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 1000209.81, New Asset: 1000209.75, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000013.56, New Asset: 1000013.06, Reward: -0.500000
# 🔍 Debug: Step 200 - Old Asset: 1000026.50, New Asset: 1000026.44, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 1000033.75, New Asset: 1000033.69, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 1000056.75, New Asset: 1000056.69, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 1000059.00, New Asset: 1000059.00, Reward: 0.000000
# 🔍 Debug: Step 600 - Old Asset: 1000060.06, New Asset: 1000060.06, Reward: 0.000000
# 🔍 Debug: Step 700 - Old Asset: 1000066.62, New Asset: 1000066.62, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 1000056.31, New Asset: 1000056.25, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 1000057.88, New Asset: 1000064.25, Reward: 6.375000
# 🔍 Debug: Step 1000 - Old Asset: 1000061.62, New Asset: 1000061.56, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 1000067.75, New Asset: 1000067.75, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 1000052.12, New Asset: 1000052.06, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 1000058.75, New Asset: 1000058.69, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 1000051.25, New Asset: 1000051.12, Reward: -0.125000
# 🔍 Debug: Step 1799000 - Asset=$1000045.19, Cash=$1058191.25, Position=-1, Price=$58146.05, Reward=0.001000
# 🔍 Debug: Step 1500 - Old Asset: 1000101.38, New Asset: 1000101.38, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 1000066.38, New Asset: 1000066.38, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 1000045.62, New Asset: 1000045.62, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999974.38, New Asset: 999974.38, Reward: 0.000000
# 🔍 Debug: Step 200 - Old Asset: 999969.88, New Asset: 999969.88, Reward: 0.000000
# 🔍 Debug: Step 300 - Old Asset: 999980.69, New Asset: 999980.62, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 999974.06, New Asset: 999974.00, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 999958.25, New Asset: 999958.19, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 999948.75, New Asset: 999948.69, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 999960.69, New Asset: 999960.69, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 999933.56, New Asset: 999933.50, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 999919.19, New Asset: 999919.12, Reward: -0.062500
# 🔍 Debug: Step 1000 - Old Asset: 999916.06, New Asset: 999916.00, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 999939.38, New Asset: 999940.44, Reward: 1.062500
# 🔍 Debug: Step 1200 - Old Asset: 999912.81, New Asset: 999912.81, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 999894.38, New Asset: 999894.38, Reward: 0.000000
# 🔍 Debug: Step 1400 - Old Asset: 999867.25, New Asset: 999867.25, Reward: 0.000000
# 🔍 Debug: Step 1500 - Old Asset: 999876.06, New Asset: 999876.00, Reward: -0.062500
# 🔍 Debug: Step 1600 - Old Asset: 999834.50, New Asset: 999832.19, Reward: -2.312500
# 🔍 Debug: Step 1800000 - Asset=$999812.38, Cash=$1059162.38, Position=-1, Price=$59350.00, Reward=0.001000
# 💾 Saved agent at step 1800000
# 🔍 Debug: Step 1700 - Old Asset: 999797.25, New Asset: 999797.25, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000017.38, New Asset: 1000017.38, Reward: 0.000000
# 🔍 Debug: Step 200 - Old Asset: 1000000.12, New Asset: 1000000.06, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 1000009.06, New Asset: 1000010.19, Reward: 1.125000
# 🔍 Debug: Step 400 - Old Asset: 1000046.56, New Asset: 1000046.50, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 1000048.75, New Asset: 1000048.69, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 1000029.31, New Asset: 1000029.31, Reward: 0.000000
# 🔍 Debug: Step 700 - Old Asset: 1000023.12, New Asset: 1000023.12, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 999997.62, New Asset: 999997.56, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 999959.62, New Asset: 999959.69, Reward: 0.062500
# 🔍 Debug: Step 1000 - Old Asset: 999951.50, New Asset: 999951.50, Reward: 0.000000
# 🔍 Debug: Step 1100 - Old Asset: 999951.50, New Asset: 999951.50, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 999976.56, New Asset: 999976.50, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 999943.75, New Asset: 999943.69, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 999915.25, New Asset: 999915.19, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999916.50, New Asset: 999916.44, Reward: -0.062500
# 🔍 Debug: Step 1600 - Old Asset: 999906.50, New Asset: 999906.50, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 999892.31, New Asset: 999892.31, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999996.81, New Asset: 999996.75, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 1000036.38, New Asset: 1000036.38, Reward: 0.000000
# 🔍 Debug: Step 1801000 - Asset=$1000036.38, Cash=$1000036.38, Position=0, Price=$58164.86, Reward=0.001000
# 🔍 Debug: Step 300 - Old Asset: 1000037.38, New Asset: 1000029.19, Reward: -8.187500
# 🔍 Debug: Step 400 - Old Asset: 1000034.31, New Asset: 1000034.31, Reward: 0.000000
# 🔍 Debug: Step 500 - Old Asset: 1000031.88, New Asset: 1000031.81, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 1000029.50, New Asset: 1000029.50, Reward: 0.000000
# 🔍 Debug: Step 700 - Old Asset: 1000031.94, New Asset: 1000031.88, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 1000002.62, New Asset: 1000002.56, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 999978.19, New Asset: 999978.12, Reward: -0.062500
# 🔍 Debug: Step 1000 - Old Asset: 999978.12, New Asset: 999978.12, Reward: 0.000000
# 🔍 Debug: Step 1100 - Old Asset: 999924.00, New Asset: 999924.00, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 999959.31, New Asset: 999964.75, Reward: 5.437500
# 🔍 Debug: Step 1300 - Old Asset: 999949.88, New Asset: 999949.81, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 999955.94, New Asset: 999955.88, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999924.56, New Asset: 999924.50, Reward: -0.062500
# 🔍 Debug: Step 1600 - Old Asset: 999923.69, New Asset: 999923.62, Reward: -0.062500
# 🔍 Debug: Step 1700 - Old Asset: 999924.56, New Asset: 999922.38, Reward: -2.187500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000000.88, New Asset: 999992.12, Reward: -8.750000
# 🔍 Debug: Step 200 - Old Asset: 999996.06, New Asset: 999996.00, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 999996.06, New Asset: 999996.00, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 1000001.62, New Asset: 1000001.62, Reward: 0.000000
# 🔍 Debug: Step 1802000 - Asset=$1000018.12, Cash=$1058371.75, Position=-1, Price=$58353.59, Reward=-0.011500
# 🔍 Debug: Step 500 - Old Asset: 1000020.00, New Asset: 1000020.44, Reward: 0.437500
# 🔍 Debug: Step 600 - Old Asset: 1000060.94, New Asset: 1000060.88, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 1000058.56, New Asset: 1000058.56, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 1000077.69, New Asset: 1000077.62, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 1000091.62, New Asset: 1000091.56, Reward: -0.062500
# 🔍 Debug: Step 1000 - Old Asset: 1000048.56, New Asset: 1000048.56, Reward: 0.000000
# 🔍 Debug: Step 1100 - Old Asset: 1000052.25, New Asset: 1000052.19, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 1000049.25, New Asset: 1000049.25, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 1000040.06, New Asset: 1000040.00, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 1000049.12, New Asset: 1000049.06, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 1000047.62, New Asset: 1000047.56, Reward: -0.062500
# 🔍 Debug: Step 1600 - Old Asset: 1000045.50, New Asset: 1000045.44, Reward: -0.062500
# 🔍 Debug: Step 1700 - Old Asset: 1000083.62, New Asset: 1000083.62, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000011.19, New Asset: 1000011.12, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 999992.75, New Asset: 999992.75, Reward: 0.000000
# 🔍 Debug: Step 300 - Old Asset: 1000065.06, New Asset: 1000065.00, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 1000060.50, New Asset: 1000057.56, Reward: -2.937500
# 🔍 Debug: Step 500 - Old Asset: 1000043.00, New Asset: 1000042.88, Reward: -0.125000
# 🔍 Debug: Step 600 - Old Asset: 1000010.44, New Asset: 1000010.44, Reward: 0.000000
# 🔍 Debug: Step 700 - Old Asset: 999962.75, New Asset: 999962.69, Reward: -0.062500
# 🔍 Debug: Step 1803000 - Asset=$999972.44, Cash=$999972.44, Position=0, Price=$56518.64, Reward=-0.005250
# 🔍 Debug: Step 800 - Old Asset: 999986.12, New Asset: 999986.12, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 999973.62, New Asset: 999973.62, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 999956.50, New Asset: 999956.44, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 999913.25, New Asset: 999913.19, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 999947.56, New Asset: 999947.56, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 999987.25, New Asset: 999987.25, Reward: 0.000000
# 🔍 Debug: Step 1400 - Old Asset: 999979.25, New Asset: 999979.19, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 1000027.12, New Asset: 1000027.06, Reward: -0.062500
# 🔍 Debug: Step 1600 - Old Asset: 1000022.12, New Asset: 1000022.06, Reward: -0.062500
# 🔍 Debug: Step 1700 - Old Asset: 999977.56, New Asset: 999977.56, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000029.00, New Asset: 1000028.88, Reward: -0.125000
# 🔍 Debug: Step 200 - Old Asset: 1000042.12, New Asset: 1000042.06, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 1000039.62, New Asset: 1000039.56, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 1000056.31, New Asset: 1000056.25, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 1000061.62, New Asset: 1000061.56, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 1000049.38, New Asset: 1000049.31, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 1000070.19, New Asset: 1000070.12, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 1000052.44, New Asset: 1000052.38, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 1000074.94, New Asset: 1000081.06, Reward: 6.125000
# 🔍 Debug: Step 1804000 - Asset=$1000108.25, Cash=$1000108.25, Position=0, Price=$57711.45, Reward=-0.186500
# 🔍 Debug: Step 1000 - Old Asset: 1000102.88, New Asset: 1000102.88, Reward: 0.000000
# 🔍 Debug: Step 1100 - Old Asset: 1000104.44, New Asset: 1000104.38, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 1000092.19, New Asset: 1000092.12, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 1000126.50, New Asset: 1000126.44, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 1000099.25, New Asset: 1000099.19, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 1000084.94, New Asset: 1000078.19, Reward: -6.750000
# 🔍 Debug: Step 1600 - Old Asset: 1000069.88, New Asset: 1000069.88, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 1000072.25, New Asset: 1000072.25, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000064.50, New Asset: 1000064.44, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 1000018.88, New Asset: 1000018.88, Reward: 0.000000
# 🔍 Debug: Step 300 - Old Asset: 1000032.19, New Asset: 1000032.12, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 1000012.69, New Asset: 1000012.62, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 1000011.38, New Asset: 1000011.31, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 999975.19, New Asset: 999975.12, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 999994.81, New Asset: 999994.81, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 999983.94, New Asset: 999983.94, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 999980.81, New Asset: 999980.81, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 999977.12, New Asset: 999983.94, Reward: 6.812500
# 🔍 Debug: Step 1100 - Old Asset: 999984.94, New Asset: 999984.94, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 999983.06, New Asset: 999968.62, Reward: -14.437500
# 🔍 Debug: Step 1805000 - Asset=$999972.12, Cash=$1056791.25, Position=-1, Price=$56819.12, Reward=-0.005250
# 🔍 Debug: Step 1300 - Old Asset: 999994.25, New Asset: 999994.25, Reward: 0.000000
# 🔍 Debug: Step 1400 - Old Asset: 999973.06, New Asset: 999973.06, Reward: 0.000000
# 🔍 Debug: Step 1500 - Old Asset: 1000013.88, New Asset: 1000013.88, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 999996.69, New Asset: 999996.69, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 999999.69, New Asset: 999999.69, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000172.19, New Asset: 1000172.19, Reward: 0.000000
# 🔍 Debug: Step 200 - Old Asset: 1000165.75, New Asset: 1000165.75, Reward: 0.000000
# 🔍 Debug: Step 300 - Old Asset: 1000132.12, New Asset: 1000132.12, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 1000091.31, New Asset: 1000091.25, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 1000080.50, New Asset: 1000080.44, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 1000103.31, New Asset: 1000086.75, Reward: -16.562500
# 🔍 Debug: Step 700 - Old Asset: 1000040.38, New Asset: 1000040.38, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 1000068.25, New Asset: 1000080.25, Reward: 12.000000
# 🔍 Debug: Step 900 - Old Asset: 1000093.69, New Asset: 1000093.69, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 1000032.12, New Asset: 1000032.00, Reward: -0.125000
# 🔍 Debug: Step 1100 - Old Asset: 1000035.38, New Asset: 1000035.38, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 1000043.38, New Asset: 1000043.38, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 1000039.06, New Asset: 1000039.00, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 1000078.56, New Asset: 1000078.56, Reward: 0.000000
# 🔍 Debug: Step 1500 - Old Asset: 1000047.06, New Asset: 1000047.06, Reward: 0.000000
# 🔍 Debug: Step 1806000 - Asset=$1000022.00, Cash=$1000022.00, Position=0, Price=$56038.57, Reward=-2.505250
# 🔍 Debug: Step 1600 - Old Asset: 999965.00, New Asset: 999964.31, Reward: -0.687500
# 🔍 Debug: Step 1700 - Old Asset: 1000025.38, New Asset: 1000025.38, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000012.69, New Asset: 1000012.62, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 1000000.81, New Asset: 999987.88, Reward: -12.937500
# 🔍 Debug: Step 300 - Old Asset: 999946.12, New Asset: 999940.19, Reward: -5.937500
# 🔍 Debug: Step 400 - Old Asset: 999975.38, New Asset: 999975.38, Reward: 0.000000
# 🔍 Debug: Step 500 - Old Asset: 999956.00, New Asset: 999955.88, Reward: -0.125000
# 🔍 Debug: Step 600 - Old Asset: 999932.69, New Asset: 999932.62, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 999882.56, New Asset: 999882.50, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 999839.81, New Asset: 999847.38, Reward: 7.562500
# 🔍 Debug: Step 900 - Old Asset: 999817.44, New Asset: 999817.38, Reward: -0.062500
# 🔍 Debug: Step 1000 - Old Asset: 999808.19, New Asset: 999808.19, Reward: 0.000000
# 🔍 Debug: Step 1100 - Old Asset: 999824.38, New Asset: 999824.31, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 999839.31, New Asset: 999839.19, Reward: -0.125000
# 🔍 Debug: Step 1300 - Old Asset: 999848.81, New Asset: 999848.75, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 999862.38, New Asset: 999862.31, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999879.06, New Asset: 999879.00, Reward: -0.062500
# 🔍 Debug: Step 1600 - Old Asset: 999901.31, New Asset: 999901.31, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 999915.12, New Asset: 999913.50, Reward: -1.625000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 1807000 - Asset=$1000001.19, Cash=$1057687.75, Position=-1, Price=$57686.55, Reward=-0.005250
# 🔍 Debug: Step 100 - Old Asset: 1000026.94, New Asset: 1000025.12, Reward: -1.812500
# 🔍 Debug: Step 200 - Old Asset: 1000009.25, New Asset: 1000009.25, Reward: 0.000000
# 🔍 Debug: Step 300 - Old Asset: 1000018.31, New Asset: 1000018.19, Reward: -0.125000
# 🔍 Debug: Step 400 - Old Asset: 1000017.31, New Asset: 1000017.25, Reward: -0.062500
# ...
# 🔍 Debug: Step 100 - Old Asset: 999984.19, New Asset: 999984.12, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 999971.31, New Asset: 999971.25, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 1000004.50, New Asset: 1000005.44, Reward: 0.937500
# 🔍 Debug: Step 400 - Old Asset: 1000004.25, New Asset: 1000004.25, Reward: 0.000000
# 🔍 Debug: Step 500 - Old Asset: 1000011.06, New Asset: 1000010.88, Reward: -0.187500
# 🔍 Debug: Step 600 - Old Asset: 1000017.00, New Asset: 1000018.19, Reward: 1.187500
# 🔍 Debug: Step 700 - Old Asset: 1000020.25, New Asset: 1000020.19, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 1000030.06, New Asset: 1000030.06, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 1000036.31, New Asset: 1000036.31, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 1000035.19, New Asset: 1000035.12, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 1000017.31, New Asset: 1000017.25, Reward: -0.062500
# 🔍 Debug: Step 1992000 - Asset=$1000054.38, Cash=$1000054.38, Position=0, Price=$57976.34, Reward=4.318750
# 🔍 Debug: Step 1200 - Old Asset: 1000097.75, New Asset: 1000097.69, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 1000096.62, New Asset: 1000096.62, Reward: 0.000000
# 🔍 Debug: Step 1400 - Old Asset: 1000091.62, New Asset: 1000091.56, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 1000077.44, New Asset: 1000077.38, Reward: -0.062500
# 🔍 Debug: Step 1600 - Old Asset: 1000077.06, New Asset: 1000077.06, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 1000070.94, New Asset: 1000070.88, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999996.81, New Asset: 999996.75, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 999988.81, New Asset: 999988.75, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 999978.38, New Asset: 999978.38, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 999976.38, New Asset: 999976.38, Reward: 0.000000
# 🔍 Debug: Step 500 - Old Asset: 999993.81, New Asset: 999993.81, Reward: 0.000000
# 🔍 Debug: Step 600 - Old Asset: 999994.75, New Asset: 999992.62, Reward: -2.125000
# 🔍 Debug: Step 700 - Old Asset: 999985.56, New Asset: 999985.56, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 999980.44, New Asset: 999984.19, Reward: 3.750000
# 🔍 Debug: Step 900 - Old Asset: 999987.62, New Asset: 999987.62, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 999998.31, New Asset: 999997.19, Reward: -1.125000
# 🔍 Debug: Step 1100 - Old Asset: 1000005.62, New Asset: 1000005.62, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 1000009.75, New Asset: 1000009.75, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 999998.88, New Asset: 999998.81, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 999981.12, New Asset: 999981.06, Reward: -0.062500
# 🔍 Debug: Step 1993000 - Asset=$999985.31, Cash=$999985.31, Position=0, Price=$58440.27, Reward=0.430250
# 🔍 Debug: Step 1500 - Old Asset: 999965.44, New Asset: 999965.44, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 999962.50, New Asset: 999962.44, Reward: -0.062500
# 🔍 Debug: Step 1700 - Old Asset: 999959.69, New Asset: 999959.56, Reward: -0.125000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000020.25, New Asset: 1000020.19, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 1000003.19, New Asset: 1000003.19, Reward: 0.000000
# 🔍 Debug: Step 300 - Old Asset: 1000017.50, New Asset: 1000017.44, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 1000040.25, New Asset: 1000040.81, Reward: 0.562500
# 🔍 Debug: Step 500 - Old Asset: 1000038.94, New Asset: 1000039.69, Reward: 0.750000
# 🔍 Debug: Step 600 - Old Asset: 1000026.81, New Asset: 1000026.81, Reward: 0.000000
# 🔍 Debug: Step 700 - Old Asset: 1000028.06, New Asset: 1000028.06, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 1000028.25, New Asset: 1000028.19, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 1000024.00, New Asset: 1000024.00, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 1000047.00, New Asset: 1000046.94, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 1000095.31, New Asset: 1000095.25, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 1000116.50, New Asset: 1000116.44, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 1000090.75, New Asset: 1000090.75, Reward: 0.000000
# 🔍 Debug: Step 1400 - Old Asset: 1000108.38, New Asset: 1000108.38, Reward: 0.000000
# 🔍 Debug: Step 1500 - Old Asset: 1000097.56, New Asset: 1000097.56, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 1000095.94, New Asset: 1000095.94, Reward: 0.000000
# 🔍 Debug: Step 1994000 - Asset=$1000095.06, Cash=$1000095.06, Position=0, Price=$57949.64, Reward=0.000000
# 🔍 Debug: Step 1700 - Old Asset: 1000089.50, New Asset: 1000089.50, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999998.81, New Asset: 999998.75, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 999998.56, New Asset: 1000002.50, Reward: 3.937500
# 🔍 Debug: Step 300 - Old Asset: 999980.19, New Asset: 999980.19, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 999981.25, New Asset: 999981.19, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 999999.44, New Asset: 999999.38, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 1000008.81, New Asset: 1000008.81, Reward: 0.000000
# 🔍 Debug: Step 700 - Old Asset: 1000070.69, New Asset: 1000070.69, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 1000068.81, New Asset: 1000068.75, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 1000062.06, New Asset: 1000062.06, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 1000057.62, New Asset: 1000057.62, Reward: 0.000000
# 🔍 Debug: Step 1100 - Old Asset: 1000059.62, New Asset: 1000059.56, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 1000038.31, New Asset: 1000033.94, Reward: -4.375000
# 🔍 Debug: Step 1300 - Old Asset: 1000006.44, New Asset: 1000006.38, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 999998.06, New Asset: 999998.00, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999996.56, New Asset: 999996.56, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 999988.56, New Asset: 999988.56, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 1000013.69, New Asset: 1000013.69, Reward: 0.000000
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000070.25, New Asset: 1000070.19, Reward: -0.062500
# 🔍 Debug: Step 1995000 - Asset=$1000131.94, Cash=$1000131.94, Position=0, Price=$55704.53, Reward=-0.055250
# 🔍 Debug: Step 200 - Old Asset: 1000131.62, New Asset: 1000131.56, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 1000109.62, New Asset: 1000109.56, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 1000103.94, New Asset: 1000103.88, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 1000019.75, New Asset: 1000019.75, Reward: 0.000000
# 🔍 Debug: Step 600 - Old Asset: 999993.06, New Asset: 999993.06, Reward: 0.000000
# 🔍 Debug: Step 700 - Old Asset: 999966.38, New Asset: 999966.38, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 1000015.25, New Asset: 1000015.25, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 1000034.25, New Asset: 1000033.56, Reward: -0.687500
# 🔍 Debug: Step 1000 - Old Asset: 1000030.75, New Asset: 1000030.69, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 1000028.94, New Asset: 1000045.25, Reward: 16.312500
# 🔍 Debug: Step 1200 - Old Asset: 1000037.88, New Asset: 1000037.81, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 999914.25, New Asset: 999913.44, Reward: -0.812500
# 🔍 Debug: Step 1400 - Old Asset: 999920.38, New Asset: 999902.88, Reward: -17.500000
# 🔍 Debug: Step 1500 - Old Asset: 999949.56, New Asset: 999949.50, Reward: -0.062500
# 🔍 Debug: Step 1600 - Old Asset: 1000002.25, New Asset: 1000002.19, Reward: -0.062500
# 🔍 Debug: Step 1700 - Old Asset: 1000034.12, New Asset: 1000034.06, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000049.81, New Asset: 1000049.81, Reward: 0.000000
# 🔍 Debug: Step 200 - Old Asset: 1000013.00, New Asset: 1000013.00, Reward: 0.000000
# 🔍 Debug: Step 300 - Old Asset: 1000026.25, New Asset: 1000026.19, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 1000016.44, New Asset: 1000016.38, Reward: -0.062500
# 🔍 Debug: Step 1996000 - Asset=$1000015.75, Cash=$1000015.75, Position=0, Price=$56439.61, Reward=0.000000
# 🔍 Debug: Step 500 - Old Asset: 1000007.75, New Asset: 1000007.75, Reward: 0.000000
# 🔍 Debug: Step 600 - Old Asset: 999996.25, New Asset: 999996.25, Reward: 0.000000
# 🔍 Debug: Step 700 - Old Asset: 999984.38, New Asset: 999984.38, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 999979.31, New Asset: 999979.25, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 999985.31, New Asset: 999985.31, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 999939.00, New Asset: 999939.00, Reward: 0.000000
# 🔍 Debug: Step 1100 - Old Asset: 999945.25, New Asset: 999941.62, Reward: -3.625000
# 🔍 Debug: Step 1200 - Old Asset: 999993.69, New Asset: 999993.62, Reward: -0.062500
# 🔍 Debug: Step 1300 - Old Asset: 1000008.62, New Asset: 1000008.50, Reward: -0.125000
# 🔍 Debug: Step 1400 - Old Asset: 1000028.88, New Asset: 1000028.81, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 1000029.19, New Asset: 1000029.19, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 1000034.19, New Asset: 1000034.12, Reward: -0.062500
# 🔍 Debug: Step 1700 - Old Asset: 1000000.50, New Asset: 1000000.44, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000003.38, New Asset: 1000003.31, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 1000000.69, New Asset: 1000000.62, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 1000001.12, New Asset: 1000001.06, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 1000014.62, New Asset: 1000050.69, Reward: 36.062500
# 🔍 Debug: Step 500 - Old Asset: 1000069.12, New Asset: 1000069.06, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 1000046.62, New Asset: 1000046.56, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 1000017.88, New Asset: 999999.88, Reward: -18.000000
# 🔍 Debug: Step 1997000 - Asset=$999999.88, Cash=$1057724.88, Position=-1, Price=$57724.98, Reward=0.001000
# 🔍 Debug: Step 800 - Old Asset: 999977.62, New Asset: 999977.62, Reward: 0.000000
# 🔍 Debug: Step 900 - Old Asset: 999971.25, New Asset: 999971.19, Reward: -0.062500
# 🔍 Debug: Step 1000 - Old Asset: 1000002.88, New Asset: 1000002.75, Reward: -0.125000
# 🔍 Debug: Step 1100 - Old Asset: 999983.94, New Asset: 999983.94, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 999975.31, New Asset: 999975.31, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 999959.06, New Asset: 999959.00, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 999947.31, New Asset: 999947.25, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999933.31, New Asset: 999933.25, Reward: -0.062500
# 🔍 Debug: Step 1600 - Old Asset: 999912.25, New Asset: 999912.25, Reward: 0.000000
# 🔍 Debug: Step 1700 - Old Asset: 999891.56, New Asset: 999891.50, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999993.44, New Asset: 999993.44, Reward: 0.000000
# 🔍 Debug: Step 200 - Old Asset: 1000021.62, New Asset: 1000021.56, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 1000025.19, New Asset: 1000017.50, Reward: -7.687500
# 🔍 Debug: Step 400 - Old Asset: 1000013.56, New Asset: 1000013.56, Reward: 0.000000
# 🔍 Debug: Step 500 - Old Asset: 1000006.31, New Asset: 1000006.31, Reward: 0.000000
# 🔍 Debug: Step 600 - Old Asset: 1000003.00, New Asset: 1000003.00, Reward: 0.000000
# 🔍 Debug: Step 700 - Old Asset: 1000000.81, New Asset: 1000000.75, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 999995.12, New Asset: 999995.06, Reward: -0.062500
# 🔍 Debug: Step 900 - Old Asset: 999981.88, New Asset: 999981.75, Reward: -0.125000
# 🔍 Debug: Step 1998000 - Asset=$999960.81, Cash=$999960.81, Position=0, Price=$59760.50, Reward=-0.005250
# 🔍 Debug: Step 1000 - Old Asset: 999959.88, New Asset: 999959.81, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 999951.00, New Asset: 999951.00, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 999947.75, New Asset: 999947.75, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 999905.88, New Asset: 999905.81, Reward: -0.062500
# 🔍 Debug: Step 1400 - Old Asset: 999919.50, New Asset: 999919.44, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999976.25, New Asset: 999976.19, Reward: -0.062500
# 🔍 Debug: Step 1600 - Old Asset: 999944.62, New Asset: 999944.50, Reward: -0.125000
# 🔍 Debug: Step 1700 - Old Asset: 999932.69, New Asset: 999932.62, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 999961.81, New Asset: 999961.75, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 999909.75, New Asset: 999909.69, Reward: -0.062500
# 🔍 Debug: Step 300 - Old Asset: 999914.56, New Asset: 999914.50, Reward: -0.062500
# 🔍 Debug: Step 400 - Old Asset: 999993.81, New Asset: 999993.75, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 999984.75, New Asset: 999984.69, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 999925.88, New Asset: 999925.81, Reward: -0.062500
# 🔍 Debug: Step 700 - Old Asset: 999969.69, New Asset: 999969.69, Reward: 0.000000
# 🔍 Debug: Step 800 - Old Asset: 999932.50, New Asset: 999926.56, Reward: -5.937500
# 🔍 Debug: Step 900 - Old Asset: 999882.00, New Asset: 999891.06, Reward: 9.062500
# 🔍 Debug: Step 1000 - Old Asset: 999872.00, New Asset: 999872.00, Reward: 0.000000
# 🔍 Debug: Step 1100 - Old Asset: 999814.62, New Asset: 999814.56, Reward: -0.062500
# 🔍 Debug: Step 1200 - Old Asset: 999805.31, New Asset: 999800.62, Reward: -4.687500
# 🔍 Debug: Step 1999000 - Asset=$999799.19, Cash=$1056478.38, Position=-1, Price=$56679.18, Reward=-0.005250
# 🔍 Debug: Step 1300 - Old Asset: 999846.50, New Asset: 999849.06, Reward: 2.562500
# 🔍 Debug: Step 1400 - Old Asset: 999877.00, New Asset: 999876.94, Reward: -0.062500
# 🔍 Debug: Step 1500 - Old Asset: 999894.62, New Asset: 999894.62, Reward: 0.000000
# 🔍 Debug: Step 1600 - Old Asset: 999853.50, New Asset: 999853.44, Reward: -0.062500
# 🔍 Debug: Step 1700 - Old Asset: 999867.12, New Asset: 999867.06, Reward: -0.062500
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Environment reset - Cash: 1000000.00, Asset: 1000000.00
# 🔍 Debug: Step 100 - Old Asset: 1000000.88, New Asset: 1000000.81, Reward: -0.062500
# 🔍 Debug: Step 200 - Old Asset: 999969.56, New Asset: 999969.44, Reward: -0.125000
# 🔍 Debug: Step 300 - Old Asset: 999949.38, New Asset: 999949.38, Reward: 0.000000
# 🔍 Debug: Step 400 - Old Asset: 999974.38, New Asset: 999974.31, Reward: -0.062500
# 🔍 Debug: Step 500 - Old Asset: 1000005.50, New Asset: 1000005.44, Reward: -0.062500
# 🔍 Debug: Step 600 - Old Asset: 1000007.06, New Asset: 1000007.06, Reward: 0.000000
# 🔍 Debug: Step 700 - Old Asset: 999990.75, New Asset: 999990.69, Reward: -0.062500
# 🔍 Debug: Step 800 - Old Asset: 999982.88, New Asset: 999982.75, Reward: -0.125000
# 🔍 Debug: Step 900 - Old Asset: 999939.56, New Asset: 999939.56, Reward: 0.000000
# 🔍 Debug: Step 1000 - Old Asset: 999910.56, New Asset: 999910.50, Reward: -0.062500
# 🔍 Debug: Step 1100 - Old Asset: 999959.31, New Asset: 999959.31, Reward: 0.000000
# 🔍 Debug: Step 1200 - Old Asset: 999962.31, New Asset: 999962.31, Reward: 0.000000
# 🔍 Debug: Step 1300 - Old Asset: 999978.38, New Asset: 999978.19, Reward: -0.187500
# 🔍 Debug: Step 1400 - Old Asset: 999976.25, New Asset: 999976.25, Reward: 0.000000
# ✅ Training completed! Agent saved to ./trained_agents/5_7_3/1sec/PPO
