# %%
import os
# For Colab/Google Drive integration:
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/FinRL/final')  # Change to your project folder in Drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import time
import numpy as np
import pandas as pd
from numpy import abs, log, sign
from scipy.stats import rankdata
from google.colab import drive
import glob

# %%
# Constants
WINDOW = 10
PERIOD = 10

# %%
# Auxiliary functions
def ref(s, n=1):
    return pd.Series(s).shift(n).values

def ts_sum(df, window=WINDOW):
    return df.rolling(window).sum()

def sma(df, window=WINDOW):
    return df.rolling(window).mean()

def ema(df, window, *, adjust=True, min_periods=1):
    return df.ewm(ignore_na=False, span=window, min_periods=min_periods, adjust=adjust).mean()

def stddev(df, window=WINDOW):
    return df.rolling(window).std()

def correlation(x, y, window=WINDOW):
    return x.rolling(window).corr(y)

def covariance(x, y, window=WINDOW):
    return x.rolling(window).cov(y)

def rolling_rank(na):
    return rankdata(na)[-1]

def ts_rank(df, window=WINDOW):
    return df.rolling(window).apply(rolling_rank)

def rolling_prod(na):
    return np.prod(na)

def product(df, window=WINDOW):
    return df.rolling(window).apply(rolling_prod)

def ts_min(df, window=WINDOW):
    return df.rolling(window).min()

def ts_max(df, window=WINDOW):
    return df.rolling(window).max()

def df_delta(df, period=1):
    return df.diff(period)

def delay(df, period=1):
    return df.shift(period)

def rank(df, window_size=WINDOW):
    return df.rolling(window=window_size).apply(lambda x: x.rank(pct=True).iloc[-1], raw=False)

def scale(df, window_size=WINDOW, k=1):
    scaled = df.mul(k)
    rolling_sums = np.abs(df).rolling(window=window_size, min_periods=1).sum()
    normalized = scaled.div(rolling_sums)
    return normalized

def ts_argmax(df, window=WINDOW):
    return df.rolling(window).apply(np.argmax) + 1

def ts_argmin(df, window=WINDOW):
    return df.rolling(window).apply(np.argmin) + 1

def decay_linear(df, period=PERIOD):
    if df.isnull().values.any():
        df.ffill(inplace=True)
        df.bfill(inplace=True)
        df.fillna(value=0, inplace=True)
    na_lwma = np.zeros_like(df)
    na_lwma[:period, :] = df.iloc[:period, :].values
    divisor = period * (period + 1) / 2
    y = (np.arange(period) + 1) * 1.0 / divisor
    for row in range(period - 1, df.shape[0]):
        x = df.iloc[row - period + 1 : row + 1, :].values
        na_lwma[row, :] = np.dot(x.T, y)
    return pd.DataFrame(na_lwma, index=df.index, columns=["LWMA"])

def normalize_with_quantiles(arys, q_low=0.01, q_high=0.99):
    min_vals = np.quantile(arys, q_low, axis=0, keepdims=True)
    max_vals = np.quantile(arys, q_high, axis=0, keepdims=True)
    arys = arys.clip(min_vals, max_vals)

    # Handle division by zero when max_vals - min_vals = 0
    denominator = max_vals - min_vals
    # Replace zeros with 1 to avoid division by zero
    denominator = np.where(denominator == 0, 1, denominator)

    arys = 2 * (arys - min_vals) / denominator - 1
    return arys

# %%
class TechIndicator:
    def __init__(self, df):
        # Handle different column names for aggregated data
        if 'midpoint' in df.columns:
            self.vwap = df["midpoint"]
        elif 'price' in df.columns:
            self.vwap = df["price"]
        elif 'close' in df.columns:
            self.vwap = df["close"]
        else:
            raise ValueError("DataFrame must contain 'midpoint', 'price', or 'close' column")

        if 'spread' in df.columns:
            self.spread = df["spread"]
        else:
            self.spread = pd.Series(0.001, index=df.index)  # Default spread

        if 'sells' in df.columns:
            self.num_asks = df["sells"]
        elif 'volume' in df.columns:
            self.num_asks = df["volume"] / 2
        else:
            self.num_asks = pd.Series(1, index=df.index)

        if 'buys' in df.columns:
            self.num_bids = df["buys"]
        elif 'volume' in df.columns:
            self.num_bids = df["volume"] / 2
        else:
            self.num_bids = pd.Series(1, index=df.index)

        # Handle order book data if available
        if 'bids_distance_3' in df.columns and 'asks_distance_3' in df.columns:
            self.best_bid = self.vwap * (1 + df["bids_distance_3"])
            self.best_ask = self.vwap * (1 + df["asks_distance_3"])
        else:
            # Use simple bid/ask approximation
            self.best_bid = self.vwap * 0.999
            self.best_ask = self.vwap * 1.001

        if 'bids_notional_3' in df.columns and 'asks_notional_3' in df.columns:
            self.bid_volume = df["bids_notional_3"]
            self.ask_volume = df["asks_notional_3"]
        else:
            self.bid_volume = self.num_bids
            self.ask_volume = self.num_asks

        self.mid_price = (self.best_bid + self.best_ask) / 2
        self.returns = np.log(self.mid_price / self.mid_price.shift(1))
        self.volume = (self.num_asks + self.num_bids) / 2

    # Alpha functions (first 10 as example - add all 101 from alpha101_complete.py)
    def alpha001(self):
        inner = self.mid_price
        inner[self.returns < 0] = stddev(self.returns, 20)
        return rank(ts_argmax(inner**2, 5))

    def alpha002(self):
        df = -1 * correlation(
            rank(df_delta(log(self.bid_volume + 1), 2)),
            rank((self.mid_price - self.best_bid) / self.best_bid),
            6,
        )
        return df.replace([-np.inf, np.inf], 0).fillna(value=0)

    def alpha003(self):
        df = -1 * correlation(rank(self.best_ask), rank(self.ask_volume), 10)
        return df.replace([-np.inf, np.inf], 0).fillna(value=0)

    def alpha004(self):
        return -1 * ts_rank(rank(self.best_ask), 9)

    def alpha005(self):
        return rank((self.best_bid - (ts_sum(self.vwap, 10) / 10))) * (-1 * abs(rank((self.mid_price - self.vwap))))

    def alpha006(self):
        df = -1 * correlation(self.best_bid, self.bid_volume, 10)
        return df.replace([-np.inf, np.inf], 0).fillna(value=0)

    def alpha007(self):
        adv20 = sma(self.bid_volume, 20)
        alpha = -1 * ts_rank(abs(df_delta(self.best_bid, 7)), 60) * sign(df_delta(self.best_bid, 7))
        alpha[adv20 >= self.bid_volume] = -1
        return alpha

    def alpha008(self):
        return -1 * (
            rank(
                (
                    (ts_sum(self.best_bid, 5) * ts_sum(self.returns, 5))
                    - delay((ts_sum(self.best_bid, 5) * ts_sum(self.returns, 5)), 10)
                )
            )
        )

    def alpha009(self):
        delta_midprice = df_delta(self.mid_price, 1)
        cond_1 = ts_min(delta_midprice, 5) > 0
        cond_2 = ts_max(delta_midprice, 5) < 0
        alpha = -1 * delta_midprice
        alpha[cond_1 | cond_2] = delta_midprice
        return alpha

    def alpha010(self):
        delta_midprice = df_delta(self.mid_price, 1)
        cond_1 = ts_min(delta_midprice, 4) > 0
        cond_2 = ts_max(delta_midprice, 4) < 0
        alpha = -1 * delta_midprice
        alpha[cond_1 | cond_2] = delta_midprice
        return alpha

    def alpha011(self):
        return (rank(ts_max((self.vwap - self.mid_price), 3)) + rank(ts_min((self.vwap - self.mid_price), 3))) * rank(
            df_delta(self.ask_volume, 3)
        )

    def alpha012(self):
        return sign(df_delta(self.bid_volume, 1)) * (-1 * df_delta(self.mid_price, 1))

    def alpha013(self):
        return -1 * rank(covariance(rank(self.mid_price), rank(self.ask_volume), 5))

    def alpha014(self):
        df = correlation(self.best_bid, self.bid_volume, 10)
        df = df.replace([-np.inf, np.inf], 0).fillna(value=0)
        return -1 * rank(df_delta(self.returns, 3)) * df

    def alpha015(self):
        df = correlation(rank(self.best_ask), rank(self.ask_volume), 3)
        df = df.replace([-np.inf, np.inf], 0).fillna(value=0)
        return -1 * ts_sum(rank(df), 3)

    def alpha016(self):
        return -1 * rank(covariance(rank(self.mid_price), rank(self.bid_volume), 5))

    def alpha017(self):
        adv20 = sma(self.bid_volume, 20)
        return -1 * (
            rank(ts_rank(self.mid_price, 10))
            * rank(df_delta(df_delta(self.mid_price, 1), 1))
            * rank(ts_rank((self.bid_volume / adv20), 5))
        )

    def alpha018(self):
        df = correlation(self.mid_price, self.best_bid, 10)
        df = df.replace([-np.inf, np.inf], 0).fillna(value=0)
        return -1 * (rank((stddev(abs((self.mid_price - self.best_bid)), 5) + (self.mid_price - self.best_bid)) + df))

    def alpha019(self):
        return (-1 * sign((self.mid_price - delay(self.mid_price, 7)) + df_delta(self.mid_price, 7))) * (
            1 + rank(1 + ts_sum(self.returns, 250))
        )

    def alpha020(self):
        return -1 * (
            rank(self.best_bid - delay(self.best_ask, 1))
            * rank(self.best_bid - delay(self.mid_price, 1))
            * rank(self.best_ask - delay(self.best_bid, 1))
        )

    def alpha021(self):
        cond_1 = sma(self.mid_price, 8) + stddev(self.mid_price, 8) < sma(self.mid_price, 2)
        cond_2 = sma(self.ask_volume, 20) / self.ask_volume < 1
        alpha = pd.DataFrame(np.ones_like(self.mid_price), index=self.mid_price.index)
        alpha[cond_1 | cond_2] = -1
        return alpha.squeeze(1)

    def alpha022(self):
        df = correlation(self.best_ask, self.ask_volume, 5)
        df = df.replace([-np.inf, np.inf], 0).fillna(value=0)
        return -1 * df_delta(df, 5) * rank(stddev(self.mid_price, 20))

    def alpha023(self):
        cond = sma(self.best_ask, 20) < self.best_ask
        alpha = pd.DataFrame(
            np.zeros_like(self.mid_price),
            index=self.mid_price.index,
            columns=["midprice"],
        )
        alpha.loc[cond, "midprice"] = -1 * df_delta(self.best_ask, 2).fillna(value=0)
        return alpha.squeeze(1)

    def alpha024(self):
        cond = df_delta(sma(self.mid_price, 100), 100) / delay(self.mid_price, 100) <= 0.05
        alpha = -1 * df_delta(self.mid_price, 3)
        alpha[cond] = -1 * (self.mid_price - ts_min(self.mid_price, 100))
        return alpha

    def alpha025(self):
        adv20 = sma(self.ask_volume, 20)
        return rank(((((-1 * self.returns) * adv20) * self.vwap) * (self.best_ask - self.mid_price)))

    def alpha026(self):
        df = correlation(ts_rank(self.bid_volume, 5), ts_rank(self.best_bid, 5), 5)
        df = df.replace([-np.inf, np.inf], 0).fillna(value=0)
        return -1 * ts_max(df, 3)

    def alpha027(self):
        alpha = rank((sma(correlation(rank(self.bid_volume), rank(self.best_bid), 6), 2) / 2.0))
        alpha[alpha > 0.5] = -1
        alpha[alpha <= 0.5] = 1
        return alpha

    def alpha028(self):
        adv20 = sma(self.bid_volume, 20)
        df = correlation(adv20, self.best_bid, 5)
        df = df.replace([-np.inf, np.inf], 0).fillna(value=0)
        return scale(df)

    def alpha029(self):
        delta_mid = df_delta((self.mid_price - 1), 5)
        rank_neg_delta = rank(-1 * delta_mid)
        sum_ranks = ts_sum(rank(rank_neg_delta), 2)
        scaled_log = scale(log(sum_ranks + 1))
        min_rank = ts_min(rank(rank(scaled_log)), 5)
        delayed_ret = delay(-1 * self.returns, 6)
        ts_rank_ret = ts_rank(delayed_ret, 5)
        return min_rank + ts_rank_ret

    def alpha030(self):
        delta_midprice = df_delta(self.mid_price, 1)
        inner = sign(delta_midprice) + sign(delay(delta_midprice, 1)) + sign(delay(delta_midprice, 2))
        return ((1.0 - rank(inner)) * ts_sum(self.ask_volume, 5)) / ts_sum(self.ask_volume, 20)

    def alpha031(self):
        adv20 = sma(self.bid_volume, 20)
        df = correlation(adv20, self.best_bid, 12).replace([-np.inf, np.inf], 0).fillna(value=0)
        p1 = rank(rank(rank(decay_linear((-1 * rank(rank(df_delta(self.mid_price, 10)))).to_frame(), 10))))
        p2 = rank((-1 * df_delta(self.mid_price, 3)))
        p3 = sign(scale(df))
        return p1.LWMA + p2 + p3

    def alpha032(self):
        return scale(((sma(self.mid_price, 7) / 7) - self.mid_price)) + (
            20 * scale(correlation(self.vwap, delay(self.mid_price, 5), 230))
        )

    def alpha033(self):
        return rank(-1 + (self.best_ask / self.mid_price))

    def alpha034(self):
        inner = stddev(self.returns, 2) / stddev(self.returns, 5)
        inner = inner.replace([-np.inf, np.inf], 1).fillna(value=1)
        return rank(2 - rank(inner) - rank(df_delta(self.mid_price, 1)))

    def alpha035(self):
        return (ts_rank(self.bid_volume, 32) * (1 - ts_rank(self.mid_price + self.spread, 16))) * (
            1 - ts_rank(self.returns, 32)
        )

    def alpha036(self):
        adv20 = sma(self.bid_volume, 20)
        corr_mid_bid = correlation(self.mid_price - self.best_bid, delay(self.bid_volume, 1), 15)
        rank_corr_mid_bid = rank(corr_mid_bid)
        rank_bid_mid = rank(self.best_bid - self.mid_price)
        delayed_neg_ret = delay(-1 * self.returns, 6)
        ts_rank_neg_ret = ts_rank(delayed_neg_ret, 5)
        rank_ts_rank_neg_ret = rank(ts_rank_neg_ret)
        abs_corr_vwap_adv20 = abs(correlation(self.vwap, adv20, 6))
        rank_abs_corr_vwap_adv20 = rank(abs_corr_vwap_adv20)
        sma_mid_200 = sma(self.mid_price, 200) / 200
        diff_sma_mid_bid = sma_mid_200 - self.best_bid
        prod_diff_mid_bid = diff_sma_mid_bid * (self.mid_price - self.best_bid)
        rank_prod_diff_mid_bid = rank(prod_diff_mid_bid)
        result = (
            (2.21 * rank_corr_mid_bid)
            + (0.7 * rank_bid_mid)
            + (0.73 * rank_ts_rank_neg_ret)
            + rank_abs_corr_vwap_adv20
            + (0.6 * rank_prod_diff_mid_bid)
        )
        return result

    def alpha037(self):
        return rank(correlation(delay(self.best_ask - self.mid_price, 1), self.mid_price, 200)) + rank(
            self.best_ask - self.mid_price
        )

    def alpha038(self):
        inner = self.mid_price / self.best_ask
        inner = inner.replace([-np.inf, np.inf], 1).fillna(value=1)
        return -1 * rank(ts_rank(self.best_ask, 10)) * rank(inner)

    def alpha039(self):
        adv20 = sma(self.ask_volume, 20)
        return (
            -1
            * rank(
                df_delta(self.mid_price, 7) * (1 - rank(decay_linear((self.ask_volume / adv20).to_frame(), 9).LWMA))
            )
        ) * (1 + rank(sma(self.returns, 250)))

    def alpha040(self):
        return -1 * rank(stddev(self.best_bid, 10)) * correlation(self.best_bid, self.bid_volume, 10)

    def alpha041(self):
        return pow((self.best_bid * self.best_ask), 0.5) - self.vwap

    def alpha042(self):
        return rank((self.vwap - self.mid_price)) / rank((self.vwap + self.mid_price))

    def alpha043(self):
        adv20 = sma(self.ask_volume, 20)
        return ts_rank(self.ask_volume / adv20, 20) * ts_rank((-1 * df_delta(self.mid_price, 7)), 8)

    def alpha044(self):
        df = correlation(self.best_ask, rank(self.ask_volume), 5)
        df = df.replace([-np.inf, np.inf], 0).fillna(value=0)
        return -1 * df

    def alpha045(self):
        df = correlation(self.mid_price, self.ask_volume, 2)
        df = df.replace([-np.inf, np.inf], 0).fillna(value=0)
        return -1 * (
            rank(sma(delay(self.mid_price, 5), 20))
            * df
            * rank(correlation(ts_sum(self.mid_price, 5), ts_sum(self.mid_price, 20), 2))
        )

    def alpha046(self):
        inner = ((delay(self.mid_price, 20) - delay(self.mid_price, 10)) / 10) - (
            (delay(self.mid_price, 10) - self.mid_price) / 10
        )
        alpha = -1 * df_delta(self.mid_price)
        alpha[inner < 0] = 1
        alpha[inner > 0.25] = -1
        return alpha

    def alpha047(self):
        adv20 = sma(self.bid_volume, 20)
        return (
            ((rank((1 / self.mid_price)) * self.bid_volume) / adv20)
            * ((self.best_bid * rank((self.best_bid - self.mid_price))) / (sma(self.best_bid, 5) / 5))
        ) - rank((self.vwap - delay(self.vwap, 5)))

    def alpha048(self):
        adv20 = sma(self.bid_volume, 20)
        return (
            ((rank((1 / self.mid_price)) * self.ask_volume) / adv20)
            * ((self.best_ask * rank((self.best_ask - self.mid_price))) / (sma(self.best_ask, 5) / 5))
        ) - rank((self.vwap - delay(self.vwap, 5)))

    def alpha049(self):
        inner = ((delay(self.mid_price, 20) - delay(self.mid_price, 10)) / 10) - (
            (delay(self.mid_price, 10) - self.mid_price) / 10
        )
        alpha = -1 * df_delta(self.mid_price)
        alpha[inner < -0.1] = 1
        return alpha

    def alpha050(self):
        return -1 * ts_max(rank(correlation(rank(self.ask_volume), rank(self.vwap), 5)), 5)

    def alpha051(self):
        inner = ((delay(self.mid_price, 20) - delay(self.mid_price, 10)) / 10) - (
            (delay(self.mid_price, 10) - self.mid_price) / 10
        )
        alpha = -1 * df_delta(self.mid_price)
        alpha[inner < -0.05] = 1
        return alpha

    def alpha052(self):
        return (
            (-1 * df_delta(ts_min(self.best_bid, 5), 5))
            * rank(((ts_sum(self.returns, 240) - ts_sum(self.returns, 20)) / 220))
        ) * ts_rank(self.bid_volume, 5)

    def alpha053(self):
        inner = self.spread.replace(0, 0.0001)
        return -1 * df_delta(
            (((self.mid_price - self.best_bid) - (self.best_bid - self.mid_price)) / inner),
            9,
        )

    def alpha054(self):
        inner = self.spread.replace(0, -0.0001)
        return -1 * (self.best_bid - self.mid_price) * (self.best_ask**5) / (inner * (self.mid_price**5))

    def alpha055(self):
        divisor = (ts_max(self.best_ask, 12) - ts_min(self.best_bid, 12)).replace(0, 0.0001)
        inner = (self.mid_price - ts_min(self.best_bid, 12)) / divisor
        df = correlation(rank(inner), rank(self.bid_volume), 6)
        return -1 * df.replace([-np.inf, np.inf], 0).fillna(value=0)

    def alpha056(self):
        inner = self.spread.replace(0, -0.0001)
        return -1 * (self.best_ask - self.mid_price) * (self.best_bid**5) / (inner * (self.mid_price**5))

    def alpha057(self):
        return 0 - (
            1 * ((self.mid_price - self.vwap) / decay_linear(rank(ts_argmax(self.mid_price, 30)).to_frame(), 2).LWMA)
        )

    def alpha058(self):
        return sign(df_delta(self.ask_volume, 1)) * (-1 * df_delta(self.mid_price, 1))

    def alpha059(self):
        divisor = self.spread.replace(0, 0.0001)
        inner = ((self.mid_price - self.best_ask) - (self.best_ask - self.mid_price)) * self.ask_volume / divisor
        return -((2 * scale(rank(inner))) - scale(rank(ts_argmax(self.mid_price, 10))))

    def alpha060(self):
        divisor = self.spread.replace(0, 0.0001)
        inner = ((self.mid_price - self.best_bid) - (self.best_bid - self.mid_price)) * self.bid_volume / divisor
        return -((2 * scale(rank(inner))) - scale(rank(ts_argmax(self.mid_price, 10))))

    def alpha061(self):
        adv180 = sma(self.ask_volume, 180)
        return rank((self.vwap - ts_min(self.vwap, 16))) < rank(correlation(self.vwap, adv180, 18))

    def alpha062(self):
        adv20 = sma(self.ask_volume, 20)
        value1 = rank(correlation(self.vwap, sma(adv20, 22), 10))
        value2 = rank(self.best_ask) + rank(self.best_ask)
        value3 = rank(((self.best_ask + self.best_bid) / 2)) + rank(self.best_ask)
        return value1 - rank(value2 - value3)

    def alpha063(self):
        adv120 = sma(self.bid_volume, 120)
        sma_bid_ask = sma(((self.best_bid * 0.178404) + (self.best_ask * (1 - 0.178404))), 13)
        sma_adv120 = sma(adv120, 13)
        corr = correlation(sma_bid_ask, sma_adv120, 17)
        rank_corr = rank(corr)
        weighted_price = (self.mid_price * 0.178404) + (self.vwap * (1 - 0.178404))
        delta_weighted_price = df_delta(weighted_price, 3)
        rank_delta = rank(delta_weighted_price)
        return rank_corr - rank_delta

    def alpha064(self):
        adv120 = sma(self.ask_volume, 120)
        return (
            rank(
                correlation(
                    sma(
                        ((self.best_ask * 0.178404) + (self.best_bid * (1 - 0.178404))),
                        13,
                    ),
                    sma(adv120, 13),
                    17,
                )
            )
            < rank(
                df_delta(
                    ((((self.best_ask + self.best_bid) / 2) * 0.178404) + (self.vwap * (1 - 0.178404))),
                    3,
                )
            )
        ) * -1

    def alpha065(self):
        adv60 = sma(self.ask_volume, 60)
        return (
            rank(
                correlation(
                    ((self.best_ask * 0.00817205) + (self.vwap * (1 - 0.00817205))),
                    sma(adv60, 9),
                    6,
                )
            )
            < rank((self.best_ask - ts_min(self.best_ask, 14)))
        ) * -1

    def alpha066(self):
        vwap_delta = df_delta(self.vwap, 4).to_frame()
        decay_vwap_delta = decay_linear(vwap_delta, 7).LWMA
        rank_decay_vwap_delta = rank(decay_vwap_delta)
        bid_ask_diff = ((self.best_bid * 0.96633) + (self.best_bid * (1 - 0.96633))) - self.vwap
        price_ratio = (bid_ask_diff / (self.best_ask - self.best_bid)).to_frame()
        decay_price_ratio = decay_linear(price_ratio, 11).LWMA
        ts_rank_decay_price_ratio = ts_rank(decay_price_ratio, 7)
        result = (rank_decay_vwap_delta + ts_rank_decay_price_ratio) * -1
        return result

    def alpha067(self):
        adv15 = sma(self.bid_volume, 15)
        return (
            ts_rank(correlation(rank(self.best_bid), rank(adv15), 9), 14)
            < rank(df_delta(((self.mid_price * 0.518371) + (self.best_ask * (1 - 0.518371))), 3))
        ) * -1

    def alpha068(self):
        adv15 = sma(self.ask_volume, 15)
        return (
            ts_rank(correlation(rank(self.best_ask), rank(adv15), 9), 14)
            < rank(df_delta(((self.mid_price * 0.518371) + (self.best_bid * (1 - 0.518371))), 3))
        ) * -1

    def alpha069(self):
        adv180 = sma(self.bid_volume, 180)
        return rank((self.vwap - ts_min(self.vwap, 16))) < rank(correlation(self.vwap, adv180, 18))

    def alpha070(self):
        adv60 = sma(self.bid_volume, 60)
        return (
            rank(
                correlation(
                    ((self.best_bid * 0.00817205) + (self.vwap * (1 - 0.00817205))),
                    sma(adv60, 9),
                    6,
                )
            )
            < rank((self.best_bid - ts_min(self.best_bid, 14)))
        ) * -1

    def alpha071(self):
        adv180 = sma(self.bid_volume, 180)
        p1 = ts_rank(
            decay_linear(
                correlation(ts_rank(self.mid_price, 3), ts_rank(adv180, 12), 18).to_frame(),
                4,
            ).LWMA,
            16,
        )
        p2 = ts_rank(
            decay_linear(
                (rank(((self.best_bid + self.best_ask) - (self.vwap + self.vwap))).pow(2)).to_frame(),
                16,
            ).LWMA,
            4,
        )
        df = pd.DataFrame({"p1": p1, "p2": p2})
        df.loc[df["p1"] >= df["p2"], "max"] = df["p1"]
        df.loc[df["p2"] >= df["p1"], "max"] = df["p2"]
        return df["max"]

    def alpha072(self):
        adv40 = sma(self.bid_volume, 40)
        return rank(decay_linear(correlation(self.mid_price, adv40, 9).to_frame(), 10).LWMA) / rank(
            decay_linear(
                correlation(ts_rank(self.vwap, 4), ts_rank(self.bid_volume, 19), 7).to_frame(),
                3,
            ).LWMA
        )

    def alpha073(self):
        p1 = rank(decay_linear(df_delta(self.vwap, 5).to_frame(), 3).LWMA)
        p2 = ts_rank(
            decay_linear(
                (
                    (
                        df_delta(
                            ((self.best_ask * 0.147155) + (self.best_bid * (1 - 0.147155))),
                            2,
                        )
                        / ((self.mid_price * 0.147155) + (self.best_bid * (1 - 0.147155)))
                    )
                    * -1
                ).to_frame(),
                3,
            ).LWMA,
            17,
        )
        df = pd.DataFrame({"p1": p1, "p2": p2})
        df.loc[df["p1"] >= df["p2"], "max"] = df["p1"]
        df.loc[df["p2"] >= df["p1"], "max"] = df["p2"]
        return -1 * df["max"]

    def alpha074(self):
        adv30 = sma(self.bid_volume, 30)
        return (
            rank(correlation(self.mid_price, sma(adv30, 37), 15))
            < rank(
                correlation(
                    rank(((self.best_bid * 0.0261661) + (self.vwap * (1 - 0.0261661)))),
                    rank(self.bid_volume),
                    11,
                )
            )
        ) * -1

    def alpha075(self):
        adv50 = sma(self.bid_volume, 50)
        return rank(correlation(self.vwap, self.bid_volume, 4)) < rank(
            correlation(rank(self.best_bid), rank(adv50), 12)
        )

    def alpha076(self):
        adv50 = sma(self.ask_volume, 50)
        return rank(correlation(self.vwap, self.ask_volume, 4)) < rank(
            correlation(rank(self.best_ask), rank(adv50), 12)
        )

    def alpha077(self):
        adv40 = sma(self.ask_volume, 40)
        p1 = rank(
            decay_linear(
                ((self.mid_price + self.best_ask) - (self.vwap + self.best_ask)).to_frame(),
                20,
            ).LWMA
        )
        p2 = rank(decay_linear(correlation(self.mid_price, adv40, 3).to_frame(), 6).LWMA)
        df = pd.DataFrame({"p1": p1, "p2": p2})
        df.loc[df["p1"] >= df["p2"], "min"] = df["p2"]
        df.loc[df["p2"] >= df["p1"], "min"] = df["p1"]
        return df["min"]

    def alpha078(self):
        adv40 = sma(self.bid_volume, 40)
        return rank(
            correlation(
                ts_sum(((self.best_bid * 0.352233) + (self.vwap * (1 - 0.352233))), 20),
                ts_sum(adv40, 20),
                7,
            )
        ).pow(rank(correlation(rank(self.vwap), rank(self.bid_volume), 6)))

    def alpha079(self):
        adv40 = sma(self.ask_volume, 40)
        return rank(
            correlation(
                ts_sum(((self.best_ask * 0.352233) + (self.vwap * (1 - 0.352233))), 20),
                ts_sum(adv40, 20),
                7,
            )
        ).pow(rank(correlation(rank(self.vwap), rank(self.ask_volume), 6)))

    def alpha080(self):
        adv10 = sma(self.bid_volume, 10)
        return (
            rank(
                log(
                    product(
                        rank((rank(correlation(self.vwap, ts_sum(adv10, 50), 8)).pow(4))),
                        15,
                    )
                )
            )
            < rank(correlation(rank(self.vwap), rank(self.bid_volume), 5))
        ) * -1

    def alpha081(self):
        adv10 = sma(self.ask_volume, 10)
        return (
            rank(
                log(
                    product(
                        rank((rank(correlation(self.vwap, ts_sum(adv10, 50), 8)).pow(4))),
                        15,
                    )
                )
            )
            < rank(correlation(rank(self.vwap), rank(self.ask_volume), 5))
        ) * -1

    def alpha082(self):
        adv20 = sma(self.bid_volume, 20)
        return (
            ts_rank(correlation(self.mid_price, sma(adv20, 15), 6), 20)
            < rank(((self.best_bid + self.mid_price) - (self.vwap + self.best_bid)))
        ) * -1

    def alpha083(self):
        return (rank(delay((self.spread / (ts_sum(self.mid_price, 5) / 5)), 2)) * rank(rank(self.bid_volume))) / (
            (self.spread / (ts_sum(self.mid_price, 5) / 5)) / (self.vwap - self.mid_price)
        )

    def alpha084(self):
        return pow(
            ts_rank((self.vwap - ts_max(self.vwap, 15)), 21),
            df_delta(self.mid_price, 5),
        )

    def alpha085(self):
        adv30 = sma(self.ask_volume, 30)
        return rank(
            correlation(
                ((self.best_ask * 0.876703) + (self.mid_price * (1 - 0.876703))),
                adv30,
                10,
            )
        ).pow(rank(correlation(ts_rank(self.mid_price, 4), ts_rank(self.ask_volume, 10), 7)))

    def alpha086(self):
        adv20 = sma(self.ask_volume, 20)
        return (
            ts_rank(correlation(self.mid_price, sma(adv20, 15), 6), 20)
            < rank(((self.best_ask + self.mid_price) - (self.vwap + self.best_ask)))
        ) * -1

    def alpha087(self):
        return -1 * ts_rank(rank(self.best_bid), 9)

    def alpha088(self):
        adv60 = sma(self.ask_volume, 60)
        rank_ask = rank(self.best_ask)
        rank_bid = rank(self.best_bid)
        rank_mid = rank(self.mid_price)
        diff_rank = (rank_ask + rank_bid) - (rank_ask + rank_mid)
        decay_diff_rank = decay_linear(diff_rank.to_frame(), 8).LWMA
        p1 = rank(decay_diff_rank)
        ts_rank_mid = ts_rank(self.mid_price, 8)
        ts_rank_adv60 = ts_rank(adv60, 21)
        corr_ts_rank = correlation(ts_rank_mid, ts_rank_adv60, 8)
        decay_corr_ts_rank = decay_linear(corr_ts_rank.to_frame(), 7).LWMA
        p2 = ts_rank(decay_corr_ts_rank, 3)
        df = pd.DataFrame({"p1": p1, "p2": p2})
        df["min"] = df[["p1", "p2"]].min(axis=1)
        return df["min"]

    def alpha089(self):
        df = -1 * correlation(
            rank(df_delta(log(self.ask_volume + 1), 2)),
            rank((self.mid_price - self.best_ask) / self.best_ask),
            6,
        )
        return df.replace([-np.inf, np.inf], 0).fillna(value=0)

    def alpha090(self):
        return -1 * (
            rank(
                (
                    (ts_sum(self.best_ask, 5) * ts_sum(self.returns, 5))
                    - delay((ts_sum(self.best_ask, 5) * ts_sum(self.returns, 5)), 10)
                )
            )
        )

    def alpha091(self):
        df = correlation(self.best_bid, self.bid_volume, 5)
        df = df.replace([-np.inf, np.inf], 0).fillna(value=0)
        return -1 * df_delta(df, 5) * rank(stddev(self.mid_price, 20))

    def alpha092(self):
        adv30 = sma(self.bid_volume, 30)
        p1 = ts_rank(
            decay_linear(
                ((self.mid_price + self.mid_price) < (self.best_ask + self.best_bid)).to_frame(),
                15,
            ).LWMA,
            19,
        )
        p2 = ts_rank(
            decay_linear(correlation(rank(self.best_bid), rank(adv30), 8).to_frame(), 7).LWMA,
            7,
        )
        df = pd.DataFrame({"p1": p1, "p2": p2})
        df.loc[df["p1"] >= df["p2"], "min"] = df["p2"]
        df.loc[df["p2"] >= df["p1"], "min"] = df["p1"]
        return df["min"]

    def alpha093(self):
        adv60 = sma(self.bid_volume, 60)
        return (
            rank((self.vwap - ts_min(self.vwap, 12))).pow(
                ts_rank(correlation(ts_rank(self.vwap, 20), ts_rank(adv60, 4), 18), 3)
            )
            * -1
        )

    def alpha094(self):
        adv60 = sma(self.ask_volume, 60)
        return (
            rank((self.vwap - ts_min(self.vwap, 12))).pow(
                ts_rank(correlation(ts_rank(self.vwap, 20), ts_rank(adv60, 4), 18), 3)
            )
            * -1
        )

    def alpha095(self):
        adv40 = sma(self.bid_volume, 40)
        return rank((self.best_bid - ts_min(self.best_bid, 12))) < ts_rank(
            (rank(correlation(sma(self.mid_price, 19), sma(adv40, 19), 13)).pow(5)), 12
        )

    def alpha096(self):
        adv60 = sma(self.ask_volume, 60)
        p1 = ts_rank(
            decay_linear(correlation(rank(self.vwap), rank(self.ask_volume).to_frame(), 4), 4).LWMA,
            8,
        )
        p2 = ts_rank(
            decay_linear(
                ts_argmax(correlation(ts_rank(self.mid_price, 7), ts_rank(adv60, 4), 4), 13).to_frame(),
                14,
            ).LWMA,
            13,
        )
        df = pd.DataFrame({"p1": p1, "p2": p2})
        df.loc[df["p1"] >= df["p2"], "max"] = df["p1"]
        df.loc[df["p2"] >= df["p1"], "max"] = df["p2"]
        return -1 * df["max"]

    def alpha097(self):
        adv5 = sma(self.ask_volume, 5)
        adv15 = sma(self.ask_volume, 15)
        return rank(decay_linear(correlation(self.vwap, sma(adv5, 26), 5).to_frame(), 7).LWMA) - rank(
            decay_linear(
                ts_rank(ts_argmin(correlation(rank(self.best_ask), rank(adv15), 21), 9), 7).to_frame(),
                8,
            ).LWMA
        )

    def alpha098(self):
        adv5 = sma(self.bid_volume, 5)
        adv15 = sma(self.bid_volume, 15)
        return rank(decay_linear(correlation(self.vwap, sma(adv5, 26), 5).to_frame(), 7).LWMA) - rank(
            decay_linear(
                ts_rank(ts_argmin(correlation(rank(self.best_bid), rank(adv15), 21), 9), 7).to_frame(),
                8,
            ).LWMA
        )

    def alpha099(self):
        adv60 = sma(self.bid_volume, 60)
        return (
            rank(correlation(ts_sum(self.mid_price, 20), ts_sum(adv60, 20), 9))
            < rank(correlation(self.best_bid, self.bid_volume, 6))
        ) * -1

    def alpha100(self):
        adv60 = sma(self.ask_volume, 60)
        return (
            rank(correlation(ts_sum(self.mid_price, 20), ts_sum(adv60, 20), 9))
            < rank(correlation(self.best_ask, self.ask_volume, 6))
        ) * -1

    def alpha101(self):
        return (self.mid_price - self.best_bid) / (self.spread + 0.001)

# %%
def generate_alpha101_signals(df, output_path=None):
    """
    Generate alpha 101 signals for your aggregated training data

    Args:
        df: DataFrame with your aggregated data
        output_path: Optional path to save the alpha signals

    Returns:
        alpha_signals: numpy array with 101 alpha signals
    """
    print("Initializing TechIndicator...")
    indicator = TechIndicator(df=df)

    alpha_arys = []
    timer0 = time.time()
    timer1 = time.time()

    print("Generating alpha signals...")
    for i in range(1, 102):  # 1 to 101
        try:
            alpha_df = getattr(indicator, f"alpha{i:03}")()
            used_time0 = time.time() - timer0
            used_time1 = time.time() - timer1
            timer1 = time.time()

            print(f"Alpha {i:3d} | Total: {used_time0:4.0f}s | Single: {used_time1:4.0f}s | Shape: {alpha_df.shape} | NaN: {np.isnan(alpha_df.values).sum()}")

            alpha_ary = np.nan_to_num(alpha_df.values, nan=0.0, neginf=0.0, posinf=0.0)
            alpha_arys.append(alpha_ary)

        except Exception as e:
            print(f"Error in alpha{i:03d}: {e}")
            # Create zero array as fallback
            alpha_ary = np.zeros((len(df), 1))
            alpha_arys.append(alpha_ary)

    print("Stacking alpha signals...")
    alpha_arys = np.stack(alpha_arys, axis=1)

    print("Normalizing signals...")
    alpha_arys = normalize_with_quantiles(alpha_arys).astype(np.float16)

    if output_path:
        np.save(output_path, alpha_arys)
        print(f"Saved alpha signals to: {output_path}")

    print(f"Final shape: {alpha_arys.shape}")
    return alpha_arys

# %%
def find_csv_files():
    """Find all CSV files in the data structure"""
    csv_files = []
    timeframes = ['1sec', '1min', '5min']
    splits = ['train', 'valid', 'test']

    for timeframe in timeframes:
        timeframe_path = os.path.join(os.getcwd(), "data", timeframe)
        if os.path.exists(timeframe_path):
            for split in splits:
                # Handle variable parts in filename (test_15, train_70, val_15, etc.)
                if split == 'train':
                    variable_part = '70'  # train_70
                elif split == 'valid':
                    variable_part = '15'  # val_15
                elif split == 'test':
                    variable_part = '15'  # test_15

                filename = f"BTC_{timeframe}_with_sentiment_risk_{split}_{timeframe}_{split}_{variable_part}.csv"
                file_path = os.path.join(timeframe_path, filename)

                if os.path.exists(file_path):
                    csv_files.append({
                        'file_path': file_path,
                        'timeframe': timeframe,
                        'split': split
                    })

    return csv_files

# %%
def find_csv_files_for_timeframe(timeframe):
    """Find all CSV files for a specific timeframe"""
    csv_files = []
    splits = ['train', 'val', 'test']

    timeframe_path = os.path.join(os.getcwd(), "data", timeframe)
    if os.path.exists(timeframe_path):
        for split in splits:
            # Handle variable parts in filename (test_15, train_70, val_15, etc.)
            if split == 'train':
                variable_part = '70'  # train_70
            elif split == 'val':
                variable_part = '15'  # val_15
            elif split == 'test':
                variable_part = '15'  # test_15

            filename = f"BTC_{timeframe}_with_sentiment_risk_train_{timeframe}_{split}_{variable_part}.csv"
            print(filename)
            file_path = os.path.join(timeframe_path, filename)

            if os.path.exists(file_path):
                csv_files.append({
                    'file_path': file_path,
                    'timeframe': timeframe,
                    'split': split
                })

    return csv_files

# %%
def process_timeframe(timeframe):
    """Process all datasets for a specific timeframe"""
    csv_files = find_csv_files_for_timeframe(timeframe)

    if not csv_files:
        print(f"No CSV files found for {timeframe}!")
        return

    print(f"Found {len(csv_files)} CSV files for {timeframe}:")
    for file_info in csv_files:
        print(f"  {file_info['split']}: {os.path.basename(file_info['file_path'])}")

    # Process each file
    for file_info in csv_files:
        print(f"\n{'='*60}")
        print(f"Processing: {timeframe}/{file_info['split']}")
        print(f"File: {file_info['file_path']}")
        print(f"{'='*60}")

        try:
            # Read the CSV file
            print("Reading CSV file...")
            df = pd.read_csv(file_info['file_path'])
            print(f"Data shape: {df.shape}")
            print(f"Columns: {list(df.columns)}")

            # Create output directory
            output_dir = os.path.join("data", file_info['timeframe'], 'alpha101')
            os.makedirs(output_dir, exist_ok=True)

            # Generate output filename
            output_filename = f"alpha101_{file_info['split']}.npy"
            output_path = os.path.join(output_dir, output_filename)

            # Check if already exists
            if os.path.exists(output_path):
                print(f"Alpha signals already exist: {output_path}")
                print("Skipping...")
                continue

            # Generate alpha signals
            alpha_signals = generate_alpha101_signals(df, output_path)

            print(f"✅ Successfully processed {timeframe}/{file_info['split']}")
            print(f"   Input shape: {df.shape}")
            print(f"   Output shape: {alpha_signals.shape}")
            print(f"   Saved to: {output_path}")

        except Exception as e:
            print(f"❌ Error processing {file_info['file_path']}: {e}")
            continue

    print(f"\n{'='*60}")
    print(f"Processing complete for {timeframe}!")
    print(f"Alpha 101 signals have been generated for {timeframe} datasets.")

# %%
def process_1sec():
    """Process 1-second data"""
    process_timeframe('1sec')

def process_1min():
    """Process 1-minute data"""
    process_timeframe('1min')

def process_5min():
    """Process 5-minute data"""
    process_timeframe('5min')

# %%
process_1sec()
# Out:
# BTC_1sec_with_sentiment_risk_train_1sec_train_70.csv
# BTC_1sec_with_sentiment_risk_train_1sec_val_15.csv
# BTC_1sec_with_sentiment_risk_train_1sec_test_15.csv
# Found 3 CSV files for 1sec:
#   train: BTC_1sec_with_sentiment_risk_train_1sec_train_70.csv
#   val: BTC_1sec_with_sentiment_risk_train_1sec_val_15.csv
#   test: BTC_1sec_with_sentiment_risk_train_1sec_test_15.csv
#
# ============================================================
# Processing: 1sec/train
# File: /content/drive/.shortcut-targets-by-id/1UkrVedDO8TczbhiaEZeL-35BAs2icj24/FinRL/final/data/1sec/BTC_1sec_with_sentiment_risk_train_1sec_train_70.csv
# ============================================================
# Reading CSV file...
# Data shape: (346324, 158)
# Columns: ['Unnamed: 0', 'system_time', 'midpoint', 'spread', 'buys', 'sells', 'bids_distance_0', 'bids_distance_1', 'bids_distance_2', 'bids_distance_3', 'bids_distance_4', 'bids_distance_5', 'bids_distance_6', 'bids_distance_7', 'bids_distance_8', 'bids_distance_9', 'bids_distance_10', 'bids_distance_11', 'bids_distance_12', 'bids_distance_13', 'bids_distance_14', 'bids_notional_0', 'bids_notional_1', 'bids_notional_2', 'bids_notional_3', 'bids_notional_4', 'bids_notional_5', 'bids_notional_6', 'bids_notional_7', 'bids_notional_8', 'bids_notional_9', 'bids_notional_10', 'bids_notional_11', 'bids_notional_12', 'bids_notional_13', 'bids_notional_14', 'bids_cancel_notional_0', 'bids_cancel_notional_1', 'bids_cancel_notional_2', 'bids_cancel_notional_3', 'bids_cancel_notional_4', 'bids_cancel_notional_5', 'bids_cancel_notional_6', 'bids_cancel_notional_7', 'bids_cancel_notional_8', 'bids_cancel_notional_9', 'bids_cancel_notional_10', 'bids_cancel_notional_11', 'bids_cancel_notional_12', 'bids_cancel_notional_13', 'bids_cancel_notional_14', 'bids_limit_notional_0', 'bids_limit_notional_1', 'bids_limit_notional_2', 'bids_limit_notional_3', 'bids_limit_notional_4', 'bids_limit_notional_5', 'bids_limit_notional_6', 'bids_limit_notional_7', 'bids_limit_notional_8', 'bids_limit_notional_9', 'bids_limit_notional_10', 'bids_limit_notional_11', 'bids_limit_notional_12', 'bids_limit_notional_13', 'bids_limit_notional_14', 'bids_market_notional_0', 'bids_market_notional_1', 'bids_market_notional_2', 'bids_market_notional_3', 'bids_market_notional_4', 'bids_market_notional_5', 'bids_market_notional_6', 'bids_market_notional_7', 'bids_market_notional_8', 'bids_market_notional_9', 'bids_market_notional_10', 'bids_market_notional_11', 'bids_market_notional_12', 'bids_market_notional_13', 'bids_market_notional_14', 'asks_distance_0', 'asks_distance_1', 'asks_distance_2', 'asks_distance_3', 'asks_distance_4', 'asks_distance_5', 'asks_distance_6', 'asks_distance_7', 'asks_distance_8', 'asks_distance_9', 'asks_distance_10', 'asks_distance_11', 'asks_distance_12', 'asks_distance_13', 'asks_distance_14', 'asks_notional_0', 'asks_notional_1', 'asks_notional_2', 'asks_notional_3', 'asks_notional_4', 'asks_notional_5', 'asks_notional_6', 'asks_notional_7', 'asks_notional_8', 'asks_notional_9', 'asks_notional_10', 'asks_notional_11', 'asks_notional_12', 'asks_notional_13', 'asks_notional_14', 'asks_cancel_notional_0', 'asks_cancel_notional_1', 'asks_cancel_notional_2', 'asks_cancel_notional_3', 'asks_cancel_notional_4', 'asks_cancel_notional_5', 'asks_cancel_notional_6', 'asks_cancel_notional_7', 'asks_cancel_notional_8', 'asks_cancel_notional_9', 'asks_cancel_notional_10', 'asks_cancel_notional_11', 'asks_cancel_notional_12', 'asks_cancel_notional_13', 'asks_cancel_notional_14', 'asks_limit_notional_0', 'asks_limit_notional_1', 'asks_limit_notional_2', 'asks_limit_notional_3', 'asks_limit_notional_4', 'asks_limit_notional_5', 'asks_limit_notional_6', 'asks_limit_notional_7', 'asks_limit_notional_8', 'asks_limit_notional_9', 'asks_limit_notional_10', 'asks_limit_notional_11', 'asks_limit_notional_12', 'asks_limit_notional_13', 'asks_limit_notional_14', 'asks_market_notional_0', 'asks_market_notional_1', 'asks_market_notional_2', 'asks_market_notional_3', 'asks_market_notional_4', 'asks_market_notional_5', 'asks_market_notional_6', 'asks_market_notional_7', 'asks_market_notional_8', 'asks_market_notional_9', 'asks_market_notional_10', 'asks_market_notional_11', 'asks_market_notional_12', 'asks_market_notional_13', 'asks_market_notional_14', 'sentiment_score', 'risk_score']
# Initializing TechIndicator...
# Generating alpha signals...
# Alpha   1 | Total:   67s | Single:   67s | Shape: (346324,) | NaN: 29
# Alpha   2 | Total:  156s | Single:   90s | Shape: (346324,) | NaN: 0
# Alpha   3 | Total:  246s | Single:   90s | Shape: (346324,) | NaN: 0
# Alpha   4 | Total:  373s | Single:  127s | Shape: (346324,) | NaN: 17
# Alpha   5 | Total:  461s | Single:   88s | Shape: (346324,) | NaN: 27
# Alpha   6 | Total:  462s | Single:    0s | Shape: (346324,) | NaN: 0
# Alpha   7 | Total:  545s | Single:   84s | Shape: (346324,) | NaN: 32
# Alpha   8 | Total:  589s | Single:   44s | Shape: (346324,) | NaN: 24
# Alpha   9 | Total:  589s | Single:    0s | Shape: (346324,) | NaN: 5
# Alpha  10 | Total:  589s | Single:    0s | Shape: (346324,) | NaN: 5
# Alpha  11 | Total:  722s | Single:  133s | Shape: (346324,) | NaN: 26
# Alpha  87 | Total: 9249s | Single:  132s | Shape: (346324,) | NaN: 17
# Alpha  88 | Total: 9719s | Single:  471s | Shape: (346324,) | NaN: 2
# Alpha  89 | Total: 9807s | Single:   87s | Shape: (346324,) | NaN: 0
# Alpha  90 | Total: 9851s | Single:   44s | Shape: (346324,) | NaN: 24
# Alpha  91 | Total: 9895s | Single:   44s | Shape: (346324,) | NaN: 46
# Alpha  92 | Total: 10172s | Single:  276s | Shape: (346324,) | NaN: 94449
# Alpha  93 | Total: 10471s | Single:  299s | Shape: (346324,) | NaN: 21425
# Alpha  94 | Total: 10767s | Single:  296s | Shape: (346324,) | NaN: 25202
# Alpha  95 | Total: 10943s | Single:  176s | Shape: (346324,) | NaN: 0
# Alpha  96 | Total: 11373s | Single:  431s | Shape: (346324,) | NaN: 145524
# Alpha  97 | Total: 11659s | Single:  285s | Shape: (346324,) | NaN: 286872
# Alpha  98 | Total: 11946s | Single:  287s | Shape: (346324,) | NaN: 279441
# Alpha  99 | Total: 12028s | Single:   82s | Shape: (346324,) | NaN: 0
# Alpha 100 | Total: 12109s | Single:   81s | Shape: (346324,) | NaN: 0
# Alpha 101 | Total: 12109s | Single:    0s | Shape: (346324,) | NaN: 3
# Stacking alpha signals...
# Normalizing signals...
# Saved alpha signals to: data/1sec/alpha101/alpha101_train.npy
# Final shape: (346324, 101)
# ✅ Successfully processed 1sec/train
#    Input shape: (346324, 158)
#    Output shape: (346324, 101)
#    Saved to: data/1sec/alpha101/alpha101_train.npy
#
# ============================================================
# Processing: 1sec/val
# File: /content/drive/.shortcut-targets-by-id/1UkrVedDO8TczbhiaEZeL-35BAs2icj24/FinRL/final/data/1sec/BTC_1sec_with_sentiment_risk_train_1sec_val_15.csv
# ============================================================
# Reading CSV file...
# Data shape: (74212, 158)
# Columns: ['Unnamed: 0', 'system_time', 'midpoint', 'spread', 'buys', 'sells', 'bids_distance_0', 'bids_distance_1', 'bids_distance_2', 'bids_distance_3', 'bids_distance_4', 'bids_distance_5', 'bids_distance_6', 'bids_distance_7', 'bids_distance_8', 'bids_distance_9', 'bids_distance_10', 'bids_distance_11', 'bids_distance_12', 'bids_distance_13', 'bids_distance_14', 'bids_notional_0', 'bids_notional_1', 'bids_notional_2', 'bids_notional_3', 'bids_notional_4', 'bids_notional_5', 'bids_notional_6', 'bids_notional_7', 'bids_notional_8', 'bids_notional_9', 'bids_notional_10', 'bids_notional_11', 'bids_notional_12', 'bids_notional_13', 'bids_notional_14', 'bids_cancel_notional_0', 'bids_cancel_notional_1', 'bids_cancel_notional_2', 'bids_cancel_notional_3', 'bids_cancel_notional_4', 'bids_cancel_notional_5', 'bids_cancel_notional_6', 'bids_cancel_notional_7', 'bids_cancel_notional_8', 'bids_cancel_notional_9', 'bids_cancel_notional_10', 'bids_cancel_notional_11', 'bids_cancel_notional_12', 'bids_cancel_notional_13', 'bids_cancel_notional_14', 'bids_limit_notional_0', 'bids_limit_notional_1', 'bids_limit_notional_2', 'bids_limit_notional_3', 'bids_limit_notional_4', 'bids_limit_notional_5', 'bids_limit_notional_6', 'bids
# Alpha   9 | Total:  132s | Single:    0s | Shape: (74212,) | NaN: 17
# Alpha  10 | Total:  132s | Single:    0s | Shape: (74212,) | NaN: 17
# Alpha  11 | Total:  161s | Single:   29s | Shape: (74212,) | NaN: 27
# Alpha  12 | Total:  161s | Single:    0s | Shape: (74212,) | NaN: 17
# Alpha  13 | Total:  191s | Single:   30s | Shape: (74212,) | NaN: 38
# Alpha  14 | Total:  202s | Single:   11s | Shape: (74212,) | NaN: 13
# Alpha  15 | Total:  231s | Single:   29s | Shape: (74212,) | NaN: 11
# Alpha  16 | Total:  260s | Single:   29s | Shape: (74212,) | NaN: 38
# Alpha  17 | Total:  326s | Single:   66s | Shape: (74212,) | NaN: 34
# Alpha  18 | Total:  336s | Single:    9s | Shape: (74212,) | NaN: 29
# Alpha  19 | Total:  345s | Single:    9s | Shape: (74212,) | NaN: 259
# Alpha  20 | Total:  373s | Single:   28s | Shape: (74212,) | NaN: 26
# Alpha  21 | Total:  373s | Single:    0s | Shape: (74212,) | NaN: 0
# Alpha  22 | Total:  383s | Single:   10s | Shape: (74212,) | NaN: 44
# Alpha  23 | Total:  383s | Single:    0s | Shape: (74212,) | NaN: 0
# Alpha  24 | Total:  383s | Single:    0s | Shape: (74212,) | NaN: 17
# Alpha  25 | Total:  392s | Single:    9s | Shape: (74212,) | NaN: 28
# Alpha  26 | Total:  430s | Single:   38s | Shape: (74212,) | NaN: 2
# Alpha  27 | Total:  459s | Single:   29s | Shape: (74212,) | NaN: 4246
# Alpha  28 | Total:  459s | Single:    0s | Shape: (74212,) | NaN: 446
# Alpha  29 | Total:  516s | Single:   57s | Shape: (74212,) | NaN: 62
# Alpha  30 | Total:  526s | Single:   10s | Shape: (74212,) | NaN: 28
# Alpha  31 | Total:  588s | Single:   61s | Shape: (74212,) | NaN: 169
# Alpha  32 | Total:  588s | Single:    0s | Shape: (74212,) | NaN: 250
# Alpha  33 | Total:  598s | Single:   10s | Shape: (74212,) | NaN: 25
# Alpha  34 | Total:  630s | Single:   33s | Shape: (74212,) | NaN: 35
# Alpha  35 | Total:  686s | Single:   55s | Shape: (74212,) | NaN: 32
# Alpha  36 | Total:  744s | Single:   59s | Shape: (74212,) | NaN: 51491
# Alpha  37 | Total:  764s | Single:   20s | Shape: (74212,) | NaN: 225
# Alpha  38 | Total:  801s | Single:   37s | Shape: (74212,) | NaN: 18
# Alpha  39 | Total:  833s | Single:   32s | Shape: (74212,) | NaN: 259
# Alpha  40 | Total:  843s | Single:   10s | Shape: (74212,) | NaN: 1936
# Alpha  41 | Total:  843s | Single:    0s | Shape: (74212,) | NaN: 0
# Alpha  42 | Total:  863s | Single:   20s | Shape: (74212,) | NaN: 25
# Alpha  43 | Total:  903s | Single:   40s | Shape: (74212,) | NaN: 38
# Alpha  44 | Total:  913s | Single:   11s | Shape: (74212,) | NaN: 0
# Alpha  45 | Total:  925s | Single:   12s | Shape: (74212,) | NaN: 60638
# Alpha  46 | Total:  925s | Single:    0s | Shape: (74212,) | NaN: 17
# Alpha  47 | Total:  955s | Single:   29s | Shape: (74212,) | NaN: 25
# Alpha  86 | Total: 1981s | Single:   21s | Shape: (74212,) | NaN: 0
# Alpha  87 | Total: 2009s | Single:   29s | Shape: (74212,) | NaN: 17
# Alpha  88 | Total: 2109s | Single:  100s | Shape: (74212,) | NaN: 2
# Alpha  89 | Total: 2129s | Single:   20s | Shape: (74212,) | NaN: 0
# Alpha  90 | Total: 2138s | Single:    9s | Shape: (74212,) | NaN: 24
# Alpha  91 | Total: 2148s | Single:   10s | Shape: (74212,) | NaN: 44
# Alpha  92 | Total: 2206s | Single:   58s | Shape: (74212,) | NaN: 19114
# Alpha  93 | Total: 2269s | Single:   63s | Shape: (74212,) | NaN: 4033
# Alpha  94 | Total: 2330s | Single:   61s | Shape: (74212,) | NaN: 4991
# Alpha  95 | Total: 2366s | Single:   36s | Shape: (74212,) | NaN: 0
# Alpha  96 | Total: 2459s | Single:   92s | Shape: (74212,) | NaN: 29688
# Alpha  97 | Total: 2520s | Single:   61s | Shape: (74212,) | NaN: 60215
# Alpha  98 | Total: 2579s | Single:   60s | Shape: (74212,) | NaN: 62436
# Alpha  99 | Total: 2596s | Single:   17s | Shape: (74212,) | NaN: 0
# Alpha 100 | Total: 2612s | Single:   16s | Shape: (74212,) | NaN: 0
# Alpha 101 | Total: 2612s | Single:    0s | Shape: (74212,) | NaN: 12
# Stacking alpha signals...
# Normalizing signals...
# Saved alpha signals to: data/1sec/alpha101/alpha101_val.npy
# Final shape: (74212, 101)
# ✅ Successfully processed 1sec/val
#    Input shape: (74212, 158)
#    Output shape: (74212, 101)
#    Saved to: data/1sec/alpha101/alpha101_val.npy
#
# ============================================================
# Processing: 1sec/test
# File: /content/drive/.shortcut-targets-by-id/1UkrVedDO8TczbhiaEZeL-35BAs2icj24/FinRL/final/data/1sec/BTC_1sec_with_sentiment_risk_train_1sec_test_15.csv
# ============================================================
# Reading CSV file...
# Data shape: (74213, 158)
# Columns: ['Unnamed: 0', 'system_time', 'midpoint', 'spread', 'buys', 'sells', 'bids_distance_0', 'bids_distance_1', 'bids_distance_2', 'bids_distance_3', 'bids_distance_4', 'bids_distance_5', 'bids_distance_6', 'bids_distance_7', 'bids_distance_8', 'bids_distance_9', 'bids_distance_10', 'bids_distance_11', 'bids_distance_12', 'bids_distance_13', 'bids_distance_14', 'bids_notional_0', 'bids_notional_1', 'bids_notional_2', 'bids_notional_3', 'bids_notional_4', 'bids_notional_5', 'bids_notional_6', 'bids_notional_7', 'bids_notional_8', 'bids_notional_9', 'bids_notional_10', 'bids_notional_11', 'bids_notional_12', 'bids_notional_13', 'bids_notional_14', 'bids_cancel_notional_0', 'bids_cancel_notional_1', 'bids_cancel_notional_2', 'bids_cancel_notional_3', 'bids_cancel_notional_4', 'bids_cancel_notional_5', 'bids_cancel_notional_6', 'bids_cancel_notional_7', 'bids_cancel_notional_8', 'bids_cancel_notional_9', 'bids_cancel_notional_10', 'bids_cancel_notional_11', 'bids_cancel_notional_12', 'bids_cancel_notional_13', 'bids_cancel_notional_14', 'bids_limit_notional_0', 'bids_lim
# Alpha   8 | Total:  126s | Single:   10s | Shape: (74213,) | NaN: 24
# Alpha   9 | Total:  126s | Single:    0s | Shape: (74213,) | NaN: 18
# Alpha  10 | Total:  126s | Single:    0s | Shape: (74213,) | NaN: 18
# Alpha  11 | Total:  154s | Single:   28s | Shape: (74213,) | NaN: 29
# Alpha  12 | Total:  154s | Single:    0s | Shape: (74213,) | NaN: 18
# Alpha  13 | Total:  182s | Single:   28s | Shape: (74213,) | NaN: 40
# Alpha  14 | Total:  190s | Single:    9s | Shape: (74213,) | NaN: 13
# Alpha  15 | Total:  218s | Single:   28s | Shape: (74213,) | NaN: 11
# Alpha  16 | Total:  246s | Single:   28s | Shape: (74213,) | NaN: 40
# Alpha  17 | Total:  312s | Single:   65s | Shape: (74213,) | NaN: 36
# Alpha  18 | Total:  321s | Single:   10s | Shape: (74213,) | NaN: 31
# Alpha  19 | Total:  330s | Single:    8s | Shape: (74213,) | NaN: 259
# Alpha  20 | Total:  358s | Single:   28s | Shape: (74213,) | NaN: 28
# Alpha  21 | Total:  358s | Single:    0s | Shape: (74213,) | NaN: 0
# Alpha  22 | Total:  367s | Single:    9s | Shape: (74213,) | NaN: 46
# Alpha  23 | Total:  367s | Single:    0s | Shape: (74213,) | NaN: 0
# Alpha  24 | Total:  367s | Single:    0s | Shape: (74213,) | NaN: 18
# Alpha  25 | Total:  377s | Single:   10s | Shape: (74213,) | NaN: 28
# Alpha  26 | Total:  412s | Single:   35s | Shape: (74213,) | NaN: 2
# Alpha  27 | Total:  440s | Single:   28s | Shape: (74213,) | NaN: 5371
# Alpha  28 | Total:  440s | Single:    0s | Shape: (74213,) | NaN: 968
# Alpha  29 | Total:  496s | Single:   56s | Shape: (74213,) | NaN: 64
# Alpha  30 | Total:  506s | Single:   10s | Shape: (74213,) | NaN: 30
# Alpha  31 | Total:  566s | Single:   60s | Shape: (74213,) | NaN: 424
# Alpha  32 | Total:  566s | Single:    0s | Shape: (74213,) | NaN: 252
# Alpha  33 | Total:  577s | Single:   10s | Shape: (74213,) | NaN: 27
# Alpha  34 | Total:  606s | Single:   29s | Shape: (74213,) | NaN: 37
# Alpha  35 | Total:  660s | Single:   54s | Shape: (74213,) | NaN: 33
# Alpha  36 | Total:  719s | Single:   60s | Shape: (74213,) | NaN: 50466
# Alpha  37 | Total:  739s | Single:   20s | Shape: (74213,) | NaN: 227
# Alpha  38 | Total:  775s | Single:   36s | Shape: (74213,) | NaN: 18
# Alpha  39 | Total:  808s | Single:   33s | Shape: (74213,) | NaN: 259
# Alpha  40 | Total:  817s | Single:    9s | Shape: (74213,) | NaN: 2519
# Alpha  41 | Total:  817s | Single:    0s | Shape: (74213,) | NaN: 0
# Alpha  42 | Total:  836s | Single:   20s | Shape: (74213,) | NaN: 27
# Alpha  43 | Total:  872s | Single:   36s | Shape: (74213,) | NaN: 38
# Alpha  44 | Total:  882s | Single:   10s | Shape: (74213,) | NaN: 0
# Alpha  45 | Total:  894s | Single:   12s | Shape: (74213,) | NaN: 55817
# Alpha  84 | Total: 1876s | Single:   17s | Shape: (74213,) | NaN: 34
# Alpha  85 | Total: 1928s | Single:   53s | Shape: (74213,) | NaN: 9171
# Alpha  86 | Total: 1952s | Single:   24s | Shape: (74213,) | NaN: 0
# Alpha  87 | Total: 1980s | Single:   28s | Shape: (74213,) | NaN: 17
# Alpha  88 | Total: 2081s | Single:  101s | Shape: (74213,) | NaN: 2
# Alpha  89 | Total: 2100s | Single:   19s | Shape: (74213,) | NaN: 0
# Alpha  90 | Total: 2110s | Single:    9s | Shape: (74213,) | NaN: 24
# Alpha  91 | Total: 2119s | Single:   10s | Shape: (74213,) | NaN: 46
# Alpha  92 | Total: 2178s | Single:   59s | Shape: (74213,) | NaN: 19719
# Alpha  93 | Total: 2242s | Single:   63s | Shape: (74213,) | NaN: 5162
# Alpha  94 | Total: 2305s | Single:   63s | Shape: (74213,) | NaN: 6016
# Alpha  95 | Total: 2343s | Single:   38s | Shape: (74213,) | NaN: 0
# Alpha  96 | Total: 2434s | Single:   92s | Shape: (74213,) | NaN: 30811
# Alpha  97 | Total: 2495s | Single:   61s | Shape: (74213,) | NaN: 59113
# Alpha  98 | Total: 2556s | Single:   61s | Shape: (74213,) | NaN: 58523
# Alpha  99 | Total: 2573s | Single:   17s | Shape: (74213,) | NaN: 0
# Alpha 100 | Total: 2589s | Single:   17s | Shape: (74213,) | NaN: 0
# Alpha 101 | Total: 2589s | Single:    0s | Shape: (74213,) | NaN: 9
# Stacking alpha signals...
# Normalizing signals...
# Saved alpha signals to: data/1sec/alpha101/alpha101_test.npy
# Final shape: (74213, 101)
# ✅ Successfully processed 1sec/test
#    Input shape: (74213, 158)
#    Output shape: (74213, 101)
#    Saved to: data/1sec/alpha101/alpha101_test.npy
#
# ============================================================
# Processing complete for 1sec!
# Alpha 101 signals have been generated for 1sec datasets.

# %%
process_1min()
# Out:
# BTC_1min_with_sentiment_risk_train_1min_train_70.csv
# BTC_1min_with_sentiment_risk_train_1min_val_15.csv
# BTC_1min_with_sentiment_risk_train_1min_test_15.csv
# Found 3 CSV files for 1min:
#   train: BTC_1min_with_sentiment_risk_train_1min_train_70.csv
#   val: BTC_1min_with_sentiment_risk_train_1min_val_15.csv
#   test: BTC_1min_with_sentiment_risk_train_1min_test_15.csv
#
# ============================================================
# Processing: 1min/train
# File: /content/drive/.shortcut-targets-by-id/1UkrVedDO8TczbhiaEZeL-35BAs2icj24/FinRL/final/data/1min/BTC_1min_with_sentiment_risk_train_1min_train_70.csv
# ============================================================
# Reading CSV file...
# Data shape: (5774, 158)
# Columns: ['system_time', 'midpoint', 'spread', 'buys', 'sells', 'bids_distance_0', 'asks_distance_0', 'bids_distance_1', 'asks_distance_1', 'bids_distance_2', 'asks_distance_2', 'bids_distance_3', 'asks_distance_3', 'bids_distance_4', 'asks_distance_4', 'bids_distance_5', 'asks_distance_5', 'bids_distance_6', 'asks_distance_6', 'bids_distance_7', 'asks_distance_7', 'bids_distance_8', 'asks_distance_8', 'bids_distance_9', 'asks_distance_9', 'bids
# Initializing TechIndicator...
# Generating alpha signals...
# Alpha   1 | Total:    1s | Single:    1s | Shape: (5774,) | NaN: 30
# Alpha   2 | Total:    3s | Single:    2s | Shape: (5774,) | NaN: 0
# Alpha   3 | Total:    5s | Single:    2s | Shape: (5774,) | NaN: 0
# Alpha   4 | Total:    7s | Single:    2s | Shape: (5774,) | NaN: 17
# Alpha   5 | Total:    8s | Single:    1s | Shape: (5774,) | NaN: 26
# Alpha   6 | Total:    8s | Single:    0s | Shape: (5774,) | NaN: 0
# Alpha   7 | Total:   10s | Single:    1s | Shape: (5774,) | NaN: 39
# Alpha   8 | Total:   10s | Single:    1s | Shape: (5774,) | NaN: 24
# Alpha   9 | Total:   10s | Single:    0s | Shape: (5774,) | NaN: 13
# Alpha  10 | Total:   10s | Single:    0s | Shape: (5774,) | NaN: 13
# Alpha  11 | Total:   13s | Single:    2s | Shape: (5774,) | NaN: 28
# Alpha  12 | Total:   13s | Single:    0s | Shape: (5774,) | NaN: 13
# Alpha  13 | Total:   15s | Single:    2s | Shape: (5774,) | NaN: 39
# Alpha  14 | Total:   16s | Single:    1s | Shape: (5774,) | NaN: 13
# Alpha  15 | Total:   18s | Single:    3s | Shape: (5774,) | NaN: 11
# Alpha  16 | Total:   21s | Single:    2s | Shape: (5774,) | NaN: 39
# Alpha  17 | Total:   25s | Single:    5s | Shape: (5774,) | NaN: 35
# Alpha  18 | Total:   26s | Single:    1s | Shape: (5774,) | NaN: 30
# Alpha  19 | Total:   27s | Single:    1s | Shape: (5774,) | NaN: 259
# Alpha  20 | Total:   29s | Single:    2s | Shape: (5774,) | NaN: 27
# Alpha  21 | Total:   29s | Single:    0s | Shape: (5774,) | NaN: 0
# Alpha  22 | Total:   30s | Single:    1s | Shape: (5774,) | NaN: 45
# Alpha  23 | Total:   30s | Single:    0s | Shape: (5774,) | NaN: 0
# Alpha  24 | Total:   30s | Single:    0s | Shape: (5774,) | NaN: 15
# Alpha  25 | Total:   31s | Single:    1s | Shape: (5774,) | NaN: 28
# Alpha  26 | Total:   34s | Single:    3s | Shape: (5774,) | NaN: 2
# Alpha  27 | Total:   36s | Single:    2s | Shape: (5774,) | NaN: 866
# Alpha  28 | Total:   36s | Single:    0s | Shape: (5774,) | NaN: 23
# Alpha  29 | Total:   40s | Single:    4s | Shape: (5774,) | NaN: 63
# Alpha  30 | Total:   41s | Single:    1s | Shape: (5774,) | NaN: 29
# Alpha  31 | Total:   46s | Single:    5s | Shape: (5774,) | NaN: 30
# Alpha  32 | Total:   46s | Single:    0s | Shape: (5774,) | NaN: 251
# Alpha  33 | Total:   47s | Single:    1s | Shape: (5774,) | NaN: 26
# Alpha  34 | Total:   49s | Single:    2s | Shape: (5774,) | NaN: 36
# Alpha  35 | Total:   53s | Single:    4s | Shape: (5774,) | NaN: 32
# Alpha  36 | Total:   58s | Single:    5s | Shape: (5774,) | NaN: 225
# Alpha  37 | Total:   60s | Single:    2s | Shape: (5774,) | NaN: 226
# Alpha  38 | Total:   63s | Single:    3s | Shape: (5774,) | NaN: 18
# Alpha  39 | Total:   65s | Single:    3s | Shape: (5774,) | NaN: 259
# Alpha  40 | Total:   66s | Single:    1s | Shape: (5774,) | NaN: 18
# Alpha  41 | Total:   66s | Single:    0s | Shape: (5774,) | NaN: 0
# Alpha  42 | Total:   67s | Single:    1s | Shape: (5774,) | NaN: 26
# Alpha  43 | Total:   70s | Single:    3s | Shape: (5774,) | NaN: 38
# Alpha  44 | Total:   71s | Single:    1s | Shape: (5774,) | NaN: 0
# Alpha  45 | Total:   72s | Single:    1s | Shape: (5774,) | NaN: 5019
# Alpha  46 | Total:   72s | Single:    0s | Shape: (5774,) | NaN: 13
# Alpha  47 | Total:   75s | Single:    3s | Shape: (5774,) | NaN: 26
# Alpha  48 | Total:   77s | Single:    2s | Shape: (5774,) | NaN: 26
# Alpha  49 | Total:   77s | Single:    0s | Shape: (5774,) | NaN: 13
# Alpha  50 | Total:   79s | Single:    2s | Shape: (5774,) | NaN: 1797
# Alpha  51 | Total:   79s | Single:    0s | Shape: (5774,) | NaN: 13
# Alpha  52 | Total:   81s | Single:    2s | Shape: (5774,) | NaN: 249
# Alpha  53 | Total:   81s | Single:    0s | Shape: (5774,) | NaN: 20
# Alpha  54 | Total:   81s | Single:    0s | Shape: (5774,) | NaN: 8
# Alpha  55 | Total:   82s | Single:    1s | Shape: (5774,) | NaN: 0
# Alpha  56 | Total:   82s | Single:    0s | Shape: (5774,) | NaN: 8
# Alpha  57 | Total:   83s | Single:    1s | Shape: (5774,) | NaN: 8
# Alpha  58 | Total:   83s | Single:    0s | Shape: (5774,) | NaN: 13
# Alpha  59 | Total:   85s | Single:    2s | Shape: (5774,) | NaN: 35
# Alpha  60 | Total:   87s | Single:    2s | Shape: (5774,) | NaN: 35
# Alpha  61 | Total:   89s | Single:    2s | Shape: (5774,) | NaN: 0
# Alpha  62 | Total:   93s | Single:    4s | Shape: (5774,) | NaN: 58
# Alpha  63 | Total:   94s | Single:    1s | Shape: (5774,) | NaN: 156
# Alpha  64 | Total:   96s | Single:    1s | Shape: (5774,) | NaN: 0
# Alpha  65 | Total:   97s | Single:    1s | Shape: (5774,) | NaN: 0
# Alpha  66 | Total:   99s | Single:    3s | Shape: (5774,) | NaN: 9
# Alpha  67 | Total:  103s | Single:    4s | Shape: (5774,) | NaN: 0
# Alpha  68 | Total:  106s | Single:    3s | Shape: (5774,) | NaN: 0
# Alpha  69 | Total:  108s | Single:    1s | Shape: (5774,) | NaN: 0
# Alpha  70 | Total:  109s | Single:    1s | Shape: (5774,) | NaN: 0
# Alpha  71 | Total:  117s | Single:    7s | Shape: (5774,) | NaN: 34
# Alpha  72 | Total:  121s | Single:    5s | Shape: (5774,) | NaN: 9
# Alpha  73 | Total:  124s | Single:    3s | Shape: (5774,) | NaN: 16
# Alpha  74 | Total:  127s | Single:    3s | Shape: (5774,) | NaN: 0
# Alpha  75 | Total:  131s | Single:    4s | Shape: (5774,) | NaN: 0
# Alpha  76 | Total:  133s | Single:    3s | Shape: (5774,) | NaN: 0
# Alpha  77 | Total:  135s | Single:    2s | Shape: (5774,) | NaN: 9
# Alpha  78 | Total:  138s | Single:    3s | Shape: (5774,) | NaN: 746
# Alpha  79 | Total:  141s | Single:    3s | Shape: (5774,) | NaN: 716
# Alpha  80 | Total:  146s | Single:    5s | Shape: (5774,) | NaN: 0
# Alpha  81 | Total:  150s | Single:    4s | Shape: (5774,) | NaN: 0
# Alpha  82 | Total:  152s | Single:    2s | Shape: (5774,) | NaN: 0
# Alpha  83 | Total:  154s | Single:    2s | Shape: (5774,) | NaN: 32
# Alpha  84 | Total:  156s | Single:    2s | Shape: (5774,) | NaN: 34
# Alpha  85 | Total:  160s | Single:    5s | Shape: (5774,) | NaN: 536
# Alpha  86 | Total:  162s | Single:    2s | Shape: (5774,) | NaN: 0
# Alpha  87 | Total:  164s | Single:    2s | Shape: (5774,) | NaN: 17
# Alpha  88 | Total:  172s | Single:    8s | Shape: (5774,) | NaN: 2
# Alpha  89 | Total:  174s | Single:    2s | Shape: (5774,) | NaN: 0
# Alpha  90 | Total:  175s | Single:    1s | Shape: (5774,) | NaN: 24
# Alpha  91 | Total:  175s | Single:    1s | Shape: (5774,) | NaN: 45
# Alpha  92 | Total:  180s | Single:    4s | Shape: (5774,) | NaN: 997
# Alpha  93 | Total:  185s | Single:    5s | Shape: (5774,) | NaN: 123
# Alpha  94 | Total:  190s | Single:    5s | Shape: (5774,) | NaN: 88
# Alpha  95 | Total:  193s | Single:    3s | Shape: (5774,) | NaN: 0
# Alpha  96 | Total:  200s | Single:    7s | Shape: (5774,) | NaN: 2258
# Alpha  97 | Total:  205s | Single:    6s | Shape: (5774,) | NaN: 9
# Alpha  98 | Total:  211s | Single:    5s | Shape: (5774,) | NaN: 9
# Alpha  99 | Total:  212s | Single:    2s | Shape: (5774,) | NaN: 0
# Alpha 100 | Total:  214s | Single:    2s | Shape: (5774,) | NaN: 0
# Alpha 101 | Total:  214s | Single:    0s | Shape: (5774,) | NaN: 8
# Stacking alpha signals...
# Normalizing signals...
# Saved alpha signals to: data/1min/alpha101/alpha101_train.npy
# Final shape: (5774, 101)
# ✅ Successfully processed 1min/train
#    Input shape: (5774, 158)
#    Output shape: (5774, 101)
#    Saved to: data/1min/alpha101/alpha101_train.npy
#
# ============================================================
# Processing: 1min/val
# File: /content/drive/.shortcut-targets-by-id/1UkrVedDO8TczbhiaEZeL-35BAs2icj24/FinRL/final/data/1min/BTC_1min_with_sentiment_risk_train_1min_val_15.csv
# ============================================================
# Reading CSV file...
# Data shape: (1237, 158)
# Columns: ['system_time', 'midpoint', 'spread', 'buys', 'sells', 'bids_distance_0', 'asks_distance_0', 'bids_distance_1', 'asks_distance_1', 'bids_distance_2', 'asks_distance_2', 'bids_distance_3', 'asks_distance_3', 'bids_distance_4', 'asks_distance_4', 'bids_distance_5', 'asks_distance_5', 'bids_distance_6', 'asks_distance_6', 'bids_distance_7', 'asks_distance_7', 'bids_distance_8', 'asks_distance_8', 'bids_distance_9', 'asks_distance_9', 'bids_
# Initializing TechIndicator...
# Generating alpha signals...
# Alpha   1 | Total:    0s | Single:    0s | Shape: (1237,) | NaN: 31
# Alpha   2 | Total:    0s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha   3 | Total:    1s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha   4 | Total:    1s | Single:    0s | Shape: (1237,) | NaN: 17
# Alpha   5 | Total:    2s | Single:    0s | Shape: (1237,) | NaN: 27
# Alpha   6 | Total:    2s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha   7 | Total:    2s | Single:    0s | Shape: (1237,) | NaN: 42
# Alpha   8 | Total:    2s | Single:    0s | Shape: (1237,) | NaN: 24
# Alpha   9 | Total:    2s | Single:    0s | Shape: (1237,) | NaN: 13
# Alpha  10 | Total:    2s | Single:    0s | Shape: (1237,) | NaN: 13
# Alpha  11 | Total:    2s | Single:    0s | Shape: (1237,) | NaN: 29
# Alpha  12 | Total:    2s | Single:    0s | Shape: (1237,) | NaN: 13
# Alpha  13 | Total:    3s | Single:    0s | Shape: (1237,) | NaN: 40
# Alpha  14 | Total:    3s | Single:    0s | Shape: (1237,) | NaN: 13
# Alpha  15 | Total:    3s | Single:    0s | Shape: (1237,) | NaN: 11
# Alpha  16 | Total:    4s | Single:    0s | Shape: (1237,) | NaN: 40
# Alpha  17 | Total:    5s | Single:    1s | Shape: (1237,) | NaN: 36
# Alpha  18 | Total:    5s | Single:    0s | Shape: (1237,) | NaN: 31
# Alpha  19 | Total:    5s | Single:    0s | Shape: (1237,) | NaN: 259
# Alpha  20 | Total:    5s | Single:    0s | Shape: (1237,) | NaN: 28
# Alpha  21 | Total:    5s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha  22 | Total:    5s | Single:    0s | Shape: (1237,) | NaN: 46
# Alpha  23 | Total:    5s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha  24 | Total:    5s | Single:    0s | Shape: (1237,) | NaN: 16
# Alpha  25 | Total:    6s | Single:    0s | Shape: (1237,) | NaN: 28
# Alpha  26 | Total:    6s | Single:    1s | Shape: (1237,) | NaN: 2
# Alpha  27 | Total:    7s | Single:    0s | Shape: (1237,) | NaN: 182
# Alpha  28 | Total:    7s | Single:    0s | Shape: (1237,) | NaN: 23
# Alpha  29 | Total:    7s | Single:    1s | Shape: (1237,) | NaN: 64
# Alpha  30 | Total:    8s | Single:    0s | Shape: (1237,) | NaN: 30
# Alpha  31 | Total:    9s | Single:    1s | Shape: (1237,) | NaN: 30
# Alpha  32 | Total:    9s | Single:    0s | Shape: (1237,) | NaN: 252
# Alpha  33 | Total:    9s | Single:    0s | Shape: (1237,) | NaN: 27
# Alpha  34 | Total:    9s | Single:    0s | Shape: (1237,) | NaN: 37
# Alpha  35 | Total:   10s | Single:    1s | Shape: (1237,) | NaN: 33
# Alpha  36 | Total:   11s | Single:    1s | Shape: (1237,) | NaN: 226
# Alpha  37 | Total:   11s | Single:    0s | Shape: (1237,) | NaN: 227
# Alpha  38 | Total:   12s | Single:    1s | Shape: (1237,) | NaN: 18
# Alpha  39 | Total:   13s | Single:    1s | Shape: (1237,) | NaN: 259
# Alpha  40 | Total:   13s | Single:    0s | Shape: (1237,) | NaN: 18
# Alpha  41 | Total:   13s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha  42 | Total:   13s | Single:    0s | Shape: (1237,) | NaN: 27
# Alpha  43 | Total:   14s | Single:    1s | Shape: (1237,) | NaN: 38
# Alpha  44 | Total:   14s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha  45 | Total:   14s | Single:    0s | Shape: (1237,) | NaN: 947
# Alpha  46 | Total:   14s | Single:    0s | Shape: (1237,) | NaN: 13
# Alpha  47 | Total:   15s | Single:    0s | Shape: (1237,) | NaN: 27
# Alpha  48 | Total:   15s | Single:    0s | Shape: (1237,) | NaN: 27
# Alpha  49 | Total:   15s | Single:    0s | Shape: (1237,) | NaN: 13
# Alpha  50 | Total:   16s | Single:    0s | Shape: (1237,) | NaN: 330
# Alpha  51 | Total:   16s | Single:    0s | Shape: (1237,) | NaN: 13
# Alpha  52 | Total:   16s | Single:    0s | Shape: (1237,) | NaN: 249
# Alpha  53 | Total:   16s | Single:    0s | Shape: (1237,) | NaN: 21
# Alpha  54 | Total:   16s | Single:    0s | Shape: (1237,) | NaN: 8
# Alpha  55 | Total:   16s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha  56 | Total:   16s | Single:    0s | Shape: (1237,) | NaN: 8
# Alpha  57 | Total:   17s | Single:    0s | Shape: (1237,) | NaN: 8
# Alpha  58 | Total:   17s | Single:    0s | Shape: (1237,) | NaN: 13
# Alpha  59 | Total:   17s | Single:    0s | Shape: (1237,) | NaN: 36
# Alpha  60 | Total:   17s | Single:    0s | Shape: (1237,) | NaN: 36
# Alpha  61 | Total:   18s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha  62 | Total:   19s | Single:    1s | Shape: (1237,) | NaN: 58
# Alpha  63 | Total:   19s | Single:    0s | Shape: (1237,) | NaN: 156
# Alpha  64 | Total:   19s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha  65 | Total:   19s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha  66 | Total:   20s | Single:    1s | Shape: (1237,) | NaN: 9
# Alpha  67 | Total:   21s | Single:    1s | Shape: (1237,) | NaN: 0
# Alpha  68 | Total:   21s | Single:    1s | Shape: (1237,) | NaN: 0
# Alpha  69 | Total:   22s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha  70 | Total:   22s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha  71 | Total:   23s | Single:    1s | Shape: (1237,) | NaN: 15
# Alpha  72 | Total:   24s | Single:    1s | Shape: (1237,) | NaN: 9
# Alpha  73 | Total:   25s | Single:    1s | Shape: (1237,) | NaN: 16
# Alpha  74 | Total:   26s | Single:    1s | Shape: (1237,) | NaN: 0
# Alpha  75 | Total:   27s | Single:    1s | Shape: (1237,) | NaN: 0
# Alpha  76 | Total:   27s | Single:    1s | Shape: (1237,) | NaN: 0
# Alpha  77 | Total:   28s | Single:    1s | Shape: (1237,) | NaN: 9
# Alpha  78 | Total:   29s | Single:    1s | Shape: (1237,) | NaN: 156
# Alpha  79 | Total:   29s | Single:    1s | Shape: (1237,) | NaN: 152
# Alpha  80 | Total:   30s | Single:    1s | Shape: (1237,) | NaN: 0
# Alpha  81 | Total:   31s | Single:    1s | Shape: (1237,) | NaN: 0
# Alpha  82 | Total:   31s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha  83 | Total:   32s | Single:    0s | Shape: (1237,) | NaN: 33
# Alpha  84 | Total:   32s | Single:    0s | Shape: (1237,) | NaN: 34
# Alpha  85 | Total:   33s | Single:    1s | Shape: (1237,) | NaN: 167
# Alpha  86 | Total:   33s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha  87 | Total:   33s | Single:    0s | Shape: (1237,) | NaN: 17
# Alpha  88 | Total:   35s | Single:    1s | Shape: (1237,) | NaN: 2
# Alpha  89 | Total:   35s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha  90 | Total:   35s | Single:    0s | Shape: (1237,) | NaN: 24
# Alpha  91 | Total:   36s | Single:    0s | Shape: (1237,) | NaN: 46
# Alpha  92 | Total:   36s | Single:    1s | Shape: (1237,) | NaN: 279
# Alpha  93 | Total:   37s | Single:    1s | Shape: (1237,) | NaN: 73
# Alpha  94 | Total:   39s | Single:    1s | Shape: (1237,) | NaN: 68
# Alpha  95 | Total:   39s | Single:    1s | Shape: (1237,) | NaN: 0
# Alpha  96 | Total:   41s | Single:    2s | Shape: (1237,) | NaN: 398
# Alpha  97 | Total:   42s | Single:    1s | Shape: (1237,) | NaN: 9
# Alpha  98 | Total:   44s | Single:    1s | Shape: (1237,) | NaN: 9
# Alpha  99 | Total:   44s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha 100 | Total:   44s | Single:    0s | Shape: (1237,) | NaN: 0
# Alpha 101 | Total:   44s | Single:    0s | Shape: (1237,) | NaN: 8
# Stacking alpha signals...
# Normalizing signals...
# Saved alpha signals to: data/1min/alpha101/alpha101_val.npy
# Final shape: (1237, 101)
# ✅ Successfully processed 1min/val
#    Input shape: (1237, 158)
#    Output shape: (1237, 101)
#    Saved to: data/1min/alpha101/alpha101_val.npy
#
# ============================================================
# Processing: 1min/test
# File: /content/drive/.shortcut-targets-by-id/1UkrVedDO8TczbhiaEZeL-35BAs2icj24/FinRL/final/data/1min/BTC_1min_with_sentiment_risk_train_1min_test_15.csv
# ============================================================
# Reading CSV file...
# Data shape: (1238, 158)
# Columns: ['system_time', 'midpoint', 'spread', 'buys', 'sells', 'bids_distance_0', 'asks_distance_0', 'bids_distance_1', 'asks_distance_1', 'bids_distance_2', 'asks_distance_2', 'bids_distance_3', 'asks_distance_3', 'bids_distance_4', 'asks_distance_4', 'bids_distance_5', 'asks_distance_5', 'bids_distance_6', 'asks_distance_6', 'bids_distance_7', 'asks_distance_7', 'bids_distance_8', 'asks_distance_8', 'bids_distance_9', 'asks_distance_9', 'bids_distance_10
# Initializing TechIndicator...
# Generating alpha signals...
# Alpha   1 | Total:    0s | Single:    0s | Shape: (1238,) | NaN: 31
# Alpha   2 | Total:    0s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha   3 | Total:    1s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha   4 | Total:    1s | Single:    0s | Shape: (1238,) | NaN: 17
# Alpha   5 | Total:    1s | Single:    0s | Shape: (1238,) | NaN: 27
# Alpha   6 | Total:    1s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha   7 | Total:    2s | Single:    0s | Shape: (1238,) | NaN: 38
# Alpha   8 | Total:    2s | Single:    0s | Shape: (1238,) | NaN: 24
# Alpha   9 | Total:    2s | Single:    0s | Shape: (1238,) | NaN: 17
# Alpha  10 | Total:    2s | Single:    0s | Shape: (1238,) | NaN: 17
# Alpha  11 | Total:    2s | Single:    0s | Shape: (1238,) | NaN: 29
# Alpha  12 | Total:    2s | Single:    0s | Shape: (1238,) | NaN: 17
# Alpha  13 | Total:    3s | Single:    0s | Shape: (1238,) | NaN: 40
# Alpha  14 | Total:    3s | Single:    0s | Shape: (1238,) | NaN: 13
# Alpha  15 | Total:    3s | Single:    0s | Shape: (1238,) | NaN: 11
# Alpha  16 | Total:    4s | Single:    0s | Shape: (1238,) | NaN: 40
# Alpha  17 | Total:    5s | Single:    1s | Shape: (1238,) | NaN: 36
# Alpha  18 | Total:    5s | Single:    0s | Shape: (1238,) | NaN: 31
# Alpha  19 | Total:    5s | Single:    0s | Shape: (1238,) | NaN: 259
# Alpha  20 | Total:    5s | Single:    0s | Shape: (1238,) | NaN: 28
# Alpha  21 | Total:    5s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha  22 | Total:    5s | Single:    0s | Shape: (1238,) | NaN: 46
# Alpha  23 | Total:    5s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha  24 | Total:    5s | Single:    0s | Shape: (1238,) | NaN: 20
# Alpha  25 | Total:    6s | Single:    0s | Shape: (1238,) | NaN: 28
# Alpha  26 | Total:    6s | Single:    1s | Shape: (1238,) | NaN: 2
# Alpha  27 | Total:    7s | Single:    0s | Shape: (1238,) | NaN: 196
# Alpha  28 | Total:    7s | Single:    0s | Shape: (1238,) | NaN: 23
# Alpha  29 | Total:    7s | Single:    1s | Shape: (1238,) | NaN: 64
# Alpha  30 | Total:    8s | Single:    0s | Shape: (1238,) | NaN: 30
# Alpha  31 | Total:    9s | Single:    1s | Shape: (1238,) | NaN: 30
# Alpha  32 | Total:    9s | Single:    0s | Shape: (1238,) | NaN: 252
# Alpha  33 | Total:    9s | Single:    0s | Shape: (1238,) | NaN: 27
# Alpha  34 | Total:   10s | Single:    1s | Shape: (1238,) | NaN: 37
# Alpha  35 | Total:   11s | Single:    1s | Shape: (1238,) | NaN: 33
# Alpha  36 | Total:   12s | Single:    1s | Shape: (1238,) | NaN: 226
# Alpha  37 | Total:   12s | Single:    0s | Shape: (1238,) | NaN: 227
# Alpha  38 | Total:   13s | Single:    1s | Shape: (1238,) | NaN: 18
# Alpha  39 | Total:   13s | Single:    0s | Shape: (1238,) | NaN: 259
# Alpha  40 | Total:   13s | Single:    0s | Shape: (1238,) | NaN: 18
# Alpha  41 | Total:   13s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha  42 | Total:   14s | Single:    0s | Shape: (1238,) | NaN: 27
# Alpha  43 | Total:   14s | Single:    1s | Shape: (1238,) | NaN: 38
# Alpha  44 | Total:   14s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha  45 | Total:   15s | Single:    0s | Shape: (1238,) | NaN: 1097
# Alpha  46 | Total:   15s | Single:    0s | Shape: (1238,) | NaN: 17
# Alpha  47 | Total:   15s | Single:    0s | Shape: (1238,) | NaN: 27
# Alpha  48 | Total:   15s | Single:    0s | Shape: (1238,) | NaN: 27
# Alpha  49 | Total:   15s | Single:    0s | Shape: (1238,) | NaN: 17
# Alpha  50 | Total:   16s | Single:    0s | Shape: (1238,) | NaN: 393
# Alpha  51 | Total:   16s | Single:    0s | Shape: (1238,) | NaN: 17
# Alpha  52 | Total:   16s | Single:    0s | Shape: (1238,) | NaN: 249
# Alpha  53 | Total:   16s | Single:    0s | Shape: (1238,) | NaN: 26
# Alpha  54 | Total:   16s | Single:    0s | Shape: (1238,) | NaN: 12
# Alpha  55 | Total:   17s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha  56 | Total:   17s | Single:    0s | Shape: (1238,) | NaN: 12
# Alpha  57 | Total:   17s | Single:    0s | Shape: (1238,) | NaN: 12
# Alpha  58 | Total:   17s | Single:    0s | Shape: (1238,) | NaN: 17
# Alpha  59 | Total:   17s | Single:    0s | Shape: (1238,) | NaN: 36
# Alpha  60 | Total:   18s | Single:    0s | Shape: (1238,) | NaN: 36
# Alpha  61 | Total:   18s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha  62 | Total:   19s | Single:    1s | Shape: (1238,) | NaN: 58
# Alpha  63 | Total:   19s | Single:    0s | Shape: (1238,) | NaN: 156
# Alpha  64 | Total:   19s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha  65 | Total:   19s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha  66 | Total:   20s | Single:    1s | Shape: (1238,) | NaN: 9
# Alpha  67 | Total:   21s | Single:    1s | Shape: (1238,) | NaN: 0
# Alpha  68 | Total:   21s | Single:    1s | Shape: (1238,) | NaN: 0
# Alpha  69 | Total:   22s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha  70 | Total:   22s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha  71 | Total:   24s | Single:    2s | Shape: (1238,) | NaN: 15
# Alpha  72 | Total:   25s | Single:    1s | Shape: (1238,) | NaN: 9
# Alpha  73 | Total:   26s | Single:    1s | Shape: (1238,) | NaN: 16
# Alpha  74 | Total:   26s | Single:    1s | Shape: (1238,) | NaN: 0
# Alpha  75 | Total:   27s | Single:    1s | Shape: (1238,) | NaN: 0
# Alpha  76 | Total:   27s | Single:    1s | Shape: (1238,) | NaN: 0
# Alpha  77 | Total:   28s | Single:    0s | Shape: (1238,) | NaN: 9
# Alpha  78 | Total:   28s | Single:    1s | Shape: (1238,) | NaN: 194
# Alpha  79 | Total:   29s | Single:    1s | Shape: (1238,) | NaN: 201
# Alpha  80 | Total:   30s | Single:    1s | Shape: (1238,) | NaN: 0
# Alpha  81 | Total:   31s | Single:    1s | Shape: (1238,) | NaN: 0
# Alpha  82 | Total:   31s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha  83 | Total:   31s | Single:    0s | Shape: (1238,) | NaN: 33
# Alpha  84 | Total:   32s | Single:    0s | Shape: (1238,) | NaN: 34
# Alpha  85 | Total:   32s | Single:    1s | Shape: (1238,) | NaN: 177
# Alpha  86 | Total:   33s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha  87 | Total:   33s | Single:    0s | Shape: (1238,) | NaN: 17
# Alpha  88 | Total:   34s | Single:    1s | Shape: (1238,) | NaN: 2
# Alpha  89 | Total:   35s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha  90 | Total:   35s | Single:    0s | Shape: (1238,) | NaN: 24
# Alpha  91 | Total:   35s | Single:    0s | Shape: (1238,) | NaN: 46
# Alpha  92 | Total:   36s | Single:    1s | Shape: (1238,) | NaN: 224
# Alpha  93 | Total:   37s | Single:    1s | Shape: (1238,) | NaN: 68
# Alpha  94 | Total:   39s | Single:    1s | Shape: (1238,) | NaN: 70
# Alpha  95 | Total:   39s | Single:    1s | Shape: (1238,) | NaN: 0
# Alpha  96 | Total:   41s | Single:    1s | Shape: (1238,) | NaN: 449
# Alpha  97 | Total:   42s | Single:    1s | Shape: (1238,) | NaN: 9
# Alpha  98 | Total:   43s | Single:    1s | Shape: (1238,) | NaN: 9
# Alpha  99 | Total:   43s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha 100 | Total:   43s | Single:    0s | Shape: (1238,) | NaN: 0
# Alpha 101 | Total:   43s | Single:    0s | Shape: (1238,) | NaN: 12
# Stacking alpha signals...
# Normalizing signals...
# Saved alpha signals to: data/1min/alpha101/alpha101_test.npy
# Final shape: (1238, 101)
# ✅ Successfully processed 1min/test
#    Input shape: (1238, 158)
#    Output shape: (1238, 101)
#    Saved to: data/1min/alpha101/alpha101_test.npy
#
# ============================================================
# Processing complete for 1min!
# Alpha 101 signals have been generated for 1min datasets.

# %%
process_5min()
# Out:
# BTC_5min_with_sentiment_risk_train_5min_train_70.csv
# BTC_5min_with_sentiment_risk_train_5min_val_15.csv
# BTC_5min_with_sentiment_risk_train_5min_test_15.csv
# Found 3 CSV files for 5min:
#   train: BTC_5min_with_sentiment_risk_train_5min_train_70.csv
#   val: BTC_5min_with_sentiment_risk_train_5min_val_15.csv
#   test: BTC_5min_with_sentiment_risk_train_5min_test_15.csv
#
# ============================================================
# Processing: 5min/train
# File: /content/drive/.shortcut-targets-by-id/1UkrVedDO8TczbhiaEZeL-35BAs2icj24/FinRL/final/data/5min/BTC_5min_with_sentiment_risk_train_5min_train_70.csv
# ============================================================
el_notional_12', 'bids_limit_notional_12', 'bids_market_notional_12', 'asks_notional_12', 'asks_cancel_notional_12', 'asks_limit_notional_12', 'asks_market_notional_12', 'bids_notional_13', 'bids_cancel_notional_13', 'bids_limit_notional_13', 'bids_market_notional_13', 'asks_notional_13', 'asks_cancel_notional_13', 'asks_limit_notional_13', 'asks_market_notional_13', 'bids_notional_14', 'bids_cancel_notional_14', 'bids_limit_notional_14', 'bids_market_notional_14', 'asks_notional_14', 'asks_cancel_notional_14', 'asks_limit_notional_14', 'asks_market_notional_14', 'sentiment_score', 'risk_score', 'system_time.1']
# Initializing TechIndicator...
# Generating alpha signals...
# Alpha   1 | Total:    0s | Single:    0s | Shape: (1155,) | NaN: 32
# Alpha   2 | Total:    1s | Single:    0s | Shape: (1155,) | NaN: 0
# Alpha   3 | Total:    1s | Single:    0s | Shape: (1155,) | NaN: 0
# Alpha   4 | Total:    1s | Single:    0s | Shape: (1155,) | NaN: 17
# Alpha   5 | Total:    1s | Single:    0s | Shape: (1155,) | NaN: 28
# Alpha   6 | Total:    1s | Single:    0s | Shape: (1155,) | NaN: 0
# Alpha   7 | Total:    2s | Single:    0s | Shape: (1155,) | NaN: 43
# Alpha   8 | Total:    2s | Single:    0s | Shape: (1155,) | NaN: 24
# Alpha   9 | Total:    2s | Single:    0s | Shape: (1155,) | NaN: 11
# Alpha  10 | Total:    2s | Single:    0s | Shape: (1155,) | NaN: 11
# Alpha  11 | Total:    2s | Single:    0s | Shape: (1155,) | NaN: 30
# Alpha  12 | Total:    2s | Single:    0s | Shape: (1155,) | NaN: 11
# Alpha  13 | Total:    3s | Single:    0s | Shape: (1155,) | NaN: 41
# Alpha  14 | Total:    3s | Single:    0s | Shape: (1155,) | NaN: 13
# Alpha  15 | Total:    3s | Single:    0s | Shape: (1155,) | NaN: 11
# Alpha  16 | Total:    4s | Single:    0s | Shape: (1155,) | NaN: 41
# Alpha  17 | Total:    5s | Single:    1s | Shape: (1155,) | NaN: 37
# Alpha  18 | Total:    5s | Single:    0s | Shape: (1155,) | NaN: 32
# Alpha  19 | Total:    5s | Single:    0s | Shape: (1155,) | NaN: 259
# Alpha  20 | Total:    5s | Single:    0s | Shape: (1155,) | NaN: 29
# Alpha  21 | Total:    5s | Single:    0s | Shape: (1155,) | NaN: 0
# Alpha  22 | Total:    5s | Single:    0s | Shape: (1155,) | NaN: 47
# Alpha  23 | Total:    5s | Single:    0s | Shape: (1155,) | NaN: 0
# Alpha  24 | Total:    5s | Single:    0s | Shape: (1155,) | NaN: 13
# Alpha  25 | Total:    5s | Single:    0s | Shape: (1155,) | NaN: 28
# Alpha  26 | Total:    6s | Single:    1s | Shape: (1155,) | NaN: 2
# Alpha  27 | Total:    7s | Single:    1s | Shape: (1155,) | NaN: 134
# Alpha  28 | Total:    7s | Single:    0s | Shape: (1155,) | NaN: 23
# Alpha  29 | Total:    8s | Single:    2s | Shape: (1155,) | NaN: 65
# Alpha  30 | Total:    9s | Single:    0s | Shape: (1155,) | NaN: 31
# Alpha  70 | Total:   25s | Single:    0s | Shape: (1155,) | NaN: 0
# Alpha  71 | Total:   27s | Single:    1s | Shape: (1155,) | NaN: 15
# Alpha  72 | Total:   28s | Single:    1s | Shape: (1155,) | NaN: 9
# Alpha  73 | Total:   28s | Single:    0s | Shape: (1155,) | NaN: 16
# Alpha  74 | Total:   29s | Single:    1s | Shape: (1155,) | NaN: 0
# Alpha  75 | Total:   29s | Single:    1s | Shape: (1155,) | NaN: 0
# Alpha  76 | Total:   30s | Single:    1s | Shape: (1155,) | NaN: 0
# Alpha  77 | Total:   30s | Single:    0s | Shape: (1155,) | NaN: 9
# Alpha  78 | Total:   31s | Single:    1s | Shape: (1155,) | NaN: 153
# Alpha  79 | Total:   31s | Single:    1s | Shape: (1155,) | NaN: 137
# Alpha  80 | Total:   32s | Single:    1s | Shape: (1155,) | NaN: 0
# Alpha  81 | Total:   33s | Single:    1s | Shape: (1155,) | NaN: 0
# Alpha  82 | Total:   33s | Single:    0s | Shape: (1155,) | NaN: 0
# Alpha  83 | Total:   33s | Single:    0s | Shape: (1155,) | NaN: 34
# Alpha  84 | Total:   34s | Single:    0s | Shape: (1155,) | NaN: 34
# Alpha  85 | Total:   34s | Single:    1s | Shape: (1155,) | NaN: 90
# Alpha  86 | Total:   35s | Single:    0s | Shape: (1155,) | NaN: 0
# Alpha  87 | Total:   35s | Single:    0s | Shape: (1155,) | NaN: 17
# Alpha  88 | Total:   37s | Single:    1s | Shape: (1155,) | NaN: 2
# Alpha  89 | Total:   37s | Single:    0s | Shape: (1155,) | NaN: 0
# Alpha  90 | Total:   37s | Single:    0s | Shape: (1155,) | NaN: 24
# Alpha  91 | Total:   37s | Single:    0s | Shape: (1155,) | NaN: 47
# Alpha  92 | Total:   38s | Single:    1s | Shape: (1155,) | NaN: 204
# Alpha  93 | Total:   40s | Single:    1s | Shape: (1155,) | NaN: 84
# Alpha  94 | Total:   41s | Single:    1s | Shape: (1155,) | NaN: 81
# Alpha  95 | Total:   41s | Single:    0s | Shape: (1155,) | NaN: 0
# Alpha  96 | Total:   42s | Single:    1s | Shape: (1155,) | NaN: 329
# Alpha  97 | Total:   43s | Single:    1s | Shape: (1155,) | NaN: 9
# Alpha  98 | Total:   44s | Single:    1s | Shape: (1155,) | NaN: 9
# Alpha  99 | Total:   44s | Single:    0s | Shape: (1155,) | NaN: 0
# Alpha 100 | Total:   45s | Single:    0s | Shape: (1155,) | NaN: 0
# Alpha 101 | Total:   45s | Single:    0s | Shape: (1155,) | NaN: 6
# Stacking alpha signals...
# Normalizing signals...
# Saved alpha signals to: data/5min/alpha101/alpha101_train.npy
# Final shape: (1155, 101)
# ✅ Successfully processed 5min/train
#    Input shape: (1155, 158)
#    Output shape: (1155, 101)
#    Saved to: data/5min/alpha101/alpha101_train.npy
#
# ============================================================
# Processing: 5min/val
# File: /content/drive/.shortcut-targets-by-id/1UkrVedDO8TczbhiaEZeL-35BAs2icj24/FinRL/final/data/5min/BTC_5min_with_sentiment_risk_train_5min_val_15.csv
# ============================================================
# Reading CSV file...
12', 'bids_limit_notional_12', 'bids_market_notional_12', 'asks_notional_12', 'asks_cancel_notional_12', 'asks_limit_notional_12', 'asks_market_notional_12', 'bids_notional_13', 'bids_cancel_notional_13', 'bids_limit_notional_13', 'bids_market_notional_13', 'asks_notional_13', 'asks_cancel_notional_13', 'asks_limit_notional_13', 'asks_market_notional_13', 'bids_notional_14', 'bids_cancel_notional_14', 'bids_limit_notional_14', 'bids_market_notional_14', 'asks_notional_14', 'asks_cancel_notional_14', 'asks_limit_notional_14', 'asks_market_notional_14', 'sentiment_score', 'risk_score', 'system_time.1']
# Initializing TechIndicator...
# Generating alpha signals...
# Alpha   1 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 31
# Alpha   2 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha   3 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha   4 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 17
# Alpha   5 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 27
# Alpha   6 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha   7 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 36
# Alpha   8 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 24
# Alpha   9 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 14
# Alpha  10 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 14
# Alpha  11 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 29
# Alpha  12 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 14
# Alpha  13 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 40
# Alpha  14 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 13
# Alpha  15 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 11
# Alpha  16 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 40
# Alpha  17 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 36
# Alpha  18 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 31
# Alpha  19 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 248
# Alpha  20 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 28
# Alpha  21 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  22 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 46
# Alpha  23 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  24 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 17
# Alpha  25 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 28
# Alpha  26 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 2
# Alpha  27 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 36
# Alpha  28 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 23
# Alpha  29 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 64
# Alpha  30 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 30
# Alpha  31 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 30
# Alpha  32 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 248
# Alpha  33 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 27
# Alpha  34 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 37
# Alpha  35 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 33
# Alpha  36 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 226
# Alpha  37 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 227
# Alpha  38 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 18
# Alpha  39 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 248
# Alpha  40 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 18
# Alpha  41 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  42 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 27
# Alpha  43 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 38
# Alpha  44 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  45 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 221
# Alpha  46 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 14
# Alpha  47 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 27
# Alpha  48 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 27
# Alpha  49 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 14
# Alpha  50 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 77
# Alpha  51 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 14
# Alpha  52 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 248
# Alpha  53 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 19
# Alpha  54 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 9
# Alpha  55 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  56 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 9
# Alpha  57 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 9
# Alpha  58 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 14
# Alpha  59 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 36
# Alpha  60 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 36
# Alpha  61 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  62 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 58
# Alpha  63 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 156
# Alpha  64 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  65 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  66 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 9
# Alpha  67 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  68 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  69 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  70 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  71 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 15
# Alpha  72 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 9
# Alpha  73 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 16
# Alpha  74 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  75 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  76 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  77 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 9
# Alpha  78 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 84
# Alpha  79 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 78
# Alpha  80 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  81 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  82 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  83 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 33
# Alpha  84 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 34
# Alpha  85 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 67
# Alpha  86 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  87 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 17
# Alpha  88 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 2
# Alpha  89 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  90 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 24
# Alpha  91 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 46
# Alpha  92 | Total:    7s | Single:    0s | Shape: (248,) | NaN: 31
# Alpha  93 | Total:    7s | Single:    0s | Shape: (248,) | NaN: 70
# Alpha  94 | Total:    7s | Single:    0s | Shape: (248,) | NaN: 70
# Alpha  95 | Total:    7s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  96 | Total:    7s | Single:    0s | Shape: (248,) | NaN: 48
# Alpha  97 | Total:    8s | Single:    0s | Shape: (248,) | NaN: 9
# Alpha  98 | Total:    8s | Single:    0s | Shape: (248,) | NaN: 9
# Alpha  99 | Total:    8s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha 100 | Total:    8s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha 101 | Total:    8s | Single:    0s | Shape: (248,) | NaN: 9
# Stacking alpha signals...
# Normalizing signals...
# Saved alpha signals to: data/5min/alpha101/alpha101_val.npy
# Final shape: (248, 101)
# ✅ Successfully processed 5min/val
#    Input shape: (248, 158)
#    Output shape: (248, 101)
#    Saved to: data/5min/alpha101/alpha101_val.npy
#
# ============================================================
# Processing: 5min/test
# File: /content/drive/.shortcut-targets-by-id/1UkrVedDO8TczbhiaEZeL-35BAs2icj24/FinRL/final/data/5min/BTC_5min_with_sentiment_risk_train_5min_test_15.csv
# ============================================================
# Reading CSV file...
# Data shape: (248, 158)
# Columns: ['system_time', 'midpoint', 'spread', 'buys', 'sells', 'bids_distance_0', 'asks_distance_0', 'bids_distance_1', 'asks_distance_1', 'bids_distance_2', 'asks_distance_2', 'bids_distance_3', 'asks_distance_3', 'bids_distance_4', 'asks_distance_4', 'bids_distance_5', 'asks_distance_5', 'bids_distance_6', 'asks_distance_6', 'bids_distance_7', 'asks_distance_7', 'bids_distance_8', 'asks_distance_8', 'bids_distance_9', 'asks_distance_9', 'bids_distance_10', 'asks_distance_10', 'bids_distance_11', 'asks_distance_11', 'bids_distance_12', 'asks_distance_12', 'bids_distance_13', 'asks_distance_13', 'bids_distance_14', 'asks_distance_14', 'bids_notional_0', 'bids_cancel_notional_0', 'bids_limit_notional_0', 'bids_market_notional_0', 'asks_notional_0', 'asks_cancel_notional_0', 'asks_limit_notional_0', 'asks_market_notional_0', 'bids_notional_1', 'bids_cancel_notional_1', 'bids_limit_notional_1', 'bids_market_notional_1', 'asks_notional_1', 'asks_cancel_notional_1', 'asks_limit_notional_1', 'asks_market_notional_1', 'bids_notional_2', 'bids_cancel_notional_2', 'bids_limit_notional_2', 'bids_market_notional_2', 'asks_notional_2', 'asks_cancel_notional_2', 'asks_limit_notional_2', 'asks_market_notional_2', 'bids_notional_3', 'bids_cancel_notional_3', 'bids_limit_notional_3', 'bids_market_notional_3', 'asks_notional_3', 'asks_cancel_notional_3', 'asks_limit_notional_3', 'asks_market_notional_3', 'bids_notional_4', 'bids_cancel_notional_4', 'bids_limit_notional_4', 'bids_market_notional_4', 'asks_notional_4', 'asks_cancel_notional_4', 'asks_limit_notional_4', 'asks_market_notional_4', 'bids_notional_5', 'bids_cancel_notional_5', 'bids_limit_notional_5', 'bids_market_notional_5', 'asks_notional_5', 'asks_cancel_notional_5', 'asks_limit_notional_5', 'asks_market_notional_5', 'bids_notional_6', 'bids_cancel_notional_6', 'bids_limit_notional_6', 'bids_market_notional_6', 'asks_notional_6', 'asks_cancel_notional_6', 'asks_limit_notional_6', 'asks_market_notional_6', 'bids_notional_7', 'bids_cancel_notional_7', 'bids_limit_notional_7', 'bids_market_notional_7', 'asks_notional_7', 'asks_cancel_notional_7', 'asks_limit_notional_7', 'asks_market_notional_7', 'bids_notional_8', 'bids_cancel_notional_8', 'bids_limit_notional_8', 'bids_market_notional_8', 'asks_notional_8', 'asks_cancel_notional_8', 'asks_limit_notional_8', 'asks_market_notional_8', 'bids_notional_9', 'bids_cancel_notional_9', 'bids_limit_notional_9', 'bids_market_notional_9', 'asks_notional_9', 'asks_cancel_notional_9', 'asks_limit_notional_9', 'asks_market_notional_9', 'bids_notional_10', 'bids_cancel_notional_10', 'bids_limit_notional_10', 'bids_market_notional_10', 'asks_notional_10', 'asks_cancel_notional_10', 'asks_limit_notional_10', 'asks_market_notional_10', 'bids_notional_11', 'bids_cancel_notional_11', 'bids_limit_notional_11', 'bids_market_notional_11', 'asks_notional_11', 'asks_cancel_notional_11', 'asks_limit_notional_11', 'asks_market_notional_11', 'bids_notional_12', 'bids_cancel_notional_12', 'bids_limit_notional_12', 'bids_market_notional_12', 'asks_notional_12', 'asks_cancel_notional_12', 'asks_limit_notional_12', 'asks_market_notional_12', 'bids_notional_13', 'bids_cancel_notional_13', 'bids_limit_notional_13', 'bids_market_notional_13', 'asks_notional_13', 'asks_cancel_notional_13', 'asks_limit_notional_13', 'asks_market_notional_13', 'bids_notional_14', 'bids_cancel_notional_14', 'bids_limit_notional_14', 'bids_market_notional_14', 'asks_notional_14', 'asks_cancel_notional_14', 'asks_limit_notional_14', 'asks_market_notional_14', 'sentiment_score', 'risk_score', 'system_time.1']
# Initializing TechIndicator...
# Generating alpha signals...
# Alpha   1 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 32
# Alpha   2 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha   3 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha   4 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 17
# Alpha   5 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 28
# Alpha   6 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha   7 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 39
# Alpha   8 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 24
# Alpha   9 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 17
# Alpha  10 | Total:    0s | Single:    0s | Shape: (248,) | NaN: 17
# Alpha  11 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 30
# Alpha  12 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 17
# Alpha  13 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 41
# Alpha  14 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 13
# Alpha  15 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 11
# Alpha  16 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 41
# Alpha  17 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 37
# Alpha  18 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 32
# Alpha  19 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 248
# Alpha  20 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 29
# Alpha  21 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  22 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 47
# Alpha  23 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  24 | Total:    1s | Single:    0s | Shape: (248,) | NaN: 18
# Alpha  25 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 28
# Alpha  26 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 2
# Alpha  27 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 24
# Alpha  28 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 23
# Alpha  29 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 65
# Alpha  30 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 31
# Alpha  31 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 31
# Alpha  32 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 248
# Alpha  33 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 28
# Alpha  34 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 38
# Alpha  35 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 34
# Alpha  36 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 227
# Alpha  37 | Total:    2s | Single:    0s | Shape: (248,) | NaN: 228
# Alpha  38 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 18
# Alpha  39 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 248
# Alpha  40 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 18
# Alpha  41 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  42 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 28
# Alpha  43 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 38
# Alpha  44 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  45 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 213
# Alpha  46 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 17
# Alpha  47 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 28
# Alpha  48 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 28
# Alpha  49 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 17
# Alpha  50 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 54
# Alpha  51 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 17
# Alpha  52 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 248
# Alpha  53 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 24
# Alpha  54 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 11
# Alpha  55 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  56 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 11
# Alpha  57 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 11
# Alpha  58 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 17
# Alpha  59 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 37
# Alpha  60 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 37
# Alpha  61 | Total:    3s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  62 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 58
# Alpha  63 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 156
# Alpha  64 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  65 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  66 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 9
# Alpha  67 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  68 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  69 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  70 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  71 | Total:    4s | Single:    0s | Shape: (248,) | NaN: 15
# Alpha  72 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 9
# Alpha  73 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 16
# Alpha  74 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  75 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  76 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  77 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 9
# Alpha  78 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 73
# Alpha  79 | Total:    5s | Single:    0s | Shape: (248,) | NaN: 73
# Alpha  80 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  81 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  82 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  83 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 34
# Alpha  84 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 34
# Alpha  85 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 57
# Alpha  86 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  87 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 17
# Alpha  88 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 2
# Alpha  89 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  90 | Total:    6s | Single:    0s | Shape: (248,) | NaN: 24
# Alpha  91 | Total:    7s | Single:    0s | Shape: (248,) | NaN: 47
# Alpha  92 | Total:    7s | Single:    0s | Shape: (248,) | NaN: 94
# Alpha  93 | Total:    7s | Single:    0s | Shape: (248,) | NaN: 87
# Alpha  94 | Total:    7s | Single:    0s | Shape: (248,) | NaN: 77
# Alpha  95 | Total:    7s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha  96 | Total:    7s | Single:    0s | Shape: (248,) | NaN: 57
# Alpha  97 | Total:    7s | Single:    0s | Shape: (248,) | NaN: 9
# Alpha  98 | Total:    8s | Single:    0s | Shape: (248,) | NaN: 9
# Alpha  99 | Total:    8s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha 100 | Total:    8s | Single:    0s | Shape: (248,) | NaN: 0
# Alpha 101 | Total:    8s | Single:    0s | Shape: (248,) | NaN: 11
# Stacking alpha signals...
# Normalizing signals...
# Saved alpha signals to: data/5min/alpha101/alpha101_test.npy
# Final shape: (248, 101)
# ✅ Successfully processed 5min/test
#    Input shape: (248, 158)
#    Output shape: (248, 101)
#    Saved to: data/5min/alpha101/alpha101_test.npy
#
# ============================================================
# Processing complete for 5min!
# Alpha 101 signals have been generated for 5min datasets.
